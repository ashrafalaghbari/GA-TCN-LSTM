# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashrafalaghbari/oil-production-forecasting/blob/main/optimal_lstm_single_step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense,Activation, Dropout
from keras.layers import LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# # check if GPU is utilized 
# device_name = tf.config.experimental.list_physical_devices()[-1][-1]
# if device_name != 'GPU':
#     raise SystemError('GPU device not found')
# print('Found GPU at: {}'.format(tf.test.gpu_device_name()))

# %%
# Select the best features
def select_features(df, target, correlation_type, threshold):
    if (threshold < -1 ) | (threshold > 1 ) :
            raise SystemError('correlation threshold is out of bounds')
    features = df.corr(correlation_type).loc[target].drop(target)
    best_features = features.where(abs(features) > threshold).dropna()
    df = pd.concat([df[target], df[best_features.index]], axis=1)
    return df

# convert series to supervised learning
def series_to_supervised(data, columns, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('%s(t-%d)' % (columns[j], i)) for j in range(n_vars)]
        # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('%s(t)' % (columns[j])) for j in range(n_vars)]
        else:
            names += [('%s(t+%d)' % (columns[j], i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# scale train and test data to new feature range[0, 1]
def scale(train, test):
	# fit scaler
	scaler = MinMaxScaler(feature_range=(0, 1))
	scaler = scaler.fit(train)
	# transform train
	train = train.reshape(train.shape[0], train.shape[1])
	train_scaled = scaler.transform(train)
	# transform test
	test = test.reshape(test.shape[0], test.shape[1])
	test_scaled = scaler.transform(test)
	return scaler, train_scaled, test_scaled


# inverse differencing
def inverse_difference(history, interval=1):
	return history[-len(test_scaled)-interval:-interval]

# %%
#Evaluation metrics
# compute RMSPE
def RMSPE(x,y):
	result=0
	for i in range(len(x)):
		result += ((x[i]-y[i])/x[i])**2
	result /= len(x)
	result = sqrt(result)
	result *= 100
	return result

# compute MAPE
def MAPE(x,y):
	result=0
	for i in range(len(x)):
		result += abs((x[i]-y[i])/x[i])
	result /= len(x)
	result *= 100
	return result

# compute wMAPE weighted absolute percentage error
def wMAPE(actual, predicted): 
    result_nom = 0
    result_deno = 0
    for i in range(len(actual)):
        result_nom +=  abs(actual[i] - predicted[i])
        result_deno +=  abs(actual[i]) 
    result = result_nom/result_deno
    return result *100

def SMAPE(actual, predicted): #Symmetric (adjusted) MEAN ABSOLUTE PERCENTAGE ERROR (SMAPE)
    result = 0
    for i in range(len(actual)):
        result += abs(actual[i] - predicted[i])/(abs(actual[i]) + abs(predicted[i]))
    result = 2 * result/ len(actual) 
    return result * 100

# %%
#load dataset
series = pd.read_csv('/content/drive/MyDrive/volve_production_data/model.csv', 
                     parse_dates=["DATEPRD"], index_col="DATEPRD")

# %%
# select feature based on correlation
series = select_features(series, "BORE_OIL_VOL", "spearman", 0)
# select features manually
series =series[["ON_STREAM_HRS",'BORE_GAS_VOL', 'BORE_WAT_VOL',
                'AVG_CHOKE_SIZE_P','F_4_BORE_WI_VOL','F_5_BORE_WI_VOL',
                 "BORE_OIL_VOL"]]

# %%
series["next_choke_size"] = series['AVG_CHOKE_SIZE_P'].shift(-1)
series["next_on_stream"] = series['ON_STREAM_HRS'].shift(-1)
series["next_BORE_GAS_VOL"] = series['BORE_GAS_VOL'].shift(-1)
series.dropna(inplace=True)

# %%
# # # Define the bin edges
# bin_edges_onstream = [0, 5, 10, 15, 20, 24]
# bin_edges_choke = [0, 20, 40, 60, 80, 100]
# lambda_bin_edges = lambda x: bin_edges_onstream if x == "ON_STREAM_HRS" else bin_edges_choke
# c = series[["ON_STREAM_HRS","AVG_CHOKE_SIZE_P"]].apply(lambda x: pd.cut(x, lambda_bin_edges(x.name)))
# one_hot_encoded_data = pd.get_dummies(c, columns = ['ON_STREAM_HRS',"AVG_CHOKE_SIZE_P"])
# #one_hot_encoded_data.drop(['ON_STREAM_HRS', "AVG_CHOKE_SIZE_P"], axis=1, inplace=True)
# series = pd.concat([series,one_hot_encoded_data], axis=1)

# %%
column_to_move = series.pop("BORE_OIL_VOL")

# insert column with insert(location, column_name, column_value)

series.insert(len(series.columns), "BORE_OIL_VOL", column_to_move)

# %%
# # Data visulaization and disribution plots for well F-14 after including the injectors
data = series.columns

# Creating figure with two rows and one column
fig, axs = plt.subplots(nrows=len(data), figsize=(17, 28))

axs = axs.ravel()

for id, column in enumerate(data):

    axs[id].plot(series[column])
    axs[id].grid(True)
    axs[id].legend([column], loc='lower left', fontsize=9, handlelength=0, handletextpad=0, frameon=False)
    
plt.show()

# %% [markdown]
# **Multi-output forecasting strategy**

# %%
new_row = series[series['ON_STREAM_HRS']==0].sample(1)
c = series[:3].copy()

# %%
B= pd.DataFrame(new_row , index=[0])

# %%
new_index = np.random.randint(0, len(series[:-381]))

# %%
c.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-1a3609c85337> in <module>
# ----> 1 c.loc[0]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     698         else:
#     699             # unrecognized type
# --> 700             raise KeyError(key)
#     701
#     702         try:
#
# KeyError: 0

# %%
new_row.shape
# Out:
# (1, 10)

# %%
c.shape
# Out:
# (3, 10)

# %%
c
# Out:
#             ON_STREAM_HRS  BORE_GAS_VOL  BORE_WAT_VOL  AVG_CHOKE_SIZE_P  \
# DATEPRD
# 2010-01-01           24.0  1.462166e+07  15304.241356         50.150825
# 2010-01-02           24.0  1.469266e+07  16519.118273         50.694654
# 2010-01-03           24.0  1.400904e+07  14796.150455         47.665676
#
#             F_4_BORE_WI_VOL  F_5_BORE_WI_VOL  next_choke_size  next_on_stream  \
# DATEPRD
# 2010-01-01     44109.287732     49054.221066        50.694654            24.0
# 2010-01-02     41936.969541     51515.296516        47.665676            24.0
# 2010-01-03     41114.572918     51717.286427        44.706230            24.0
#
#             next_BORE_GAS_VOL  BORE_OIL_VOL
# DATEPRD
# 2010-01-01       1.469266e+07  18593.749401
# 2010-01-02       1.400904e+07  18701.242265
# 2010-01-03       1.341015e+07  17799.912406

# %%
# # # convert series to stationary 
series_diff = series.copy()
diff_order = 1
series_diff['BORE_OIL_VOL'] = series_diff['BORE_OIL_VOL'].diff(diff_order)
# # convert the stationary series to supervise learning
timesteps = 1 # lag features
steps_ahead = 1
series_supervised = series_to_supervised(series_diff, series_diff.columns, n_in=timesteps, n_out=steps_ahead, dropnan=True)

# %%
series_supervised
# Out:
#             ON_STREAM_HRS(t-1)  BORE_GAS_VOL(t-1)  BORE_WAT_VOL(t-1)  \
# DATEPRD
# 2010-01-03                24.0       1.469266e+07       16519.118273
# 2010-01-04                24.0       1.400904e+07       14796.150455
# 2010-01-05                24.0       1.341015e+07       13428.619835
# 2010-01-06                24.0       1.361768e+07        9839.905499
# 2010-01-07                24.0       1.364834e+07       10054.073550
# ...                        ...                ...                ...
# 2015-03-18                24.0       1.348689e+06       21771.927799
# 2015-03-19                24.0       1.354500e+06       21725.383201
# 2015-03-20                24.0       1.366424e+06       21779.601368
# 2015-03-21                24.0       1.397308e+06       23586.538158
# 2015-03-22                24.0       1.408435e+06       22172.777429
#
#             AVG_CHOKE_SIZE_P(t-1)  F_4_BORE_WI_VOL(t-1)  F_5_BORE_WI_VOL(t-1)  \
# DATEPRD
# 2010-01-03              50.694654          41936.969541          51515.296516
# 2010-01-04              47.665676          41114.572918          51717.286427
# 2010-01-05              44.706230          40267.292699          51948.640243
# 2010-01-06              45.743761          40524.238503          52129.744099
# 2010-01-07              46.053981          40733.215195          52212.108216
# ...                           ...                   ...                   ...
# 2015-03-18             100.000000          26885.294563          27819.994862
# 2015-03-19             100.000000          27174.003165          26957.732482
# 2015-03-20             100.000000          27765.068530          26704.126695
# 2015-03-21             100.000000          26112.632371          27951.162219
# 2015-03-22             100.000000          26281.191015          27980.731217
#
#             next_choke_size(t-1)  next_on_stream(t-1)  next_BORE_GAS_VOL(t-1)  \
# DATEPRD
# 2010-01-03             47.665676                 24.0            1.400904e+07
# 2010-01-04             44.706230                 24.0            1.341015e+07
# 2010-01-05             45.743761                 24.0            1.361768e+07
# 2010-01-06             46.053981                 24.0            1.364834e+07
# 2010-01-07             44.740102                 24.0            1.350971e+07
# ...                          ...                  ...                     ...
# 2015-03-18            100.000000                 24.0            1.354500e+06
# 2015-03-19            100.000000                 24.0            1.366424e+06
# 2015-03-20            100.000000                 24.0            1.397308e+06
# 2015-03-21            100.000000                 24.0            1.408435e+06
# 2015-03-22            100.000000                 24.0            1.379366e+06
#
#             BORE_OIL_VOL(t-1)  ON_STREAM_HRS(t)  BORE_GAS_VOL(t)  \
# DATEPRD
# 2010-01-03         107.492863              24.0     1.400904e+07
# 2010-01-04        -901.329859              24.0     1.341015e+07
# 2010-01-05        -797.296392              24.0     1.361768e+07
# 2010-01-06         268.323320              24.0     1.364834e+07
# 2010-01-07          60.822469              24.0     1.350971e+07
# ...                       ...               ...              ...
# 2015-03-18          18.806534              24.0     1.354500e+06
# 2015-03-19          10.315289              24.0     1.366424e+06
# 2015-03-20           3.270702              24.0     1.397308e+06
# 2015-03-21          44.783451              24.0     1.408435e+06
# 2015-03-22          17.925960              24.0     1.379366e+06
#
#             BORE_WAT_VOL(t)  AVG_CHOKE_SIZE_P(t)  F_4_BORE_WI_VOL(t)  \
# DATEPRD
# 2010-01-03     14796.150455            47.665676        41114.572918
# 2010-01-04     13428.619835            44.706230        40267.292699
# 2010-01-05      9839.905499            45.743761        40524.238503
# 2010-01-06     10054.073550            46.053981        40733.215195
# 2010-01-07     12837.943721            44.740102        39969.857579
# ...                     ...                  ...                 ...
# 2015-03-18     21725.383201           100.000000        27174.003165
# 2015-03-19     21779.601368           100.000000        27765.068530
# 2015-03-20     23586.538158           100.000000        26112.632371
# 2015-03-21     22172.777429           100.000000        26281.191015
# 2015-03-22     21863.570340           100.000000        26104.671114
#
#             F_5_BORE_WI_VOL(t)  next_choke_size(t)  next_on_stream(t)  \
# DATEPRD
# 2010-01-03        51717.286427           44.706230               24.0
# 2010-01-04        51948.640243           45.743761               24.0
# 2010-01-05        52129.744099           46.053981               24.0
# 2010-01-06        52212.108216           44.740102               24.0
# 2010-01-07        51109.971510           44.805229               24.0
# ...                        ...                 ...                ...
# 2015-03-18        26957.732482          100.000000               24.0
# 2015-03-19        26704.126695          100.000000               24.0
# 2015-03-20        27951.162219          100.000000               24.0
# 2015-03-21        27980.731217          100.000000               24.0
# 2015-03-22        27500.440270           99.994093               24.0
#
#             next_BORE_GAS_VOL(t)  BORE_OIL_VOL(t)
# DATEPRD
# 2010-01-03          1.341015e+07      -901.329859
# 2010-01-04          1.361768e+07      -797.296392
# 2010-01-05          1.364834e+07       268.323320
# 2010-01-06          1.350971e+07        60.822469
# 2010-01-07          1.349732e+07      -193.160084
# ...                          ...              ...
# 2015-03-18          1.366424e+06        10.315289
# 2015-03-19          1.397308e+06         3.270702
# 2015-03-20          1.408435e+06        44.783451
# 2015-03-21          1.379366e+06        17.925960
# 2015-03-22          1.263109e+06      -104.788245
#
# [1801 rows x 20 columns]

# %%
test_y[:10]
# Out:
# array([[0.48464176],
#        [0.48801066],
#        [0.49000228],
#        [0.47421549],
#        [0.48788185],
#        [0.48824351],
#        [0.493391  ],
#        [0.48883307],
#        [0.48923684],
#        [0.48786451]])

# %%
test_y[:10]
# Out:
# array([[0.55175402],
#        [0.54699636],
#        [0.54995765],
#        [0.5517083 ],
#        [0.53783159],
#        [0.54984442],
#        [0.55016233],
#        [0.55468701],
#        [0.55068055],
#        [0.55103547]])

# %%
series_supervised.columns
# Out:
# Index(['ON_STREAM_HRS(t-1)', 'BORE_GAS_VOL(t-1)', 'BORE_WAT_VOL(t-1)',
#        'AVG_DOWNHOLE_TEMPERATURE(t-1)', 'AVG_CHOKE_SIZE_P(t-1)',
#        'F_4_BORE_WI_VOL(t-1)', 'F_5_BORE_WI_VOL(t-1)', 'next_choke_size(t-1)',
#        'next_on_stream(t-1)', 'next_BORE_GAS_VOL(t-1)', 'BORE_OIL_VOL(t-1)',
#        'ON_STREAM_HRS(t)', 'BORE_GAS_VOL(t)', 'BORE_WAT_VOL(t)',
#        'AVG_DOWNHOLE_TEMPERATURE(t)', 'AVG_CHOKE_SIZE_P(t)',
#        'F_4_BORE_WI_VOL(t)', 'F_5_BORE_WI_VOL(t)', 'next_choke_size(t)',
#        'next_on_stream(t)', 'next_BORE_GAS_VOL(t)', 'BORE_OIL_VOL(t)'],
#       dtype='object')

# %%
series_supervised.drop(['ON_STREAM_HRS(t)', 'BORE_GAS_VOL(t)',
       'BORE_WAT_VOL(t)', 'AVG_CHOKE_SIZE_P(t)', 
       'next_choke_size(t)', 'next_on_stream(t)',
        'next_BORE_GAS_VOL(t)', 
       'F_4_BORE_WI_VOL(t)',
       'F_5_BORE_WI_VOL(t)'
       ], axis=1, inplace= True)

# %%
# # split into train and test sets
series_supervised = series_supervised.values
#train_size = int(series_supervised.shape[0] * 0.8)
train_size = series_supervised.shape[0]  - 381
test_size = series_supervised.shape[0] - train_size
train, test = series_supervised[0:train_size], series_supervised[train_size:]
print(train.shape, test.shape)
# Out:
# (1524, 11) (381, 11)

# %%
# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
print(train_scaled.shape, test_scaled.shape)
# Out:
# (1524, 11) (381, 11)

# %%
# # reshape input to be 3D [samples, timesteps, features]
n_features = len(series.columns) 

train_X, train_y = train_scaled[:, 0:-steps_ahead], train_scaled[:, -steps_ahead:]
train_X = train_X.reshape(train_X.shape[0], timesteps, n_features)
test_X, test_y = test_scaled[:, 0:-steps_ahead], test_scaled[:, -steps_ahead:]
test_X = test_X.reshape(test_X.shape[0], timesteps, n_features )
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1524, 1, 10) (1524, 1) (381, 1, 10) (381, 1)

# %%
# Create a new directory in My Drive
directory = '/content/drive/My Drive/my_trained_models'
if not os.path.exists(directory):
    os.makedirs(directory)

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
np.random.seed(12345)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,
                                        inter_op_parallelism_threads=1)

from keras import backend as K
tf.random.set_seed(1234)

sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(),
                            config=session_conf)
K.set_session(sess)

# fit the model
neurons= [22]#22 12 

model = Sequential()
model.add(LSTM(neurons[0], activation="tanh",
               input_shape=(timesteps, n_features)))
model.add(Dense(steps_ahead)) # output layer
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4))
early_stopping = EarlyStopping(monitor='loss', patience=10, verbose=2,
                                restore_best_weights=True, mode='min')
# save the best weights if training is interrupted
mcp_save = ModelCheckpoint(os.path.join(directory, 'mdl_wts.hdf5'),
                            save_best_only=True,
                            monitor='val_loss', mode='min') 


# Set the initial and total number of epochs
initial_epoch = 1
n_epochs = 700
loss_tracking = list()

# Run the training loop
for epoch in range(initial_epoch , n_epochs+1):
    print(f'Epoch {epoch}/{n_epochs}')
    # Train the model for one epoch
    history = model.fit(train_X, train_y, callbacks=[early_stopping, mcp_save],
                    epochs=1, batch_size=2, validation_data=(test_X, test_y),
                     verbose=2,
                     shuffle=False)
    # to find for which epoch each loss belongs
    validation_loss= model.evaluate(test_X, test_y, verbose=0)
    loss_tracking.append(validation_loss)
    # Save the model every 10 epochs
    if epoch % 50 == 0:
        # Save the model  in HDF5 foramt with a filename that includes the epoch number
        #model.save(f'model_{epoch}Eps.h5')
        model.save(os.path.join(directory, f'model_{epoch}Eps.h5'))
# Out:
# Epoch 1/700
# 762/762 - 3s - loss: 0.0814 - val_loss: 0.0051 - 3s/epoch - 5ms/step
# Epoch 2/700
# 762/762 - 1s - loss: 0.0209 - val_loss: 0.0037 - 1s/epoch - 2ms/step
# Epoch 3/700
# 762/762 - 1s - loss: 0.0154 - val_loss: 0.0024 - 1s/epoch - 1ms/step
# Epoch 4/700
# 762/762 - 1s - loss: 0.0107 - val_loss: 0.0015 - 1s/epoch - 1ms/step
# Epoch 5/700
# 762/762 - 1s - loss: 0.0070 - val_loss: 0.0011 - 1s/epoch - 2ms/step
# Epoch 6/700
# 762/762 - 1s - loss: 0.0044 - val_loss: 9.0882e-04 - 1s/epoch - 2ms/step
# Epoch 7/700
# 762/762 - 1s - loss: 0.0029 - val_loss: 9.1575e-04 - 1s/epoch - 1ms/step
# Epoch 8/700
# 762/762 - 1s - loss: 0.0021 - val_loss: 9.3190e-04 - 980ms/epoch - 1ms/step
# Epoch 9/700
# 762/762 - 1s - loss: 0.0017 - val_loss: 9.1033e-04 - 1s/epoch - 2ms/step
# Epoch 10/700
# 762/762 - 1s - loss: 0.0015 - val_loss: 8.6538e-04 - 1s/epoch - 1ms/step
# Epoch 11/700
# 762/762 - 1s - loss: 0.0013 - val_loss: 8.1377e-04 - 1s/epoch - 1ms/step
# Epoch 12/700
# 762/762 - 1s - loss: 0.0011 - val_loss: 7.6060e-04 - 1s/epoch - 2ms/step
# Epoch 13/700
# 762/762 - 1s - loss: 0.0010 - val_loss: 7.0633e-04 - 1s/epoch - 2ms/step
# Epoch 14/700
# 762/762 - 1s - loss: 9.1400e-04 - val_loss: 6.5144e-04 - 1s/epoch - 1ms/step
# Epoch 15/700
# 762/762 - 1s - loss: 8.2824e-04 - val_loss: 5.9695e-04 - 1s/epoch - 2ms/step
# Epoch 16/700
# 762/762 - 1s - loss: 7.5156e-04 - val_loss: 5.4391e-04 - 1s/epoch - 2ms/step
# Epoch 17/700
# 762/762 - 1s - loss: 6.8209e-04 - val_loss: 4.9315e-04 - 1s/epoch - 2ms/step
# Epoch 18/700
# 762/762 - 1s - loss: 6.1873e-04 - val_loss: 4.4516e-04 - 1s/epoch - 2ms/step
# Epoch 19/700
# 762/762 - 1s - loss: 5.6079e-04 - val_loss: 4.0025e-04 - 1s/epoch - 2ms/step
# Epoch 20/700
# 762/762 - 1s - loss: 5.0782e-04 - val_loss: 3.5856e-04 - 1s/epoch - 1ms/step
# Epoch 21/700
# 762/762 - 1s - loss: 4.5954e-04 - val_loss: 3.2017e-04 - 1s/epoch - 2ms/step
# Epoch 22/700
# 762/762 - 1s - loss: 4.1574e-04 - val_loss: 2.8511e-04 - 1s/epoch - 1ms/step
# Epoch 23/700
# 762/762 - 1s - loss: 3.7625e-04 - val_loss: 2.5341e-04 - 1s/epoch - 2ms/step
# Epoch 24/700
# 762/762 - 1s - loss: 3.4091e-04 - val_loss: 2.2504e-04 - 1s/epoch - 2ms/step
# Epoch 25/700
# 762/762 - 1s - loss: 3.0953e-04 - val_loss: 1.9991e-04 - 1s/epoch - 2ms/step
# Epoch 26/700
# 762/762 - 2s - loss: 2.8190e-04 - val_loss: 1.7787e-04 - 2s/epoch - 2ms/step
# Epoch 27/700
# 762/762 - 1s - loss: 2.5776e-04 - val_loss: 1.5867e-04 - 1s/epoch - 2ms/step
# Epoch 28/700
# 762/762 - 1s - loss: 2.3683e-04 - val_loss: 1.4200e-04 - 1s/epoch - 2ms/step
# Epoch 29/700
# 762/762 - 1s - loss: 2.1877e-04 - val_loss: 1.2752e-04 - 1s/epoch - 2ms/step
# Epoch 30/700
# 762/762 - 1s - loss: 2.0325e-04 - val_loss: 1.1488e-04 - 1s/epoch - 2ms/step
# Epoch 31/700
# 762/762 - 1s - loss: 1.8993e-04 - val_loss: 1.0378e-04 - 1s/epoch - 2ms/step
# Epoch 32/700
# 762/762 - 1s - loss: 1.7852e-04 - val_loss: 9.3968e-05 - 1s/epoch - 1ms/step
# Epoch 33/700
# 762/762 - 1s - loss: 1.6871e-04 - val_loss: 8.5251e-05 - 1s/epoch - 2ms/step
# Epoch 34/700
# 762/762 - 1s - loss: 1.6027e-04 - val_loss: 7.7481e-05 - 1s/epoch - 1ms/step
# Epoch 35/700
# 762/762 - 1s - loss: 1.5298e-04 - val_loss: 7.0549e-05 - 1s/epoch - 2ms/step
# Epoch 36/700
# 762/762 - 1s - loss: 1.4666e-04 - val_loss: 6.4368e-05 - 1s/epoch - 2ms/step
# Epoch 37/700
# 762/762 - 1s - loss: 1.4115e-04 - val_loss: 5.8864e-05 - 1s/epoch - 1ms/step
# Epoch 38/700
# 762/762 - 1s - loss: 1.3634e-04 - val_loss: 5.3974e-05 - 1s/epoch - 2ms/step
# Epoch 39/700
# 762/762 - 1s - loss: 1.3212e-04 - val_loss: 4.9637e-05 - 1s/epoch - 1ms/step
# Epoch 40/700
# 762/762 - 1s - loss: 1.2840e-04 - val_loss: 4.5798e-05 - 1s/epoch - 1ms/step
# Epoch 41/700
# 762/762 - 1s - loss: 1.2512e-04 - val_loss: 4.2405e-05 - 1s/epoch - 1ms/step
# Epoch 42/700
# 762/762 - 1s - loss: 1.2220e-04 - val_loss: 3.9407e-05 - 1s/epoch - 2ms/step
# Epoch 43/700
# 762/762 - 1s - loss: 1.1961e-04 - val_loss: 3.6760e-05 - 1s/epoch - 2ms/step
# Epoch 44/700
# 762/762 - 1s - loss: 1.1730e-04 - val_loss: 3.4423e-05 - 1s/epoch - 1ms/step
# Epoch 45/700
# 762/762 - 1s - loss: 1.1523e-04 - val_loss: 3.2358e-05 - 1s/epoch - 1ms/step
# Epoch 46/700
# 762/762 - 1s - loss: 1.1337e-04 - val_loss: 3.0532e-05 - 1s/epoch - 1ms/step
# Epoch 47/700
# 762/762 - 1s - loss: 1.1169e-04 - val_loss: 2.8917e-05 - 1s/epoch - 2ms/step
# Epoch 48/700
# 762/762 - 1s - loss: 1.1018e-04 - val_loss: 2.7487e-05 - 1s/epoch - 2ms/step
# Epoch 49/700
# 762/762 - 1s - loss: 1.0880e-04 - val_loss: 2.6220e-05 - 1s/epoch - 2ms/step
# Epoch 50/700
# 762/762 - 1s - loss: 1.0756e-04 - val_loss: 2.5095e-05 - 1s/epoch - 1ms/step
# Epoch 51/700
# 762/762 - 1s - loss: 1.0642e-04 - val_loss: 2.4095e-05 - 1s/epoch - 1ms/step
# Epoch 52/700
# 762/762 - 1s - loss: 1.0538e-04 - val_loss: 2.3206e-05 - 1s/epoch - 2ms/step
# Epoch 53/700
# 762/762 - 1s - loss: 1.0443e-04 - val_loss: 2.2413e-05 - 1s/epoch - 1ms/step
# Epoch 54/700
# 762/762 - 1s - loss: 1.0355e-04 - val_loss: 2.1707e-05 - 1s/epoch - 2ms/step
# Epoch 55/700
# 762/762 - 1s - loss: 1.0274e-04 - val_loss: 2.1075e-05 - 1s/epoch - 2ms/step
# Epoch 56/700
# 762/762 - 1s - loss: 1.0199e-04 - val_loss: 2.0510e-05 - 1s/epoch - 1ms/step
# Epoch 57/700
# 762/762 - 1s - loss: 1.0130e-04 - val_loss: 2.0005e-05 - 1s/epoch - 2ms/step
# Epoch 58/700
# 762/762 - 1s - loss: 1.0065e-04 - val_loss: 1.9551e-05 - 1s/epoch - 2ms/step
# Epoch 59/700
# 762/762 - 1s - loss: 1.0005e-04 - val_loss: 1.9143e-05 - 1s/epoch - 2ms/step
# Epoch 60/700
# 762/762 - 1s - loss: 9.9491e-05 - val_loss: 1.8777e-05 - 1s/epoch - 1ms/step
# Epoch 61/700
# 762/762 - 1s - loss: 9.8966e-05 - val_loss: 1.8447e-05 - 1s/epoch - 2ms/step
# Epoch 62/700
# 762/762 - 1s - loss: 9.8473e-05 - val_loss: 1.8149e-05 - 1s/epoch - 2ms/step
# Epoch 63/700
# 762/762 - 1s - loss: 9.8010e-05 - val_loss: 1.7880e-05 - 1s/epoch - 2ms/step
# Epoch 64/700
# 762/762 - 1s - loss: 9.7573e-05 - val_loss: 1.7636e-05 - 1s/epoch - 2ms/step
# Epoch 65/700
# 762/762 - 1s - loss: 9.7162e-05 - val_loss: 1.7416e-05 - 1s/epoch - 1ms/step
# Epoch 66/700
# 762/762 - 1s - loss: 9.6773e-05 - val_loss: 1.7216e-05 - 1s/epoch - 2ms/step
# Epoch 67/700
# 762/762 - 1s - loss: 9.6405e-05 - val_loss: 1.7034e-05 - 1s/epoch - 2ms/step
# Epoch 68/700
# 762/762 - 1s - loss: 9.6056e-05 - val_loss: 1.6868e-05 - 1s/epoch - 2ms/step
# Epoch 69/700
# 762/762 - 1s - loss: 9.5725e-05 - val_loss: 1.6717e-05 - 1s/epoch - 1ms/step
# Epoch 70/700
# 762/762 - 1s - loss: 9.5409e-05 - val_loss: 1.6580e-05 - 1s/epoch - 2ms/step
# Epoch 71/700
# 762/762 - 1s - loss: 9.5109e-05 - val_loss: 1.6454e-05 - 1s/epoch - 1ms/step
# Epoch 72/700
# 762/762 - 1s - loss: 9.4822e-05 - val_loss: 1.6338e-05 - 1s/epoch - 2ms/step
# Epoch 73/700
# 762/762 - 1s - loss: 9.4548e-05 - val_loss: 1.6232e-05 - 1s/epoch - 2ms/step
# Epoch 74/700
# 762/762 - 1s - loss: 9.4286e-05 - val_loss: 1.6134e-05 - 1s/epoch - 2ms/step
# Epoch 75/700
# 762/762 - 1s - loss: 9.4035e-05 - val_loss: 1.6045e-05 - 1s/epoch - 1ms/step
# Epoch 76/700
# 762/762 - 1s - loss: 9.3794e-05 - val_loss: 1.5962e-05 - 1s/epoch - 2ms/step
# Epoch 77/700
# 762/762 - 1s - loss: 9.3563e-05 - val_loss: 1.5885e-05 - 1s/epoch - 2ms/step
# Epoch 78/700
# 762/762 - 1s - loss: 9.3341e-05 - val_loss: 1.5814e-05 - 1s/epoch - 2ms/step
# Epoch 79/700
# 762/762 - 1s - loss: 9.3127e-05 - val_loss: 1.5748e-05 - 1s/epoch - 1ms/step
# Epoch 80/700
# 762/762 - 1s - loss: 9.2920e-05 - val_loss: 1.5687e-05 - 1s/epoch - 1ms/step
# Epoch 81/700
# 762/762 - 1s - loss: 9.2721e-05 - val_loss: 1.5629e-05 - 1s/epoch - 2ms/step
# Epoch 82/700
# 762/762 - 1s - loss: 9.2528e-05 - val_loss: 1.5576e-05 - 1s/epoch - 2ms/step
# Epoch 83/700
# 762/762 - 1s - loss: 9.2342e-05 - val_loss: 1.5526e-05 - 1s/epoch - 2ms/step
# Epoch 84/700
# 762/762 - 1s - loss: 9.2161e-05 - val_loss: 1.5479e-05 - 1s/epoch - 1ms/step
# Epoch 85/700
# 762/762 - 1s - loss: 9.1986e-05 - val_loss: 1.5434e-05 - 1s/epoch - 2ms/step
# Epoch 86/700
# 762/762 - 1s - loss: 9.1816e-05 - val_loss: 1.5393e-05 - 1s/epoch - 1ms/step
# Epoch 87/700
# 762/762 - 1s - loss: 9.1651e-05 - val_loss: 1.5353e-05 - 1s/epoch - 2ms/step
# Epoch 88/700
# 762/762 - 1s - loss: 9.1490e-05 - val_loss: 1.5316e-05 - 1s/epoch - 1ms/step
# Epoch 89/700
# 762/762 - 1s - loss: 9.1334e-05 - val_loss: 1.5281e-05 - 1s/epoch - 2ms/step
# Epoch 90/700
# 762/762 - 1s - loss: 9.1182e-05 - val_loss: 1.5247e-05 - 1s/epoch - 1ms/step
# Epoch 91/700
# 762/762 - 1s - loss: 9.1033e-05 - val_loss: 1.5215e-05 - 1s/epoch - 1ms/step
# Epoch 92/700
# 762/762 - 1s - loss: 9.0888e-05 - val_loss: 1.5184e-05 - 1s/epoch - 2ms/step
# Epoch 93/700
# 762/762 - 1s - loss: 9.0747e-05 - val_loss: 1.5155e-05 - 1s/epoch - 2ms/step
# Epoch 94/700
# 762/762 - 1s - loss: 9.0608e-05 - val_loss: 1.5127e-05 - 1s/epoch - 2ms/step
# Epoch 95/700
# 762/762 - 1s - loss: 9.0473e-05 - val_loss: 1.5099e-05 - 1s/epoch - 2ms/step
# Epoch 96/700
# 762/762 - 1s - loss: 9.0340e-05 - val_loss: 1.5073e-05 - 1s/epoch - 2ms/step
# Epoch 97/700
# 762/762 - 1s - loss: 9.0210e-05 - val_loss: 1.5048e-05 - 1s/epoch - 2ms/step
# Epoch 98/700
# 762/762 - 1s - loss: 9.0082e-05 - val_loss: 1.5024e-05 - 1s/epoch - 1ms/step
# Epoch 99/700
# 762/762 - 1s - loss: 8.9957e-05 - val_loss: 1.5001e-05 - 1s/epoch - 1ms/step
# Epoch 100/700
# 762/762 - 1s - loss: 8.9834e-05 - val_loss: 1.4978e-05 - 1s/epoch - 1ms/step
# Epoch 101/700
# 762/762 - 1s - loss: 8.9714e-05 - val_loss: 1.4956e-05 - 1s/epoch - 1ms/step
# Epoch 102/700
# 762/762 - 1s - loss: 8.9595e-05 - val_loss: 1.4935e-05 - 1s/epoch - 2ms/step
# Epoch 103/700
# 762/762 - 1s - loss: 8.9478e-05 - val_loss: 1.4914e-05 - 1s/epoch - 1ms/step
# Epoch 104/700
# 762/762 - 1s - loss: 8.9363e-05 - val_loss: 1.4894e-05 - 1s/epoch - 2ms/step
# Epoch 105/700
# 762/762 - 1s - loss: 8.9250e-05 - val_loss: 1.4874e-05 - 1s/epoch - 1ms/step
# Epoch 106/700
# 762/762 - 1s - loss: 8.9139e-05 - val_loss: 1.4854e-05 - 1s/epoch - 2ms/step
# Epoch 107/700
# 762/762 - 1s - loss: 8.9029e-05 - val_loss: 1.4836e-05 - 1s/epoch - 2ms/step
# Epoch 108/700
# 762/762 - 1s - loss: 8.8921e-05 - val_loss: 1.4817e-05 - 1s/epoch - 1ms/step
# Epoch 109/700
# 762/762 - 1s - loss: 8.8814e-05 - val_loss: 1.4799e-05 - 1s/epoch - 1ms/step
# Epoch 110/700
# 762/762 - 1s - loss: 8.8708e-05 - val_loss: 1.4781e-05 - 1s/epoch - 1ms/step
# Epoch 111/700
# 762/762 - 1s - loss: 8.8604e-05 - val_loss: 1.4764e-05 - 1s/epoch - 2ms/step
# Epoch 112/700
# 762/762 - 1s - loss: 8.8501e-05 - val_loss: 1.4747e-05 - 1s/epoch - 1ms/step
# Epoch 113/700
# 762/762 - 1s - loss: 8.8400e-05 - val_loss: 1.4730e-05 - 1s/epoch - 2ms/step
# Epoch 114/700
# 762/762 - 1s - loss: 8.8299e-05 - val_loss: 1.4714e-05 - 1s/epoch - 1ms/step
# Epoch 115/700
# 762/762 - 1s - loss: 8.8200e-05 - val_loss: 1.4698e-05 - 1s/epoch - 2ms/step
# Epoch 116/700
# 762/762 - 1s - loss: 8.8102e-05 - val_loss: 1.4682e-05 - 1s/epoch - 1ms/step
# Epoch 117/700
# 762/762 - 1s - loss: 8.8005e-05 - val_loss: 1.4666e-05 - 1s/epoch - 2ms/step
# Epoch 118/700
# 762/762 - 1s - loss: 8.7909e-05 - val_loss: 1.4651e-05 - 1s/epoch - 2ms/step
# Epoch 119/700
# 762/762 - 1s - loss: 8.7813e-05 - val_loss: 1.4636e-05 - 1s/epoch - 1ms/step
# Epoch 120/700
# 762/762 - 1s - loss: 8.7719e-05 - val_loss: 1.4621e-05 - 1s/epoch - 2ms/step
# Epoch 121/700
# 762/762 - 1s - loss: 8.7626e-05 - val_loss: 1.4606e-05 - 1s/epoch - 2ms/step
# Epoch 122/700
# 762/762 - 1s - loss: 8.7534e-05 - val_loss: 1.4592e-05 - 1s/epoch - 2ms/step
# Epoch 123/700
# 762/762 - 1s - loss: 8.7442e-05 - val_loss: 1.4578e-05 - 1s/epoch - 2ms/step
# Epoch 124/700
# 762/762 - 1s - loss: 8.7351e-05 - val_loss: 1.4564e-05 - 1s/epoch - 1ms/step
# Epoch 125/700
# 762/762 - 1s - loss: 8.7262e-05 - val_loss: 1.4550e-05 - 1s/epoch - 1ms/step
# Epoch 126/700
# 762/762 - 1s - loss: 8.7173e-05 - val_loss: 1.4537e-05 - 1s/epoch - 2ms/step
# Epoch 127/700
# 762/762 - 1s - loss: 8.7084e-05 - val_loss: 1.4524e-05 - 1s/epoch - 2ms/step
# Epoch 128/700
# 762/762 - 2s - loss: 8.6997e-05 - val_loss: 1.4510e-05 - 2s/epoch - 2ms/step
# Epoch 129/700
# 762/762 - 2s - loss: 8.6910e-05 - val_loss: 1.4497e-05 - 2s/epoch - 2ms/step
# Epoch 130/700
# 762/762 - 1s - loss: 8.6823e-05 - val_loss: 1.4485e-05 - 1s/epoch - 2ms/step
# Epoch 131/700
# 762/762 - 1s - loss: 8.6738e-05 - val_loss: 1.4472e-05 - 1s/epoch - 1ms/step
# Epoch 132/700
# 762/762 - 1s - loss: 8.6653e-05 - val_loss: 1.4460e-05 - 1s/epoch - 1ms/step
# Epoch 133/700
# 762/762 - 1s - loss: 8.6569e-05 - val_loss: 1.4448e-05 - 1s/epoch - 2ms/step
# Epoch 134/700
# 762/762 - 1s - loss: 8.6485e-05 - val_loss: 1.4436e-05 - 1s/epoch - 2ms/step
# Epoch 135/700
# 762/762 - 1s - loss: 8.6402e-05 - val_loss: 1.4424e-05 - 1s/epoch - 1ms/step
# Epoch 136/700
# 762/762 - 1s - loss: 8.6320e-05 - val_loss: 1.4413e-05 - 1s/epoch - 2ms/step
# Epoch 137/700
# 762/762 - 1s - loss: 8.6238e-05 - val_loss: 1.4402e-05 - 1s/epoch - 1ms/step
# Epoch 138/700
# 762/762 - 1s - loss: 8.6157e-05 - val_loss: 1.4391e-05 - 1s/epoch - 1ms/step
# Epoch 139/700
# 762/762 - 1s - loss: 8.6076e-05 - val_loss: 1.4380e-05 - 1s/epoch - 2ms/step
# Epoch 140/700
# 762/762 - 1s - loss: 8.5996e-05 - val_loss: 1.4369e-05 - 1s/epoch - 2ms/step
# Epoch 141/700
# 762/762 - 1s - loss: 8.5916e-05 - val_loss: 1.4359e-05 - 1s/epoch - 2ms/step
# Epoch 142/700
# 762/762 - 1s - loss: 8.5837e-05 - val_loss: 1.4348e-05 - 1s/epoch - 1ms/step
# Epoch 143/700
# 762/762 - 1s - loss: 8.5758e-05 - val_loss: 1.4338e-05 - 1s/epoch - 1ms/step
# Epoch 144/700
# 762/762 - 1s - loss: 8.5680e-05 - val_loss: 1.4329e-05 - 1s/epoch - 2ms/step
# Epoch 145/700
# 762/762 - 1s - loss: 8.5602e-05 - val_loss: 1.4319e-05 - 1s/epoch - 2ms/step
# Epoch 146/700
# 762/762 - 1s - loss: 8.5525e-05 - val_loss: 1.4310e-05 - 1s/epoch - 2ms/step
# Epoch 147/700
# 762/762 - 1s - loss: 8.5449e-05 - val_loss: 1.4301e-05 - 1s/epoch - 1ms/step
# Epoch 148/700
# 762/762 - 1s - loss: 8.5372e-05 - val_loss: 1.4292e-05 - 1s/epoch - 2ms/step
# Epoch 149/700
# 762/762 - 1s - loss: 8.5297e-05 - val_loss: 1.4283e-05 - 1s/epoch - 1ms/step
# Epoch 150/700
# 762/762 - 1s - loss: 8.5221e-05 - val_loss: 1.4274e-05 - 1s/epoch - 1ms/step
# Epoch 151/700
# 762/762 - 1s - loss: 8.5146e-05 - val_loss: 1.4266e-05 - 1s/epoch - 2ms/step
# Epoch 152/700
# 762/762 - 1s - loss: 8.5072e-05 - val_loss: 1.4258e-05 - 1s/epoch - 2ms/step
# Epoch 153/700
# 762/762 - 1s - loss: 8.4998e-05 - val_loss: 1.4250e-05 - 1s/epoch - 1ms/step
# Epoch 154/700
# 762/762 - 1s - loss: 8.4924e-05 - val_loss: 1.4243e-05 - 1s/epoch - 1ms/step
# Epoch 155/700
# 762/762 - 1s - loss: 8.4851e-05 - val_loss: 1.4235e-05 - 1s/epoch - 2ms/step
# Epoch 156/700
# 762/762 - 1s - loss: 8.4779e-05 - val_loss: 1.4228e-05 - 1s/epoch - 1ms/step
# Epoch 157/700
# 762/762 - 1s - loss: 8.4706e-05 - val_loss: 1.4221e-05 - 1s/epoch - 1ms/step
# Epoch 158/700
# 762/762 - 1s - loss: 8.4634e-05 - val_loss: 1.4215e-05 - 1s/epoch - 1ms/step
# Epoch 159/700
# 762/762 - 1s - loss: 8.4562e-05 - val_loss: 1.4208e-05 - 1s/epoch - 2ms/step
# Epoch 160/700
# 762/762 - 1s - loss: 8.4491e-05 - val_loss: 1.4202e-05 - 1s/epoch - 2ms/step
# Epoch 161/700
# 762/762 - 1s - loss: 8.4420e-05 - val_loss: 1.4196e-05 - 1s/epoch - 1ms/step
# Epoch 162/700
# 762/762 - 1s - loss: 8.4350e-05 - val_loss: 1.4190e-05 - 1s/epoch - 2ms/step
# Epoch 163/700
# 762/762 - 1s - loss: 8.4280e-05 - val_loss: 1.4185e-05 - 1s/epoch - 1ms/step
# Epoch 164/700
# 762/762 - 1s - loss: 8.4210e-05 - val_loss: 1.4180e-05 - 1s/epoch - 1ms/step
# Epoch 165/700
# 762/762 - 1s - loss: 8.4141e-05 - val_loss: 1.4175e-05 - 1s/epoch - 2ms/step
# Epoch 166/700
# 762/762 - 1s - loss: 8.4072e-05 - val_loss: 1.4170e-05 - 1s/epoch - 2ms/step
# Epoch 167/700
# 762/762 - 1s - loss: 8.4003e-05 - val_loss: 1.4165e-05 - 1s/epoch - 2ms/step
# Epoch 168/700
# 762/762 - 1s - loss: 8.3935e-05 - val_loss: 1.4161e-05 - 1s/epoch - 1ms/step
# Epoch 169/700
# 762/762 - 1s - loss: 8.3867e-05 - val_loss: 1.4157e-05 - 1s/epoch - 1ms/step
# Epoch 170/700
# 762/762 - 1s - loss: 8.3799e-05 - val_loss: 1.4154e-05 - 1s/epoch - 1ms/step
# Epoch 171/700
# 762/762 - 1s - loss: 8.3732e-05 - val_loss: 1.4150e-05 - 1s/epoch - 2ms/step
# Epoch 172/700
# 762/762 - 1s - loss: 8.3665e-05 - val_loss: 1.4147e-05 - 1s/epoch - 2ms/step
# Epoch 173/700
# 762/762 - 1s - loss: 8.3598e-05 - val_loss: 1.4144e-05 - 1s/epoch - 1ms/step
# Epoch 174/700
# 762/762 - 1s - loss: 8.3532e-05 - val_loss: 1.4141e-05 - 1s/epoch - 2ms/step
# Epoch 175/700
# 762/762 - 1s - loss: 8.3466e-05 - val_loss: 1.4139e-05 - 1s/epoch - 1ms/step
# Epoch 176/700
# 762/762 - 1s - loss: 8.3400e-05 - val_loss: 1.4137e-05 - 1s/epoch - 1ms/step
# Epoch 177/700
# 762/762 - 1s - loss: 8.3335e-05 - val_loss: 1.4135e-05 - 1s/epoch - 2ms/step
# Epoch 178/700
# 762/762 - 1s - loss: 8.3270e-05 - val_loss: 1.4133e-05 - 1s/epoch - 2ms/step
# Epoch 179/700
# 762/762 - 1s - loss: 8.3205e-05 - val_loss: 1.4131e-05 - 1s/epoch - 2ms/step
# Epoch 180/700
# 762/762 - 1s - loss: 8.3141e-05 - val_loss: 1.4130e-05 - 1s/epoch - 2ms/step
# Epoch 181/700
# 762/762 - 1s - loss: 8.3076e-05 - val_loss: 1.4130e-05 - 1s/epoch - 1ms/step
# Epoch 182/700
# 762/762 - 1s - loss: 8.3012e-05 - val_loss: 1.4129e-05 - 1s/epoch - 2ms/step
# Epoch 183/700
# 762/762 - 1s - loss: 8.2949e-05 - val_loss: 1.4129e-05 - 1s/epoch - 1ms/step
# Epoch 184/700
# 762/762 - 1s - loss: 8.2886e-05 - val_loss: 1.4128e-05 - 1s/epoch - 1ms/step
# Epoch 185/700
# 762/762 - 1s - loss: 8.2823e-05 - val_loss: 1.4129e-05 - 1s/epoch - 1ms/step
# Epoch 186/700
# 762/762 - 1s - loss: 8.2760e-05 - val_loss: 1.4129e-05 - 1s/epoch - 2ms/step
# Epoch 187/700
# 762/762 - 1s - loss: 8.2698e-05 - val_loss: 1.4130e-05 - 1s/epoch - 1ms/step
# Epoch 188/700
# 762/762 - 1s - loss: 8.2635e-05 - val_loss: 1.4131e-05 - 1s/epoch - 2ms/step
# Epoch 189/700
# 762/762 - 1s - loss: 8.2574e-05 - val_loss: 1.4132e-05 - 1s/epoch - 1ms/step
# Epoch 190/700
# 762/762 - 1s - loss: 8.2512e-05 - val_loss: 1.4134e-05 - 1s/epoch - 2ms/step
# Epoch 191/700
# 762/762 - 1s - loss: 8.2451e-05 - val_loss: 1.4135e-05 - 1s/epoch - 1ms/step
# Epoch 192/700
# 762/762 - 1s - loss: 8.2390e-05 - val_loss: 1.4137e-05 - 1s/epoch - 1ms/step
# Epoch 193/700
# 762/762 - 1s - loss: 8.2329e-05 - val_loss: 1.4140e-05 - 1s/epoch - 1ms/step
# Epoch 194/700
# 762/762 - 1s - loss: 8.2268e-05 - val_loss: 1.4142e-05 - 1s/epoch - 2ms/step
# Epoch 195/700
# 762/762 - 1s - loss: 8.2208e-05 - val_loss: 1.4145e-05 - 1s/epoch - 2ms/step
# Epoch 196/700
# 762/762 - 1s - loss: 8.2148e-05 - val_loss: 1.4148e-05 - 1s/epoch - 2ms/step
# Epoch 197/700
# 762/762 - 1s - loss: 8.2088e-05 - val_loss: 1.4152e-05 - 1s/epoch - 2ms/step
# Epoch 198/700
# 762/762 - 1s - loss: 8.2029e-05 - val_loss: 1.4155e-05 - 1s/epoch - 1ms/step
# Epoch 199/700
# 762/762 - 1s - loss: 8.1970e-05 - val_loss: 1.4159e-05 - 1s/epoch - 1ms/step
# Epoch 200/700
# 762/762 - 1s - loss: 8.1911e-05 - val_loss: 1.4164e-05 - 992ms/epoch - 1ms/step
# Epoch 201/700
# 762/762 - 1s - loss: 8.1852e-05 - val_loss: 1.4168e-05 - 1s/epoch - 2ms/step
# Epoch 202/700
# 762/762 - 1s - loss: 8.1794e-05 - val_loss: 1.4173e-05 - 1s/epoch - 2ms/step
# Epoch 203/700
# 762/762 - 1s - loss: 8.1736e-05 - val_loss: 1.4178e-05 - 1s/epoch - 2ms/step
# Epoch 204/700
# 762/762 - 1s - loss: 8.1678e-05 - val_loss: 1.4183e-05 - 1s/epoch - 2ms/step
# Epoch 205/700
# 762/762 - 1s - loss: 8.1620e-05 - val_loss: 1.4189e-05 - 1s/epoch - 2ms/step
# Epoch 206/700
# 762/762 - 1s - loss: 8.1563e-05 - val_loss: 1.4195e-05 - 1s/epoch - 1ms/step
# Epoch 207/700
# 762/762 - 1s - loss: 8.1505e-05 - val_loss: 1.4201e-05 - 1s/epoch - 1ms/step
# Epoch 208/700
# 762/762 - 1s - loss: 8.1448e-05 - val_loss: 1.4207e-05 - 1s/epoch - 2ms/step
# Epoch 209/700
# 762/762 - 1s - loss: 8.1392e-05 - val_loss: 1.4214e-05 - 1s/epoch - 2ms/step
# Epoch 210/700
# 762/762 - 1s - loss: 8.1335e-05 - val_loss: 1.4221e-05 - 1s/epoch - 2ms/step
# Epoch 211/700
# 762/762 - 1s - loss: 8.1279e-05 - val_loss: 1.4228e-05 - 1s/epoch - 1ms/step
# Epoch 212/700
# 762/762 - 1s - loss: 8.1223e-05 - val_loss: 1.4235e-05 - 1s/epoch - 1ms/step
# Epoch 213/700
# 762/762 - 1s - loss: 8.1167e-05 - val_loss: 1.4243e-05 - 1s/epoch - 2ms/step
# Epoch 214/700
# 762/762 - 1s - loss: 8.1112e-05 - val_loss: 1.4251e-05 - 1s/epoch - 2ms/step
# Epoch 215/700
# 762/762 - 1s - loss: 8.1056e-05 - val_loss: 1.4259e-05 - 992ms/epoch - 1ms/step
# Epoch 216/700
# 762/762 - 1s - loss: 8.1001e-05 - val_loss: 1.4268e-05 - 1s/epoch - 2ms/step
# Epoch 217/700
# 762/762 - 1s - loss: 8.0946e-05 - val_loss: 1.4277e-05 - 1s/epoch - 2ms/step
# Epoch 218/700
# 762/762 - 1s - loss: 8.0892e-05 - val_loss: 1.4286e-05 - 1s/epoch - 1ms/step
# Epoch 219/700
# 762/762 - 1s - loss: 8.0837e-05 - val_loss: 1.4295e-05 - 1s/epoch - 2ms/step
# Epoch 220/700
# 762/762 - 1s - loss: 8.0783e-05 - val_loss: 1.4305e-05 - 1s/epoch - 2ms/step
# Epoch 221/700
# 762/762 - 1s - loss: 8.0729e-05 - val_loss: 1.4314e-05 - 1s/epoch - 2ms/step
# Epoch 222/700
# 762/762 - 1s - loss: 8.0676e-05 - val_loss: 1.4324e-05 - 1s/epoch - 2ms/step
# Epoch 223/700
# 762/762 - 1s - loss: 8.0622e-05 - val_loss: 1.4335e-05 - 1s/epoch - 1ms/step
# Epoch 224/700
# 762/762 - 1s - loss: 8.0569e-05 - val_loss: 1.4346e-05 - 1s/epoch - 1ms/step
# Epoch 225/700
# 762/762 - 1s - loss: 8.0516e-05 - val_loss: 1.4357e-05 - 1s/epoch - 1ms/step
# Epoch 226/700
# 762/762 - 1s - loss: 8.0463e-05 - val_loss: 1.4368e-05 - 1s/epoch - 2ms/step
# Epoch 227/700
# 762/762 - 1s - loss: 8.0410e-05 - val_loss: 1.4379e-05 - 1s/epoch - 1ms/step
# Epoch 228/700
# 762/762 - 1s - loss: 8.0358e-05 - val_loss: 1.4391e-05 - 1s/epoch - 2ms/step
# Epoch 229/700
# 762/762 - 1s - loss: 8.0305e-05 - val_loss: 1.4403e-05 - 1s/epoch - 1ms/step
# Epoch 230/700
# 762/762 - 1s - loss: 8.0253e-05 - val_loss: 1.4415e-05 - 1s/epoch - 1ms/step
# Epoch 231/700
# 762/762 - 1s - loss: 8.0202e-05 - val_loss: 1.4427e-05 - 1s/epoch - 1ms/step
# Epoch 232/700
# 762/762 - 1s - loss: 8.0150e-05 - val_loss: 1.4440e-05 - 1s/epoch - 1ms/step
# Epoch 233/700
# 762/762 - 1s - loss: 8.0099e-05 - val_loss: 1.4453e-05 - 1s/epoch - 1ms/step
# Epoch 234/700
# 762/762 - 1s - loss: 8.0047e-05 - val_loss: 1.4466e-05 - 1s/epoch - 1ms/step
# Epoch 235/700
# 762/762 - 1s - loss: 7.9996e-05 - val_loss: 1.4480e-05 - 1s/epoch - 2ms/step
# Epoch 236/700
# 762/762 - 1s - loss: 7.9946e-05 - val_loss: 1.4493e-05 - 1s/epoch - 1ms/step
# Epoch 237/700
# 762/762 - 1s - loss: 7.9895e-05 - val_loss: 1.4507e-05 - 1s/epoch - 2ms/step
# Epoch 238/700
# 762/762 - 1s - loss: 7.9845e-05 - val_loss: 1.4522e-05 - 1s/epoch - 2ms/step
# Epoch 239/700
# 762/762 - 1s - loss: 7.9795e-05 - val_loss: 1.4536e-05 - 1s/epoch - 2ms/step
# Epoch 240/700
# 762/762 - 1s - loss: 7.9745e-05 - val_loss: 1.4551e-05 - 1s/epoch - 2ms/step
# Epoch 241/700
# 762/762 - 1s - loss: 7.9695e-05 - val_loss: 1.4566e-05 - 1s/epoch - 1ms/step
# Epoch 242/700
# 762/762 - 1s - loss: 7.9645e-05 - val_loss: 1.4581e-05 - 1s/epoch - 2ms/step
# Epoch 243/700
# 762/762 - 1s - loss: 7.9596e-05 - val_loss: 1.4596e-05 - 1s/epoch - 1ms/step
# Epoch 244/700
# 762/762 - 1s - loss: 7.9547e-05 - val_loss: 1.4612e-05 - 1s/epoch - 2ms/step
# Epoch 245/700
# 762/762 - 1s - loss: 7.9498e-05 - val_loss: 1.4628e-05 - 1s/epoch - 2ms/step
# Epoch 246/700
# 762/762 - 1s - loss: 7.9449e-05 - val_loss: 1.4644e-05 - 1s/epoch - 1ms/step
# Epoch 247/700
# 762/762 - 1s - loss: 7.9400e-05 - val_loss: 1.4661e-05 - 1s/epoch - 2ms/step
# Epoch 248/700
# 762/762 - 1s - loss: 7.9352e-05 - val_loss: 1.4677e-05 - 1s/epoch - 1ms/step
# Epoch 249/700
# 762/762 - 1s - loss: 7.9303e-05 - val_loss: 1.4694e-05 - 1s/epoch - 2ms/step
# Epoch 250/700
# 762/762 - 1s - loss: 7.9255e-05 - val_loss: 1.4711e-05 - 1s/epoch - 1ms/step
# Epoch 251/700
# 762/762 - 1s - loss: 7.9208e-05 - val_loss: 1.4729e-05 - 1s/epoch - 1ms/step
# Epoch 252/700
# 762/762 - 1s - loss: 7.9160e-05 - val_loss: 1.4747e-05 - 1s/epoch - 2ms/step
# Epoch 253/700
# 762/762 - 1s - loss: 7.9112e-05 - val_loss: 1.4764e-05 - 1s/epoch - 2ms/step
# Epoch 254/700
# 762/762 - 1s - loss: 7.9065e-05 - val_loss: 1.4782e-05 - 1s/epoch - 2ms/step
# Epoch 255/700
# 762/762 - 1s - loss: 7.9018e-05 - val_loss: 1.4801e-05 - 1s/epoch - 1ms/step
# Epoch 256/700
# 762/762 - 1s - loss: 7.8971e-05 - val_loss: 1.4819e-05 - 1s/epoch - 1ms/step
# Epoch 257/700
# 762/762 - 1s - loss: 7.8924e-05 - val_loss: 1.4838e-05 - 1s/epoch - 2ms/step
# Epoch 258/700
# 762/762 - 1s - loss: 7.8878e-05 - val_loss: 1.4857e-05 - 1s/epoch - 2ms/step
# Epoch 259/700
# 762/762 - 1s - loss: 7.8831e-05 - val_loss: 1.4876e-05 - 1s/epoch - 1ms/step
# Epoch 260/700
# 762/762 - 1s - loss: 7.8785e-05 - val_loss: 1.4896e-05 - 1s/epoch - 2ms/step
# Epoch 261/700
# 762/762 - 1s - loss: 7.8739e-05 - val_loss: 1.4915e-05 - 1s/epoch - 1ms/step
# Epoch 262/700
# 762/762 - 1s - loss: 7.8693e-05 - val_loss: 1.4935e-05 - 1s/epoch - 1ms/step
# Epoch 263/700
# 762/762 - 1s - loss: 7.8647e-05 - val_loss: 1.4955e-05 - 1s/epoch - 2ms/step
# Epoch 264/700
# 762/762 - 1s - loss: 7.8602e-05 - val_loss: 1.4976e-05 - 1s/epoch - 2ms/step
# Epoch 265/700
# 762/762 - 1s - loss: 7.8557e-05 - val_loss: 1.4996e-05 - 1s/epoch - 1ms/step
# Epoch 266/700
# 762/762 - 1s - loss: 7.8511e-05 - val_loss: 1.5017e-05 - 1s/epoch - 2ms/step
# Epoch 267/700
# 762/762 - 1s - loss: 7.8467e-05 - val_loss: 1.5038e-05 - 1s/epoch - 2ms/step
# Epoch 268/700
# 762/762 - 1s - loss: 7.8422e-05 - val_loss: 1.5060e-05 - 1s/epoch - 1ms/step
# Epoch 269/700
# 762/762 - 1s - loss: 7.8377e-05 - val_loss: 1.5081e-05 - 1s/epoch - 2ms/step
# Epoch 270/700
# 762/762 - 1s - loss: 7.8333e-05 - val_loss: 1.5102e-05 - 1s/epoch - 1ms/step
# Epoch 271/700
# 762/762 - 1s - loss: 7.8288e-05 - val_loss: 1.5124e-05 - 1s/epoch - 2ms/step
# Epoch 272/700
# 762/762 - 1s - loss: 7.8244e-05 - val_loss: 1.5146e-05 - 1s/epoch - 2ms/step
# Epoch 273/700
# 762/762 - 1s - loss: 7.8200e-05 - val_loss: 1.5169e-05 - 1s/epoch - 1ms/step
# Epoch 274/700
# 762/762 - 1s - loss: 7.8156e-05 - val_loss: 1.5191e-05 - 1s/epoch - 1ms/step
# Epoch 275/700
# 762/762 - 1s - loss: 7.8113e-05 - val_loss: 1.5214e-05 - 1s/epoch - 1ms/step
# Epoch 276/700
# 762/762 - 1s - loss: 7.8069e-05 - val_loss: 1.5237e-05 - 1s/epoch - 1ms/step
# Epoch 277/700
# 762/762 - 1s - loss: 7.8026e-05 - val_loss: 1.5260e-05 - 1s/epoch - 1ms/step
# Epoch 278/700
# 762/762 - 1s - loss: 7.7983e-05 - val_loss: 1.5283e-05 - 1s/epoch - 1ms/step
# Epoch 279/700
# 762/762 - 1s - loss: 7.7940e-05 - val_loss: 1.5307e-05 - 1s/epoch - 2ms/step
# Epoch 280/700
# 762/762 - 1s - loss: 7.7897e-05 - val_loss: 1.5330e-05 - 1s/epoch - 2ms/step
# Epoch 281/700
# 762/762 - 1s - loss: 7.7854e-05 - val_loss: 1.5354e-05 - 1s/epoch - 2ms/step
# Epoch 282/700
# 762/762 - 1s - loss: 7.7812e-05 - val_loss: 1.5378e-05 - 1s/epoch - 1ms/step
# Epoch 283/700
# 762/762 - 1s - loss: 7.7770e-05 - val_loss: 1.5403e-05 - 1s/epoch - 1ms/step
# Epoch 284/700
# 762/762 - 1s - loss: 7.7727e-05 - val_loss: 1.5427e-05 - 1s/epoch - 1ms/step
# Epoch 285/700
# 762/762 - 1s - loss: 7.7685e-05 - val_loss: 1.5452e-05 - 1s/epoch - 2ms/step
# Epoch 286/700
# 762/762 - 1s - loss: 7.7644e-05 - val_loss: 1.5477e-05 - 1s/epoch - 2ms/step
# Epoch 287/700
# 762/762 - 1s - loss: 7.7602e-05 - val_loss: 1.5502e-05 - 1s/epoch - 1ms/step
# Epoch 288/700
# 762/762 - 1s - loss: 7.7560e-05 - val_loss: 1.5527e-05 - 1s/epoch - 2ms/step
# Epoch 289/700
# 762/762 - 1s - loss: 7.7519e-05 - val_loss: 1.5552e-05 - 1s/epoch - 2ms/step
# Epoch 290/700
# 762/762 - 1s - loss: 7.7478e-05 - val_loss: 1.5578e-05 - 1s/epoch - 1ms/step
# Epoch 291/700
# 762/762 - 1s - loss: 7.7437e-05 - val_loss: 1.5604e-05 - 1s/epoch - 1ms/step
# Epoch 292/700
# 762/762 - 1s - loss: 7.7396e-05 - val_loss: 1.5630e-05 - 1s/epoch - 1ms/step
# Epoch 293/700
# 762/762 - 1s - loss: 7.7355e-05 - val_loss: 1.5656e-05 - 1s/epoch - 1ms/step
# Epoch 294/700
# 762/762 - 1s - loss: 7.7315e-05 - val_loss: 1.5682e-05 - 1s/epoch - 2ms/step
# Epoch 295/700
# 762/762 - 1s - loss: 7.7274e-05 - val_loss: 1.5709e-05 - 1s/epoch - 2ms/step
# Epoch 296/700
# 762/762 - 1s - loss: 7.7234e-05 - val_loss: 1.5736e-05 - 1s/epoch - 1ms/step
# Epoch 297/700
# 762/762 - 1s - loss: 7.7194e-05 - val_loss: 1.5763e-05 - 1s/epoch - 2ms/step
# Epoch 298/700
# 762/762 - 1s - loss: 7.7154e-05 - val_loss: 1.5790e-05 - 1s/epoch - 2ms/step
# Epoch 299/700
# 762/762 - 1s - loss: 7.7114e-05 - val_loss: 1.5817e-05 - 1s/epoch - 1ms/step
# Epoch 300/700
# 762/762 - 1s - loss: 7.7074e-05 - val_loss: 1.5844e-05 - 1s/epoch - 1ms/step
# Epoch 301/700
# 762/762 - 1s - loss: 7.7035e-05 - val_loss: 1.5872e-05 - 1s/epoch - 2ms/step
# Epoch 302/700
# 762/762 - 1s - loss: 7.6995e-05 - val_loss: 1.5900e-05 - 1s/epoch - 2ms/step
# Epoch 303/700
# 762/762 - 1s - loss: 7.6956e-05 - val_loss: 1.5927e-05 - 1s/epoch - 2ms/step
# Epoch 304/700
# 762/762 - 1s - loss: 7.6917e-05 - val_loss: 1.5955e-05 - 1s/epoch - 1ms/step
# Epoch 305/700
# 762/762 - 1s - loss: 7.6878e-05 - val_loss: 1.5984e-05 - 1s/epoch - 1ms/step
# Epoch 306/700
# 762/762 - 1s - loss: 7.6839e-05 - val_loss: 1.6012e-05 - 1s/epoch - 1ms/step
# Epoch 307/700
# 762/762 - 1s - loss: 7.6800e-05 - val_loss: 1.6041e-05 - 1s/epoch - 2ms/step
# Epoch 308/700
# 762/762 - 1s - loss: 7.6762e-05 - val_loss: 1.6069e-05 - 1s/epoch - 1ms/step
# Epoch 309/700
# 762/762 - 1s - loss: 7.6723e-05 - val_loss: 1.6098e-05 - 1s/epoch - 1ms/step
# Epoch 310/700
# 762/762 - 1s - loss: 7.6685e-05 - val_loss: 1.6127e-05 - 1s/epoch - 1ms/step
# Epoch 311/700
# 762/762 - 1s - loss: 7.6647e-05 - val_loss: 1.6157e-05 - 1s/epoch - 2ms/step
# Epoch 312/700
# 762/762 - 1s - loss: 7.6609e-05 - val_loss: 1.6186e-05 - 1s/epoch - 2ms/step
# Epoch 313/700
# 762/762 - 1s - loss: 7.6571e-05 - val_loss: 1.6215e-05 - 1s/epoch - 2ms/step
# Epoch 314/700
# 762/762 - 1s - loss: 7.6534e-05 - val_loss: 1.6245e-05 - 1s/epoch - 2ms/step
# Epoch 315/700
# 762/762 - 1s - loss: 7.6496e-05 - val_loss: 1.6275e-05 - 1s/epoch - 2ms/step
# Epoch 316/700
# 762/762 - 1s - loss: 7.6459e-05 - val_loss: 1.6305e-05 - 1s/epoch - 2ms/step
# Epoch 317/700
# 762/762 - 1s - loss: 7.6421e-05 - val_loss: 1.6335e-05 - 1s/epoch - 2ms/step
# Epoch 318/700
# 762/762 - 1s - loss: 7.6384e-05 - val_loss: 1.6365e-05 - 1s/epoch - 2ms/step
# Epoch 319/700
# 762/762 - 1s - loss: 7.6347e-05 - val_loss: 1.6395e-05 - 1s/epoch - 1ms/step
# Epoch 320/700
# 762/762 - 1s - loss: 7.6310e-05 - val_loss: 1.6426e-05 - 1s/epoch - 2ms/step
# Epoch 321/700
# 762/762 - 1s - loss: 7.6274e-05 - val_loss: 1.6456e-05 - 1s/epoch - 1ms/step
# Epoch 322/700
# 762/762 - 1s - loss: 7.6237e-05 - val_loss: 1.6487e-05 - 1s/epoch - 1ms/step
# Epoch 323/700
# 762/762 - 1s - loss: 7.6201e-05 - val_loss: 1.6518e-05 - 1s/epoch - 2ms/step
# Epoch 324/700
# 762/762 - 1s - loss: 7.6164e-05 - val_loss: 1.6549e-05 - 1s/epoch - 2ms/step
# Epoch 325/700
# 762/762 - 1s - loss: 7.6128e-05 - val_loss: 1.6580e-05 - 1s/epoch - 2ms/step
# Epoch 326/700
# 762/762 - 1s - loss: 7.6092e-05 - val_loss: 1.6612e-05 - 1s/epoch - 1ms/step
# Epoch 327/700
# 762/762 - 1s - loss: 7.6056e-05 - val_loss: 1.6643e-05 - 1s/epoch - 1ms/step
# Epoch 328/700
# 762/762 - 1s - loss: 7.6021e-05 - val_loss: 1.6675e-05 - 1s/epoch - 2ms/step
# Epoch 329/700
# 762/762 - 1s - loss: 7.5985e-05 - val_loss: 1.6706e-05 - 1s/epoch - 2ms/step
# Epoch 330/700
# 762/762 - 1s - loss: 7.5949e-05 - val_loss: 1.6738e-05 - 1s/epoch - 2ms/step
# Epoch 331/700
# 762/762 - 1s - loss: 7.5914e-05 - val_loss: 1.6770e-05 - 1s/epoch - 1ms/step
# Epoch 332/700
# 762/762 - 1s - loss: 7.5879e-05 - val_loss: 1.6802e-05 - 1s/epoch - 2ms/step
# Epoch 333/700
# 762/762 - 1s - loss: 7.5844e-05 - val_loss: 1.6834e-05 - 1s/epoch - 1ms/step
# Epoch 334/700
# 762/762 - 1s - loss: 7.5809e-05 - val_loss: 1.6867e-05 - 1s/epoch - 2ms/step
# Epoch 335/700
# 762/762 - 1s - loss: 7.5774e-05 - val_loss: 1.6899e-05 - 1s/epoch - 2ms/step
# Epoch 336/700
# 762/762 - 1s - loss: 7.5739e-05 - val_loss: 1.6932e-05 - 1s/epoch - 2ms/step
# Epoch 337/700
# 762/762 - 1s - loss: 7.5704e-05 - val_loss: 1.6965e-05 - 997ms/epoch - 1ms/step
# Epoch 338/700
# 762/762 - 1s - loss: 7.5670e-05 - val_loss: 1.6997e-05 - 1s/epoch - 2ms/step
# Epoch 339/700
# 762/762 - 1s - loss: 7.5636e-05 - val_loss: 1.7030e-05 - 1s/epoch - 2ms/step
# Epoch 340/700
# 762/762 - 1s - loss: 7.5602e-05 - val_loss: 1.7063e-05 - 998ms/epoch - 1ms/step
# Epoch 341/700
# 762/762 - 1s - loss: 7.5567e-05 - val_loss: 1.7096e-05 - 1s/epoch - 2ms/step
# Epoch 342/700
# 762/762 - 1s - loss: 7.5533e-05 - val_loss: 1.7130e-05 - 1s/epoch - 2ms/step
# Epoch 343/700
# 762/762 - 1s - loss: 7.5500e-05 - val_loss: 1.7163e-05 - 1s/epoch - 2ms/step
# Epoch 344/700
# 762/762 - 1s - loss: 7.5466e-05 - val_loss: 1.7196e-05 - 1s/epoch - 1ms/step
# Epoch 345/700
# 762/762 - 1s - loss: 7.5432e-05 - val_loss: 1.7230e-05 - 1s/epoch - 1ms/step
# Epoch 346/700
# 762/762 - 1s - loss: 7.5399e-05 - val_loss: 1.7264e-05 - 1s/epoch - 1ms/step
# Epoch 347/700
# 762/762 - 1s - loss: 7.5365e-05 - val_loss: 1.7297e-05 - 1s/epoch - 1ms/step
# Epoch 348/700
# 762/762 - 1s - loss: 7.5332e-05 - val_loss: 1.7331e-05 - 1s/epoch - 2ms/step
# Epoch 349/700
# 762/762 - 1s - loss: 7.5299e-05 - val_loss: 1.7365e-05 - 1s/epoch - 1ms/step
# Epoch 350/700
# 762/762 - 1s - loss: 7.5266e-05 - val_loss: 1.7399e-05 - 1s/epoch - 2ms/step
# Epoch 351/700
# 762/762 - 2s - loss: 7.5233e-05 - val_loss: 1.7433e-05 - 2s/epoch - 2ms/step
# Epoch 352/700
# 762/762 - 1s - loss: 7.5200e-05 - val_loss: 1.7468e-05 - 1s/epoch - 2ms/step
# Epoch 353/700
# 762/762 - 1s - loss: 7.5168e-05 - val_loss: 1.7502e-05 - 1s/epoch - 1ms/step
# Epoch 354/700
# 762/762 - 1s - loss: 7.5135e-05 - val_loss: 1.7536e-05 - 1s/epoch - 2ms/step
# Epoch 355/700
# 762/762 - 1s - loss: 7.5103e-05 - val_loss: 1.7571e-05 - 1s/epoch - 2ms/step
# Epoch 356/700
# 762/762 - 1s - loss: 7.5071e-05 - val_loss: 1.7605e-05 - 1s/epoch - 1ms/step
# Epoch 357/700
# 762/762 - 1s - loss: 7.5038e-05 - val_loss: 1.7640e-05 - 1s/epoch - 2ms/step
# Epoch 358/700
# 762/762 - 1s - loss: 7.5006e-05 - val_loss: 1.7675e-05 - 1s/epoch - 1ms/step
# Epoch 359/700
# 762/762 - 1s - loss: 7.4974e-05 - val_loss: 1.7710e-05 - 1s/epoch - 2ms/step
# Epoch 360/700
# 762/762 - 1s - loss: 7.4943e-05 - val_loss: 1.7745e-05 - 1s/epoch - 1ms/step
# Epoch 361/700
# 762/762 - 1s - loss: 7.4911e-05 - val_loss: 1.7780e-05 - 1s/epoch - 2ms/step
# Epoch 362/700
# 762/762 - 1s - loss: 7.4879e-05 - val_loss: 1.7815e-05 - 1s/epoch - 1ms/step
# Epoch 363/700
# 762/762 - 1s - loss: 7.4848e-05 - val_loss: 1.7850e-05 - 1s/epoch - 1ms/step
# Epoch 364/700
# 762/762 - 1s - loss: 7.4817e-05 - val_loss: 1.7885e-05 - 1s/epoch - 2ms/step
# Epoch 365/700
# 762/762 - 1s - loss: 7.4785e-05 - val_loss: 1.7921e-05 - 1s/epoch - 1ms/step
# Epoch 366/700
# 762/762 - 1s - loss: 7.4754e-05 - val_loss: 1.7956e-05 - 1s/epoch - 2ms/step
# Epoch 367/700
# 762/762 - 1s - loss: 7.4723e-05 - val_loss: 1.7992e-05 - 1s/epoch - 2ms/step
# Epoch 368/700
# 762/762 - 1s - loss: 7.4692e-05 - val_loss: 1.8027e-05 - 1s/epoch - 2ms/step
# Epoch 369/700
# 762/762 - 1s - loss: 7.4661e-05 - val_loss: 1.8063e-05 - 1s/epoch - 2ms/step
# Epoch 370/700
# 762/762 - 1s - loss: 7.4631e-05 - val_loss: 1.8099e-05 - 1s/epoch - 2ms/step
# Epoch 371/700
# 762/762 - 1s - loss: 7.4600e-05 - val_loss: 1.8134e-05 - 1s/epoch - 1ms/step
# Epoch 372/700
# 762/762 - 1s - loss: 7.4570e-05 - val_loss: 1.8170e-05 - 1s/epoch - 1ms/step
# Epoch 373/700
# 762/762 - 1s - loss: 7.4539e-05 - val_loss: 1.8206e-05 - 1s/epoch - 1ms/step
# Epoch 374/700
# 762/762 - 1s - loss: 7.4509e-05 - val_loss: 1.8242e-05 - 1s/epoch - 1ms/step
# Epoch 375/700
# 762/762 - 1s - loss: 7.4479e-05 - val_loss: 1.8278e-05 - 1s/epoch - 2ms/step
# Epoch 376/700
# 762/762 - 1s - loss: 7.4449e-05 - val_loss: 1.8314e-05 - 1s/epoch - 2ms/step
# Epoch 377/700
# 762/762 - 1s - loss: 7.4419e-05 - val_loss: 1.8351e-05 - 1s/epoch - 1ms/step
# Epoch 378/700
# 762/762 - 1s - loss: 7.4389e-05 - val_loss: 1.8387e-05 - 1s/epoch - 2ms/step
# Epoch 379/700
# 762/762 - 1s - loss: 7.4360e-05 - val_loss: 1.8423e-05 - 1s/epoch - 1ms/step
# Epoch 380/700
# 762/762 - 1s - loss: 7.4330e-05 - val_loss: 1.8459e-05 - 1s/epoch - 1ms/step
# Epoch 381/700
# 762/762 - 1s - loss: 7.4300e-05 - val_loss: 1.8496e-05 - 1s/epoch - 2ms/step
# Epoch 382/700
# 762/762 - 1s - loss: 7.4271e-05 - val_loss: 1.8532e-05 - 1s/epoch - 1ms/step
# Epoch 383/700
# 762/762 - 1s - loss: 7.4242e-05 - val_loss: 1.8569e-05 - 1s/epoch - 2ms/step
# Epoch 384/700
# 762/762 - 1s - loss: 7.4213e-05 - val_loss: 1.8605e-05 - 1s/epoch - 2ms/step
# Epoch 385/700
# 762/762 - 1s - loss: 7.4184e-05 - val_loss: 1.8642e-05 - 1s/epoch - 2ms/step
# Epoch 386/700
# 762/762 - 1s - loss: 7.4155e-05 - val_loss: 1.8678e-05 - 1s/epoch - 1ms/step
# Epoch 387/700
# 762/762 - 1s - loss: 7.4126e-05 - val_loss: 1.8715e-05 - 1s/epoch - 2ms/step
# Epoch 388/700
# 762/762 - 1s - loss: 7.4097e-05 - val_loss: 1.8752e-05 - 1s/epoch - 2ms/step
# Epoch 389/700
# 762/762 - 1s - loss: 7.4068e-05 - val_loss: 1.8788e-05 - 1s/epoch - 2ms/step
# Epoch 390/700
# 762/762 - 1s - loss: 7.4040e-05 - val_loss: 1.8825e-05 - 1s/epoch - 1ms/step
# Epoch 391/700
# 762/762 - 1s - loss: 7.4011e-05 - val_loss: 1.8862e-05 - 1s/epoch - 2ms/step
# Epoch 392/700
# 762/762 - 1s - loss: 7.3983e-05 - val_loss: 1.8899e-05 - 1s/epoch - 2ms/step
# Epoch 393/700
# 762/762 - 1s - loss: 7.3955e-05 - val_loss: 1.8936e-05 - 1s/epoch - 2ms/step
# Epoch 394/700
# 762/762 - 1s - loss: 7.3926e-05 - val_loss: 1.8973e-05 - 1s/epoch - 2ms/step
# Epoch 395/700
# 762/762 - 1s - loss: 7.3898e-05 - val_loss: 1.9010e-05 - 985ms/epoch - 1ms/step
# Epoch 396/700
# 762/762 - 1s - loss: 7.3870e-05 - val_loss: 1.9047e-05 - 1s/epoch - 2ms/step
# Epoch 397/700
# 762/762 - 1s - loss: 7.3843e-05 - val_loss: 1.9084e-05 - 1s/epoch - 2ms/step
# Epoch 398/700
# 762/762 - 1s - loss: 7.3815e-05 - val_loss: 1.9121e-05 - 1s/epoch - 1ms/step
# Epoch 399/700
# 762/762 - 1s - loss: 7.3787e-05 - val_loss: 1.9158e-05 - 1s/epoch - 2ms/step
# Epoch 400/700
# 762/762 - 1s - loss: 7.3760e-05 - val_loss: 1.9195e-05 - 1s/epoch - 1ms/step
# Epoch 401/700
# 762/762 - 1s - loss: 7.3732e-05 - val_loss: 1.9232e-05 - 1s/epoch - 2ms/step
# Epoch 402/700
# 762/762 - 1s - loss: 7.3705e-05 - val_loss: 1.9270e-05 - 1s/epoch - 2ms/step
# Epoch 403/700
# 762/762 - 1s - loss: 7.3677e-05 - val_loss: 1.9307e-05 - 1s/epoch - 1ms/step
# Epoch 404/700
# 762/762 - 1s - loss: 7.3650e-05 - val_loss: 1.9344e-05 - 1s/epoch - 1ms/step
# Epoch 405/700
# 762/762 - 1s - loss: 7.3623e-05 - val_loss: 1.9381e-05 - 1s/epoch - 1ms/step
# Epoch 406/700
# 762/762 - 1s - loss: 7.3596e-05 - val_loss: 1.9419e-05 - 1s/epoch - 1ms/step
# Epoch 407/700
# 762/762 - 1s - loss: 7.3569e-05 - val_loss: 1.9456e-05 - 1s/epoch - 1ms/step
# Epoch 408/700
# 762/762 - 1s - loss: 7.3542e-05 - val_loss: 1.9493e-05 - 1s/epoch - 2ms/step
# Epoch 409/700
# 762/762 - 1s - loss: 7.3516e-05 - val_loss: 1.9531e-05 - 1s/epoch - 2ms/step
# Epoch 410/700
# 762/762 - 1s - loss: 7.3489e-05 - val_loss: 1.9568e-05 - 1s/epoch - 1ms/step
# Epoch 411/700
# 762/762 - 1s - loss: 7.3463e-05 - val_loss: 1.9606e-05 - 1s/epoch - 1ms/step
# Epoch 412/700
# 762/762 - 1s - loss: 7.3436e-05 - val_loss: 1.9643e-05 - 1s/epoch - 2ms/step
# Epoch 413/700
# 762/762 - 1s - loss: 7.3410e-05 - val_loss: 1.9680e-05 - 1s/epoch - 2ms/step
# Epoch 414/700
# 762/762 - 1s - loss: 7.3384e-05 - val_loss: 1.9718e-05 - 1s/epoch - 1ms/step
# Epoch 415/700
# 762/762 - 1s - loss: 7.3357e-05 - val_loss: 1.9755e-05 - 1s/epoch - 2ms/step
# Epoch 416/700
# 762/762 - 1s - loss: 7.3331e-05 - val_loss: 1.9793e-05 - 1s/epoch - 1ms/step
# Epoch 417/700
# 762/762 - 1s - loss: 7.3305e-05 - val_loss: 1.9830e-05 - 1s/epoch - 1ms/step
# Epoch 418/700
# 762/762 - 1s - loss: 7.3280e-05 - val_loss: 1.9868e-05 - 1s/epoch - 2ms/step
# Epoch 419/700
# 762/762 - 1s - loss: 7.3254e-05 - val_loss: 1.9905e-05 - 1s/epoch - 1ms/step
# Epoch 420/700
# 762/762 - 1s - loss: 7.3228e-05 - val_loss: 1.9943e-05 - 1s/epoch - 2ms/step
# Epoch 421/700
# 762/762 - 1s - loss: 7.3202e-05 - val_loss: 1.9980e-05 - 1s/epoch - 1ms/step
# Epoch 422/700
# 762/762 - 1s - loss: 7.3177e-05 - val_loss: 2.0017e-05 - 986ms/epoch - 1ms/step
# Epoch 423/700
# 762/762 - 1s - loss: 7.3152e-05 - val_loss: 2.0055e-05 - 1s/epoch - 1ms/step
# Epoch 424/700
# 762/762 - 1s - loss: 7.3126e-05 - val_loss: 2.0092e-05 - 994ms/epoch - 1ms/step
# Epoch 425/700
# 762/762 - 1s - loss: 7.3101e-05 - val_loss: 2.0130e-05 - 1s/epoch - 1ms/step
# Epoch 426/700
# 762/762 - 1s - loss: 7.3076e-05 - val_loss: 2.0167e-05 - 983ms/epoch - 1ms/step
# Epoch 427/700
# 762/762 - 1s - loss: 7.3051e-05 - val_loss: 2.0205e-05 - 1s/epoch - 2ms/step
# Epoch 428/700
# 762/762 - 1s - loss: 7.3026e-05 - val_loss: 2.0242e-05 - 1s/epoch - 2ms/step
# Epoch 429/700
# 762/762 - 1s - loss: 7.3001e-05 - val_loss: 2.0280e-05 - 1s/epoch - 2ms/step
# Epoch 430/700
# 762/762 - 1s - loss: 7.2976e-05 - val_loss: 2.0317e-05 - 1s/epoch - 1ms/step
# Epoch 431/700
# 762/762 - 1s - loss: 7.2951e-05 - val_loss: 2.0355e-05 - 1s/epoch - 2ms/step
# Epoch 432/700
# 762/762 - 1s - loss: 7.2927e-05 - val_loss: 2.0392e-05 - 1s/epoch - 1ms/step
# Epoch 433/700
# 762/762 - 1s - loss: 7.2902e-05 - val_loss: 2.0430e-05 - 1s/epoch - 1ms/step
# Epoch 434/700
# 762/762 - 1s - loss: 7.2877e-05 - val_loss: 2.0467e-05 - 1000ms/epoch - 1ms/step
# Epoch 435/700
# 762/762 - 1s - loss: 7.2853e-05 - val_loss: 2.0505e-05 - 1s/epoch - 2ms/step
# Epoch 436/700
# 762/762 - 1s - loss: 7.2829e-05 - val_loss: 2.0542e-05 - 1s/epoch - 2ms/step
# Epoch 437/700
# 762/762 - 1s - loss: 7.2805e-05 - val_loss: 2.0579e-05 - 1s/epoch - 2ms/step
# Epoch 438/700
# 762/762 - 1s - loss: 7.2780e-05 - val_loss: 2.0617e-05 - 988ms/epoch - 1ms/step
# Epoch 439/700
# 762/762 - 1s - loss: 7.2756e-05 - val_loss: 2.0654e-05 - 1s/epoch - 2ms/step
# Epoch 440/700
# 762/762 - 1s - loss: 7.2732e-05 - val_loss: 2.0692e-05 - 1s/epoch - 1ms/step
# Epoch 441/700
# 762/762 - 1s - loss: 7.2708e-05 - val_loss: 2.0729e-05 - 1s/epoch - 2ms/step
# Epoch 442/700
# 762/762 - 1s - loss: 7.2685e-05 - val_loss: 2.0766e-05 - 1s/epoch - 1ms/step
# Epoch 443/700
# 762/762 - 1s - loss: 7.2661e-05 - val_loss: 2.0803e-05 - 1s/epoch - 2ms/step
# Epoch 444/700
# 762/762 - 1s - loss: 7.2637e-05 - val_loss: 2.0841e-05 - 1s/epoch - 2ms/step
# Epoch 445/700
# 762/762 - 1s - loss: 7.2614e-05 - val_loss: 2.0878e-05 - 1s/epoch - 1ms/step
# Epoch 446/700
# 762/762 - 1s - loss: 7.2590e-05 - val_loss: 2.0915e-05 - 1s/epoch - 2ms/step
# Epoch 447/700
# 762/762 - 1s - loss: 7.2567e-05 - val_loss: 2.0952e-05 - 1s/epoch - 1ms/step
# Epoch 448/700
# 762/762 - 1s - loss: 7.2543e-05 - val_loss: 2.0990e-05 - 1s/epoch - 2ms/step
# Epoch 449/700
# 762/762 - 1s - loss: 7.2520e-05 - val_loss: 2.1027e-05 - 1s/epoch - 2ms/step
# Epoch 450/700
# 762/762 - 1s - loss: 7.2497e-05 - val_loss: 2.1064e-05 - 1s/epoch - 2ms/step
# Epoch 451/700
# 762/762 - 1s - loss: 7.2474e-05 - val_loss: 2.1101e-05 - 1s/epoch - 2ms/step
# Epoch 452/700
# 762/762 - 1s - loss: 7.2451e-05 - val_loss: 2.1138e-05 - 1s/epoch - 2ms/step
# Epoch 453/700
# 762/762 - 1s - loss: 7.2428e-05 - val_loss: 2.1175e-05 - 1s/epoch - 2ms/step
# Epoch 454/700
# 762/762 - 1s - loss: 7.2405e-05 - val_loss: 2.1212e-05 - 1s/epoch - 1ms/step
# Epoch 455/700
# 762/762 - 1s - loss: 7.2382e-05 - val_loss: 2.1249e-05 - 1s/epoch - 2ms/step
# Epoch 456/700
# 762/762 - 1s - loss: 7.2359e-05 - val_loss: 2.1286e-05 - 1s/epoch - 1ms/step
# Epoch 457/700
# 762/762 - 1s - loss: 7.2337e-05 - val_loss: 2.1323e-05 - 1s/epoch - 1ms/step
# Epoch 458/700
# 762/762 - 1s - loss: 7.2314e-05 - val_loss: 2.1359e-05 - 1s/epoch - 1ms/step
# Epoch 459/700
# 762/762 - 1s - loss: 7.2292e-05 - val_loss: 2.1396e-05 - 1s/epoch - 2ms/step
# Epoch 460/700
# 762/762 - 1s - loss: 7.2269e-05 - val_loss: 2.1433e-05 - 1s/epoch - 1ms/step
# Epoch 461/700
# 762/762 - 1s - loss: 7.2247e-05 - val_loss: 2.1470e-05 - 1s/epoch - 2ms/step
# Epoch 462/700
# 762/762 - 1s - loss: 7.2225e-05 - val_loss: 2.1506e-05 - 1s/epoch - 2ms/step
# Epoch 463/700
# 762/762 - 1s - loss: 7.2202e-05 - val_loss: 2.1543e-05 - 1s/epoch - 2ms/step
# Epoch 464/700
# 762/762 - 1s - loss: 7.2180e-05 - val_loss: 2.1580e-05 - 1s/epoch - 2ms/step
# Epoch 465/700
# 762/762 - 1s - loss: 7.2158e-05 - val_loss: 2.1616e-05 - 1s/epoch - 1ms/step
# Epoch 466/700
# 762/762 - 1s - loss: 7.2136e-05 - val_loss: 2.1653e-05 - 1s/epoch - 1ms/step
# Epoch 467/700
# 762/762 - 1s - loss: 7.2114e-05 - val_loss: 2.1690e-05 - 1s/epoch - 2ms/step
# Epoch 468/700
# 762/762 - 1s - loss: 7.2092e-05 - val_loss: 2.1726e-05 - 1s/epoch - 1ms/step
# Epoch 469/700
# 762/762 - 1s - loss: 7.2071e-05 - val_loss: 2.1762e-05 - 1s/epoch - 2ms/step
# Epoch 470/700
# 762/762 - 1s - loss: 7.2049e-05 - val_loss: 2.1799e-05 - 1s/epoch - 1ms/step
# Epoch 471/700
# 762/762 - 1s - loss: 7.2027e-05 - val_loss: 2.1835e-05 - 1s/epoch - 1ms/step
# Epoch 472/700
# 762/762 - 1s - loss: 7.2006e-05 - val_loss: 2.1871e-05 - 1s/epoch - 1ms/step
# Epoch 473/700
# 762/762 - 1s - loss: 7.1984e-05 - val_loss: 2.1908e-05 - 1s/epoch - 1ms/step
# Epoch 474/700
# 762/762 - 1s - loss: 7.1963e-05 - val_loss: 2.1944e-05 - 1s/epoch - 2ms/step
# Epoch 475/700
# 762/762 - 1s - loss: 7.1942e-05 - val_loss: 2.1980e-05 - 1s/epoch - 2ms/step
# Epoch 476/700
# 762/762 - 1s - loss: 7.1920e-05 - val_loss: 2.2016e-05 - 1s/epoch - 2ms/step
# Epoch 477/700
# 762/762 - 1s - loss: 7.1899e-05 - val_loss: 2.2052e-05 - 1s/epoch - 2ms/step
# Epoch 478/700
# 762/762 - 1s - loss: 7.1878e-05 - val_loss: 2.2088e-05 - 1s/epoch - 2ms/step
# Epoch 479/700
# 762/762 - 1s - loss: 7.1857e-05 - val_loss: 2.2124e-05 - 1s/epoch - 2ms/step
# Epoch 480/700
# 762/762 - 1s - loss: 7.1836e-05 - val_loss: 2.2160e-05 - 1s/epoch - 1ms/step
# Epoch 481/700
# 762/762 - 1s - loss: 7.1815e-05 - val_loss: 2.2196e-05 - 1s/epoch - 1ms/step
# Epoch 482/700
# 762/762 - 1s - loss: 7.1794e-05 - val_loss: 2.2231e-05 - 1s/epoch - 1ms/step
# Epoch 483/700
# 762/762 - 1s - loss: 7.1774e-05 - val_loss: 2.2267e-05 - 1s/epoch - 2ms/step
# Epoch 484/700
# 762/762 - 1s - loss: 7.1753e-05 - val_loss: 2.2303e-05 - 1s/epoch - 2ms/step
# Epoch 485/700
# 762/762 - 1s - loss: 7.1732e-05 - val_loss: 2.2339e-05 - 1s/epoch - 2ms/step
# Epoch 486/700
# 762/762 - 1s - loss: 7.1712e-05 - val_loss: 2.2374e-05 - 1s/epoch - 2ms/step
# Epoch 487/700
# 762/762 - 1s - loss: 7.1691e-05 - val_loss: 2.2410e-05 - 1s/epoch - 1ms/step
# Epoch 488/700
# 762/762 - 1s - loss: 7.1671e-05 - val_loss: 2.2445e-05 - 994ms/epoch - 1ms/step
# Epoch 489/700
# 762/762 - 1s - loss: 7.1650e-05 - val_loss: 2.2481e-05 - 1s/epoch - 2ms/step
# Epoch 490/700
# 762/762 - 1s - loss: 7.1630e-05 - val_loss: 2.2516e-05 - 1s/epoch - 2ms/step
# Epoch 491/700
# 762/762 - 1s - loss: 7.1610e-05 - val_loss: 2.2551e-05 - 1s/epoch - 2ms/step
# Epoch 492/700
# 762/762 - 1s - loss: 7.1590e-05 - val_loss: 2.2586e-05 - 1s/epoch - 2ms/step
# Epoch 493/700
# 762/762 - 1s - loss: 7.1569e-05 - val_loss: 2.2621e-05 - 1s/epoch - 1ms/step
# Epoch 494/700
# 762/762 - 1s - loss: 7.1549e-05 - val_loss: 2.2656e-05 - 1s/epoch - 2ms/step
# Epoch 495/700
# 762/762 - 1s - loss: 7.1529e-05 - val_loss: 2.2691e-05 - 1s/epoch - 2ms/step
# Epoch 496/700
# 762/762 - 1s - loss: 7.1509e-05 - val_loss: 2.2727e-05 - 1s/epoch - 1ms/step
# Epoch 497/700
# 762/762 - 1s - loss: 7.1489e-05 - val_loss: 2.2761e-05 - 1s/epoch - 2ms/step
# Epoch 498/700
# 762/762 - 1s - loss: 7.1470e-05 - val_loss: 2.2796e-05 - 1s/epoch - 2ms/step
# Epoch 499/700
# 762/762 - 1s - loss: 7.1450e-05 - val_loss: 2.2831e-05 - 1s/epoch - 2ms/step
# Epoch 500/700
# 762/762 - 1s - loss: 7.1430e-05 - val_loss: 2.2866e-05 - 1s/epoch - 1ms/step
# Epoch 501/700
# 762/762 - 1s - loss: 7.1411e-05 - val_loss: 2.2900e-05 - 1s/epoch - 2ms/step
# Epoch 502/700
# 762/762 - 1s - loss: 7.1391e-05 - val_loss: 2.2935e-05 - 1s/epoch - 2ms/step
# Epoch 503/700
# 762/762 - 1s - loss: 7.1372e-05 - val_loss: 2.2969e-05 - 1s/epoch - 1ms/step
# Epoch 504/700
# 762/762 - 1s - loss: 7.1352e-05 - val_loss: 2.3004e-05 - 1s/epoch - 2ms/step
# Epoch 505/700
# 762/762 - 1s - loss: 7.1333e-05 - val_loss: 2.3038e-05 - 1s/epoch - 1ms/step
# Epoch 506/700
# 762/762 - 1s - loss: 7.1314e-05 - val_loss: 2.3072e-05 - 1s/epoch - 1ms/step
# Epoch 507/700
# 762/762 - 1s - loss: 7.1294e-05 - val_loss: 2.3106e-05 - 1s/epoch - 1ms/step
# Epoch 508/700
# 762/762 - 1s - loss: 7.1275e-05 - val_loss: 2.3141e-05 - 1s/epoch - 2ms/step
# Epoch 509/700
# 762/762 - 1s - loss: 7.1256e-05 - val_loss: 2.3175e-05 - 1s/epoch - 1ms/step
# Epoch 510/700
# 762/762 - 1s - loss: 7.1237e-05 - val_loss: 2.3209e-05 - 1s/epoch - 1ms/step
# Epoch 511/700
# 762/762 - 1s - loss: 7.1218e-05 - val_loss: 2.3243e-05 - 1s/epoch - 2ms/step
# Epoch 512/700
# 762/762 - 1s - loss: 7.1199e-05 - val_loss: 2.3276e-05 - 1s/epoch - 1ms/step
# Epoch 513/700
# 762/762 - 1s - loss: 7.1180e-05 - val_loss: 2.3310e-05 - 1s/epoch - 1ms/step
# Epoch 514/700
# 762/762 - 1s - loss: 7.1161e-05 - val_loss: 2.3344e-05 - 1s/epoch - 2ms/step
# Epoch 515/700
# 762/762 - 1s - loss: 7.1143e-05 - val_loss: 2.3377e-05 - 1s/epoch - 2ms/step
# Epoch 516/700
# 762/762 - 1s - loss: 7.1124e-05 - val_loss: 2.3411e-05 - 1s/epoch - 2ms/step
# Epoch 517/700
# 762/762 - 1s - loss: 7.1105e-05 - val_loss: 2.3444e-05 - 1s/epoch - 1ms/step
# Epoch 518/700
# 762/762 - 1s - loss: 7.1087e-05 - val_loss: 2.3478e-05 - 1s/epoch - 2ms/step
# Epoch 519/700
# 762/762 - 1s - loss: 7.1068e-05 - val_loss: 2.3511e-05 - 1s/epoch - 1ms/step
# Epoch 520/700
# 762/762 - 1s - loss: 7.1050e-05 - val_loss: 2.3544e-05 - 1s/epoch - 2ms/step
# Epoch 521/700
# 762/762 - 1s - loss: 7.1031e-05 - val_loss: 2.3577e-05 - 1s/epoch - 1ms/step
# Epoch 522/700
# 762/762 - 1s - loss: 7.1013e-05 - val_loss: 2.3610e-05 - 1s/epoch - 1ms/step
# Epoch 523/700
# 762/762 - 1s - loss: 7.0995e-05 - val_loss: 2.3643e-05 - 998ms/epoch - 1ms/step
# Epoch 524/700
# 762/762 - 1s - loss: 7.0976e-05 - val_loss: 2.3676e-05 - 1s/epoch - 2ms/step
# Epoch 525/700
# 762/762 - 1s - loss: 7.0958e-05 - val_loss: 2.3709e-05 - 991ms/epoch - 1ms/step
# Epoch 526/700
# 762/762 - 1s - loss: 7.0940e-05 - val_loss: 2.3742e-05 - 1s/epoch - 2ms/step
# Epoch 527/700
# 762/762 - 1s - loss: 7.0922e-05 - val_loss: 2.3775e-05 - 987ms/epoch - 1ms/step
# Epoch 528/700
# 762/762 - 1s - loss: 7.0904e-05 - val_loss: 2.3807e-05 - 1s/epoch - 2ms/step
# Epoch 529/700
# ...
# Epoch 552/700
# 762/762 - 1s - loss: 7.0488e-05 - val_loss: 2.4565e-05 - 1s/epoch - 1ms/step
# Epoch 553/700
# 762/762 - 1s - loss: 7.0471e-05 - val_loss: 2.4595e-05 - 1s/epoch - 1ms/step
# Epoch 554/700
# 762/762 - 1s - loss: 7.0455e-05 - val_loss: 2.4626e-05 - 1s/epoch - 2ms/step
# Epoch 555/700
# 762/762 - 1s - loss: 7.0438e-05 - val_loss: 2.4656e-05 - 1s/epoch - 2ms/step
# Epoch 556/700
# 762/762 - 1s - loss: 7.0422e-05 - val_loss: 2.4686e-05 - 1s/epoch - 1ms/step
# Epoch 557/700
# 762/762 - 1s - loss: 7.0405e-05 - val_loss: 2.4716e-05 - 1s/epoch - 1ms/step
# Epoch 558/700
# 762/762 - 1s - loss: 7.0389e-05 - val_loss: 2.4746e-05 - 1s/epoch - 2ms/step
# Epoch 559/700
# 762/762 - 1s - loss: 7.0372e-05 - val_loss: 2.4776e-05 - 1s/epoch - 2ms/step
# Epoch 560/700
# 762/762 - 1s - loss: 7.0356e-05 - val_loss: 2.4806e-05 - 1s/epoch - 1ms/step
# Epoch 561/700
# 762/762 - 1s - loss: 7.0340e-05 - val_loss: 2.4836e-05 - 1s/epoch - 1ms/step
# Epoch 562/700
# 762/762 - 1s - loss: 7.0323e-05 - val_loss: 2.4866e-05 - 1s/epoch - 2ms/step
# Epoch 563/700
# 762/762 - 1s - loss: 7.0307e-05 - val_loss: 2.4896e-05 - 1s/epoch - 1ms/step
# Epoch 564/700
# 762/762 - 1s - loss: 7.0291e-05 - val_loss: 2.4925e-05 - 1s/epoch - 2ms/step
# Epoch 565/700
# 762/762 - 1s - loss: 7.0275e-05 - val_loss: 2.4954e-05 - 1s/epoch - 2ms/step
# Epoch 566/700
# 762/762 - 1s - loss: 7.0259e-05 - val_loss: 2.4984e-05 - 1s/epoch - 2ms/step
# Epoch 567/700
# 762/762 - 1s - loss: 7.0243e-05 - val_loss: 2.5013e-05 - 1s/epoch - 2ms/step
# Epoch 568/700
# 762/762 - 1s - loss: 7.0227e-05 - val_loss: 2.5042e-05 - 1s/epoch - 1ms/step
# Epoch 569/700
# 762/762 - 1s - loss: 7.0211e-05 - val_loss: 2.5071e-05 - 1s/epoch - 1ms/step
# Epoch 570/700
# 762/762 - 1s - loss: 7.0195e-05 - val_loss: 2.5100e-05 - 1s/epoch - 1ms/step
# Epoch 571/700
# 762/762 - 1s - loss: 7.0180e-05 - val_loss: 2.5129e-05 - 1s/epoch - 1ms/step
# Epoch 572/700
# 762/762 - 1s - loss: 7.0164e-05 - val_loss: 2.5158e-05 - 1s/epoch - 1ms/step
# Epoch 573/700
# 762/762 - 1s - loss: 7.0148e-05 - val_loss: 2.5187e-05 - 999ms/epoch - 1ms/step
# Epoch 574/700
# 762/762 - 1s - loss: 7.0132e-05 - val_loss: 2.5215e-05 - 1s/epoch - 2ms/step
# Epoch 575/700
# 762/762 - 1s - loss: 7.0117e-05 - val_loss: 2.5244e-05 - 1s/epoch - 2ms/step
# Epoch 576/700
# 762/762 - 1s - loss: 7.0101e-05 - val_loss: 2.5273e-05 - 1s/epoch - 1ms/step
# Epoch 577/700
# 762/762 - 1s - loss: 7.0086e-05 - val_loss: 2.5301e-05 - 1s/epoch - 2ms/step
# Epoch 578/700
# 762/762 - 1s - loss: 7.0070e-05 - val_loss: 2.5329e-05 - 1s/epoch - 2ms/step
# Epoch 579/700
# 762/762 - 1s - loss: 7.0055e-05 - val_loss: 2.5357e-05 - 1s/epoch - 2ms/step
# Epoch 580/700
# 762/762 - 1s - loss: 7.0039e-05 - val_loss: 2.5385e-05 - 1s/epoch - 1ms/step
# Epoch 581/700
# 762/762 - 1s - loss: 7.0024e-05 - val_loss: 2.5413e-05 - 1s/epoch - 2ms/step
# Epoch 582/700
# 762/762 - 1s - loss: 7.0009e-05 - val_loss: 2.5441e-05 - 1s/epoch - 2ms/step
# Epoch 583/700
# 762/762 - 1s - loss: 6.9993e-05 - val_loss: 2.5469e-05 - 1s/epoch - 2ms/step
# Epoch 584/700
# 762/762 - 1s - loss: 6.9978e-05 - val_loss: 2.5497e-05 - 1s/epoch - 2ms/step
# Epoch 585/700
# 762/762 - 1s - loss: 6.9963e-05 - val_loss: 2.5524e-05 - 1s/epoch - 2ms/step
# Epoch 586/700
# 762/762 - 1s - loss: 6.9948e-05 - val_loss: 2.5552e-05 - 1s/epoch - 1ms/step
# Epoch 587/700
# 762/762 - 1s - loss: 6.9933e-05 - val_loss: 2.5579e-05 - 1s/epoch - 2ms/step
# Epoch 588/700
# 762/762 - 1s - loss: 6.9918e-05 - val_loss: 2.5607e-05 - 1s/epoch - 1ms/step
# Epoch 589/700
# 762/762 - 1s - loss: 6.9903e-05 - val_loss: 2.5634e-05 - 1s/epoch - 2ms/step
# Epoch 590/700
# 762/762 - 1s - loss: 6.9888e-05 - val_loss: 2.5662e-05 - 1s/epoch - 2ms/step
# Epoch 591/700
# 762/762 - 1s - loss: 6.9873e-05 - val_loss: 2.5689e-05 - 1s/epoch - 2ms/step
# Epoch 592/700
# 762/762 - 1s - loss: 6.9858e-05 - val_loss: 2.5716e-05 - 1s/epoch - 2ms/step
# Epoch 593/700
# 762/762 - 1s - loss: 6.9843e-05 - val_loss: 2.5743e-05 - 1s/epoch - 2ms/step
# Epoch 594/700
# 762/762 - 1s - loss: 6.9828e-05 - val_loss: 2.5769e-05 - 1s/epoch - 2ms/step
# Epoch 595/700
# 762/762 - 1s - loss: 6.9813e-05 - val_loss: 2.5796e-05 - 1s/epoch - 2ms/step
# Epoch 596/700
# 762/762 - 1s - loss: 6.9799e-05 - val_loss: 2.5823e-05 - 1s/epoch - 1ms/step
# Epoch 597/700
# 762/762 - 1s - loss: 6.9784e-05 - val_loss: 2.5849e-05 - 1s/epoch - 2ms/step
# Epoch 598/700
# 762/762 - 1s - loss: 6.9769e-05 - val_loss: 2.5876e-05 - 1s/epoch - 2ms/step
# Epoch 599/700
# 762/762 - 1s - loss: 6.9755e-05 - val_loss: 2.5903e-05 - 1s/epoch - 2ms/step
# Epoch 600/700
# 762/762 - 1s - loss: 6.9740e-05 - val_loss: 2.5929e-05 - 1s/epoch - 2ms/step
# Epoch 601/700
# 762/762 - 1s - loss: 6.9726e-05 - val_loss: 2.5955e-05 - 1s/epoch - 1ms/step
# Epoch 602/700
# 762/762 - 1s - loss: 6.9711e-05 - val_loss: 2.5981e-05 - 1s/epoch - 2ms/step
# Epoch 603/700
# 762/762 - 1s - loss: 6.9697e-05 - val_loss: 2.6008e-05 - 1s/epoch - 1ms/step
# Epoch 604/700
# 762/762 - 1s - loss: 6.9682e-05 - val_loss: 2.6034e-05 - 1s/epoch - 2ms/step
# Epoch 605/700
# 762/762 - 1s - loss: 6.9668e-05 - val_loss: 2.6059e-05 - 1s/epoch - 2ms/step
# Epoch 606/700
# 762/762 - 1s - loss: 6.9654e-05 - val_loss: 2.6085e-05 - 1s/epoch - 1ms/step
# Epoch 607/700
# 762/762 - 1s - loss: 6.9640e-05 - val_loss: 2.6111e-05 - 1s/epoch - 1ms/step
# Epoch 608/700
# 762/762 - 1s - loss: 6.9625e-05 - val_loss: 2.6137e-05 - 1s/epoch - 2ms/step
# Epoch 609/700
# 762/762 - 1s - loss: 6.9611e-05 - val_loss: 2.6162e-05 - 992ms/epoch - 1ms/step
# Epoch 610/700
# 762/762 - 1s - loss: 6.9597e-05 - val_loss: 2.6188e-05 - 998ms/epoch - 1ms/step
# Epoch 611/700
# 762/762 - 1s - loss: 6.9583e-05 - val_loss: 2.6213e-05 - 1s/epoch - 2ms/step
# Epoch 612/700
# 762/762 - 1s - loss: 6.9569e-05 - val_loss: 2.6239e-05 - 1s/epoch - 2ms/step
# Epoch 613/700
# 762/762 - 1s - loss: 6.9555e-05 - val_loss: 2.6264e-05 - 1s/epoch - 1ms/step
# Epoch 614/700
# 762/762 - 1s - loss: 6.9541e-05 - val_loss: 2.6289e-05 - 1s/epoch - 2ms/step
# Epoch 615/700
# 762/762 - 1s - loss: 6.9527e-05 - val_loss: 2.6314e-05 - 1s/epoch - 1ms/step
# Epoch 616/700
# 762/762 - 1s - loss: 6.9513e-05 - val_loss: 2.6339e-05 - 1s/epoch - 1ms/step
# Epoch 617/700
# 762/762 - 1s - loss: 6.9499e-05 - val_loss: 2.6364e-05 - 1s/epoch - 2ms/step
# Epoch 618/700
# 762/762 - 1s - loss: 6.9485e-05 - val_loss: 2.6389e-05 - 1s/epoch - 2ms/step
# Epoch 619/700
# 762/762 - 1s - loss: 6.9471e-05 - val_loss: 2.6414e-05 - 1s/epoch - 1ms/step
# Epoch 620/700
# 762/762 - 1s - loss: 6.9458e-05 - val_loss: 2.6438e-05 - 1s/epoch - 2ms/step
# Epoch 621/700
# 762/762 - 1s - loss: 6.9444e-05 - val_loss: 2.6463e-05 - 1s/epoch - 2ms/step
# Epoch 622/700
# 762/762 - 1s - loss: 6.9430e-05 - val_loss: 2.6487e-05 - 1s/epoch - 1ms/step
# Epoch 623/700
# 762/762 - 1s - loss: 6.9416e-05 - val_loss: 2.6512e-05 - 1s/epoch - 2ms/step
# Epoch 624/700
# 762/762 - 1s - loss: 6.9403e-05 - val_loss: 2.6536e-05 - 1s/epoch - 2ms/step
# Epoch 625/700
# 762/762 - 1s - loss: 6.9389e-05 - val_loss: 2.6561e-05 - 1s/epoch - 1ms/step
# Epoch 626/700
# 762/762 - 1s - loss: 6.9376e-05 - val_loss: 2.6585e-05 - 1s/epoch - 1ms/step
# Epoch 627/700
# 762/762 - 1s - loss: 6.9362e-05 - val_loss: 2.6609e-05 - 1s/epoch - 2ms/step
# Epoch 628/700
# 762/762 - 1s - loss: 6.9349e-05 - val_loss: 2.6633e-05 - 1s/epoch - 1ms/step
# Epoch 629/700
# 762/762 - 1s - loss: 6.9335e-05 - val_loss: 2.6657e-05 - 989ms/epoch - 1ms/step
# Epoch 630/700
# 762/762 - 1s - loss: 6.9322e-05 - val_loss: 2.6680e-05 - 1s/epoch - 2ms/step
# Epoch 631/700
# 762/762 - 1s - loss: 6.9308e-05 - val_loss: 2.6704e-05 - 1s/epoch - 2ms/step
# Epoch 632/700
# 762/762 - 1s - loss: 6.9295e-05 - val_loss: 2.6728e-05 - 1s/epoch - 2ms/step
# Epoch 633/700
# 762/762 - 1s - loss: 6.9282e-05 - val_loss: 2.6751e-05 - 1s/epoch - 2ms/step
# Epoch 634/700
# 762/762 - 1s - loss: 6.9269e-05 - val_loss: 2.6775e-05 - 1s/epoch - 2ms/step
# Epoch 635/700
# 762/762 - 1s - loss: 6.9255e-05 - val_loss: 2.6798e-05 - 1s/epoch - 2ms/step
# Epoch 636/700
# 762/762 - 1s - loss: 6.9242e-05 - val_loss: 2.6822e-05 - 1s/epoch - 1ms/step
# Epoch 637/700
# 762/762 - 1s - loss: 6.9229e-05 - val_loss: 2.6845e-05 - 1s/epoch - 2ms/step
# Epoch 638/700
# 762/762 - 1s - loss: 6.9216e-05 - val_loss: 2.6868e-05 - 1s/epoch - 2ms/step
# Epoch 639/700
# 762/762 - 1s - loss: 6.9203e-05 - val_loss: 2.6891e-05 - 1s/epoch - 2ms/step
# Epoch 640/700
# 762/762 - 1s - loss: 6.9190e-05 - val_loss: 2.6914e-05 - 1s/epoch - 2ms/step
# Epoch 641/700
# 762/762 - 1s - loss: 6.9177e-05 - val_loss: 2.6937e-05 - 1s/epoch - 1ms/step
# Epoch 642/700
# 762/762 - 1s - loss: 6.9164e-05 - val_loss: 2.6960e-05 - 1s/epoch - 2ms/step
# Epoch 643/700
# 762/762 - 1s - loss: 6.9151e-05 - val_loss: 2.6983e-05 - 1s/epoch - 2ms/step
# Epoch 644/700
# 762/762 - 1s - loss: 6.9138e-05 - val_loss: 2.7006e-05 - 1s/epoch - 2ms/step
# Epoch 645/700
# 762/762 - 1s - loss: 6.9125e-05 - val_loss: 2.7029e-05 - 1s/epoch - 2ms/step
# Epoch 646/700
# 762/762 - 1s - loss: 6.9112e-05 - val_loss: 2.7051e-05 - 1s/epoch - 1ms/step
# Epoch 647/700
# 762/762 - 1s - loss: 6.9099e-05 - val_loss: 2.7074e-05 - 1s/epoch - 2ms/step
# Epoch 648/700
# 762/762 - 1s - loss: 6.9087e-05 - val_loss: 2.7096e-05 - 1s/epoch - 2ms/step
# Epoch 649/700
# 762/762 - 1s - loss: 6.9074e-05 - val_loss: 2.7118e-05 - 1s/epoch - 1ms/step
# Epoch 650/700
# 762/762 - 1s - loss: 6.9061e-05 - val_loss: 2.7141e-05 - 1s/epoch - 1ms/step
# Epoch 651/700
# 762/762 - 1s - loss: 6.9048e-05 - val_loss: 2.7163e-05 - 1s/epoch - 1ms/step
# Epoch 652/700
# 762/762 - 1s - loss: 6.9036e-05 - val_loss: 2.7185e-05 - 1s/epoch - 2ms/step
# Epoch 653/700
# 762/762 - 1s - loss: 6.9023e-05 - val_loss: 2.7207e-05 - 1s/epoch - 1ms/step
# Epoch 654/700
# 762/762 - 1s - loss: 6.9010e-05 - val_loss: 2.7229e-05 - 1s/epoch - 2ms/step
# Epoch 655/700
# 762/762 - 1s - loss: 6.8998e-05 - val_loss: 2.7251e-05 - 1s/epoch - 2ms/step
# Epoch 656/700
# 762/762 - 1s - loss: 6.8985e-05 - val_loss: 2.7273e-05 - 1s/epoch - 1ms/step
# Epoch 657/700
# 762/762 - 1s - loss: 6.8973e-05 - val_loss: 2.7294e-05 - 1s/epoch - 2ms/step
# Epoch 658/700
# 762/762 - 1s - loss: 6.8960e-05 - val_loss: 2.7316e-05 - 988ms/epoch - 1ms/step
# Epoch 659/700
# 762/762 - 1s - loss: 6.8948e-05 - val_loss: 2.7338e-05 - 1s/epoch - 1ms/step
# Epoch 660/700
# 762/762 - 1s - loss: 6.8936e-05 - val_loss: 2.7360e-05 - 1s/epoch - 2ms/step
# Epoch 661/700
# 762/762 - 1s - loss: 6.8923e-05 - val_loss: 2.7381e-05 - 1s/epoch - 1ms/step
# Epoch 662/700
# 762/762 - 1s - loss: 6.8911e-05 - val_loss: 2.7402e-05 - 1s/epoch - 1ms/step
# Epoch 663/700
# 762/762 - 1s - loss: 6.8899e-05 - val_loss: 2.7424e-05 - 1s/epoch - 2ms/step
# Epoch 664/700
# 762/762 - 1s - loss: 6.8886e-05 - val_loss: 2.7445e-05 - 1s/epoch - 2ms/step
# Epoch 665/700
# 762/762 - 1s - loss: 6.8874e-05 - val_loss: 2.7466e-05 - 1s/epoch - 1ms/step
# Epoch 666/700
# 762/762 - 1s - loss: 6.8862e-05 - val_loss: 2.7487e-05 - 1s/epoch - 1ms/step
# Epoch 667/700
# 762/762 - 1s - loss: 6.8850e-05 - val_loss: 2.7508e-05 - 1s/epoch - 1ms/step
# Epoch 668/700
# 762/762 - 1s - loss: 6.8837e-05 - val_loss: 2.7529e-05 - 1s/epoch - 1ms/step
# Epoch 669/700
# 762/762 - 1s - loss: 6.8825e-05 - val_loss: 2.7550e-05 - 1s/epoch - 1ms/step
# Epoch 670/700
# 762/762 - 1s - loss: 6.8813e-05 - val_loss: 2.7571e-05 - 1s/epoch - 2ms/step
# Epoch 671/700
# 762/762 - 1s - loss: 6.8801e-05 - val_loss: 2.7592e-05 - 1s/epoch - 2ms/step
# Epoch 672/700
# 762/762 - 1s - loss: 6.8789e-05 - val_loss: 2.7612e-05 - 1s/epoch - 1ms/step
# Epoch 673/700
# 762/762 - 1s - loss: 6.8777e-05 - val_loss: 2.7633e-05 - 1s/epoch - 1ms/step
# Epoch 674/700
# 762/762 - 1s - loss: 6.8765e-05 - val_loss: 2.7653e-05 - 993ms/epoch - 1ms/step
# Epoch 675/700
# 762/762 - 1s - loss: 6.8753e-05 - val_loss: 2.7674e-05 - 1s/epoch - 1ms/step
# Epoch 676/700
# 762/762 - 1s - loss: 6.8741e-05 - val_loss: 2.7694e-05 - 1s/epoch - 1ms/step
# Epoch 677/700
# 762/762 - 1s - loss: 6.8729e-05 - val_loss: 2.7715e-05 - 1s/epoch - 1ms/step
# Epoch 678/700
# 762/762 - 1s - loss: 6.8717e-05 - val_loss: 2.7735e-05 - 1s/epoch - 1ms/step
# Epoch 679/700
# 762/762 - 1s - loss: 6.8706e-05 - val_loss: 2.7755e-05 - 1s/epoch - 1ms/step
# Epoch 680/700
# 762/762 - 1s - loss: 6.8694e-05 - val_loss: 2.7776e-05 - 1s/epoch - 1ms/step
# Epoch 681/700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-8848d79d7d97> in <module>
#      40     print(f'Epoch {epoch}/{n_epochs}')
#      41     # Train the model for one epoch
# ---> 42     history = model.fit(train_X, train_y, callbacks=[early_stopping, mcp_save],
#      43                     epochs=1, batch_size=2, validation_data=(test_X, test_y),
#      44                      verbose=2,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
1- 0.82 /9.4
2-
3- 0.87/11
4 -0.839/7.168

# %%
# 11 valraibles selected based on the literature produced an an error rate of 5. and r2 95 and four next with 30 lags
# 11 valraibles selected based on the literature produced an an error rate of 9 and r2 81  and two next with 30 lags
# 7 valraibles selected based on the literature produced an an error rate of 6.39 and r2 86   and two next with 30 lags
# 7 valraibles selected based on the literature produced an an error rate of  and r2    and four next with 30 lags

check the1 variables with two next as

# %%
# load the trained saved model
model = tf.keras.models.load_model('/content/drive/MyDrive/my_trained_models/model_700Eps.h5')

# %%
# Load the best weights
model.load_weights(os.path.join(directory, 'mdl_wts.hdf5'))

# %%
# Load the best weights
model_saved.load_weights('/content/drive/MyDrive/my_trained_models/best_lstm_mdl_wts.hdf5')

# %%
model.evaluate(test_X, test_y, verbose=0)
# Out:
# 1.4128429938864429e-05

# %%
score = model.evaluate(test_X, test_y, verbose=0)
best_epoch = loss_tracking.index(score) + 1
# validation loss and corresponding epoch for the saved model
print(f'Epoch:{best_epoch}\nValidation loss: {score}')
# Out:
# Epoch:184
# Validation loss: 1.4128429938864429e-05

# %%
# if training is interrupted 
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5))
early_stopping = EarlyStopping(monitor='loss', patience=10, verbose=2,
                                restore_best_weights=True, mode='min')
# save the best weights if training is interrupted
mcp_save = ModelCheckpoint(os.path.join(directory, 'mdl_wts.hdf5'),
                            save_best_only=True,
                            monitor='val_loss', mode='min') 
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_delta=1e-4, mode='min')

# Set the initial and total number of epochs
initial_epoch = 1
n_epochs = 2000

# Run the training loop
for epoch in range(initial_epoch , n_epochs+1):
    print(f'Epoch {epoch}/{n_epochs}')
    # Train the model for one epoch
    history = model.fit(train_X, train_y, callbacks=[early_stopping, mcp_save, reduce_lr_loss],
                    epochs=1, batch_size=2, validation_data=(test_X, test_y),
                     verbose=2,
                     shuffle=False)
    # to find for which epoch each loss belongs
    validation_loss= model.evaluate(test_X, test_y, verbose=0)
    loss_tracking.append(validation_loss)
    # Save the model every 10 epochs
    if epoch % 50 == 0:
        # Save the model  in HDF5 foramt with a filename that includes the epoch number
        #model.save(f'model_{epoch}Eps.h5')
        model.save(os.path.join(directory, f'model_{epoch}Eps.h5'))
# Out:
# Epoch 1/2000
# 760/760 - 19s - loss: 5.4890e-05 - val_loss: 3.1985e-05 - lr: 1.0000e-05 - 19s/epoch - 25ms/step
# Epoch 2/2000
# 760/760 - 4s - loss: 5.5010e-05 - val_loss: 3.1975e-05 - lr: 1.0000e-05 - 4s/epoch - 6ms/step
# Epoch 3/2000
# 760/760 - 5s - loss: 5.5002e-05 - val_loss: 3.1956e-05 - lr: 1.0000e-05 - 5s/epoch - 7ms/step
# Epoch 4/2000
# 760/760 - 2s - loss: 5.4993e-05 - val_loss: 3.1942e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 5/2000
# 760/760 - 2s - loss: 5.4984e-05 - val_loss: 3.1932e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 6/2000
# 760/760 - 2s - loss: 5.4976e-05 - val_loss: 3.1924e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 7/2000
# 760/760 - 3s - loss: 5.4967e-05 - val_loss: 3.1918e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 8/2000
# 760/760 - 3s - loss: 5.4959e-05 - val_loss: 3.1913e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 9/2000
# 760/760 - 2s - loss: 5.4951e-05 - val_loss: 3.1908e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 10/2000
# 760/760 - 2s - loss: 5.4943e-05 - val_loss: 3.1904e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 11/2000
# 760/760 - 2s - loss: 5.4935e-05 - val_loss: 3.1899e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 12/2000
# 760/760 - 3s - loss: 5.4927e-05 - val_loss: 3.1895e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 13/2000
# 760/760 - 2s - loss: 5.4919e-05 - val_loss: 3.1892e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 14/2000
# 760/760 - 2s - loss: 5.4911e-05 - val_loss: 3.1887e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 15/2000
# 760/760 - 3s - loss: 5.4903e-05 - val_loss: 3.1883e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 16/2000
# 760/760 - 3s - loss: 5.4895e-05 - val_loss: 3.1879e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 17/2000
# 760/760 - 4s - loss: 5.4887e-05 - val_loss: 3.1875e-05 - lr: 1.0000e-05 - 4s/epoch - 5ms/step
# Epoch 18/2000
# 760/760 - 3s - loss: 5.4879e-05 - val_loss: 3.1872e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 19/2000
# 760/760 - 2s - loss: 5.4871e-05 - val_loss: 3.1868e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 20/2000
# 760/760 - 2s - loss: 5.4863e-05 - val_loss: 3.1864e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 21/2000
# 760/760 - 2s - loss: 5.4855e-05 - val_loss: 3.1860e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 22/2000
# 760/760 - 2s - loss: 5.4847e-05 - val_loss: 3.1856e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 23/2000
# 760/760 - 2s - loss: 5.4839e-05 - val_loss: 3.1852e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 24/2000
# 760/760 - 2s - loss: 5.4831e-05 - val_loss: 3.1849e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 25/2000
# 760/760 - 3s - loss: 5.4824e-05 - val_loss: 3.1845e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 26/2000
# 760/760 - 2s - loss: 5.4816e-05 - val_loss: 3.1841e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 27/2000
# 760/760 - 2s - loss: 5.4808e-05 - val_loss: 3.1837e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 28/2000
# 760/760 - 2s - loss: 5.4800e-05 - val_loss: 3.1833e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 29/2000
# 760/760 - 2s - loss: 5.4792e-05 - val_loss: 3.1830e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 30/2000
# 760/760 - 3s - loss: 5.4784e-05 - val_loss: 3.1826e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 31/2000
# 760/760 - 2s - loss: 5.4776e-05 - val_loss: 3.1822e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 32/2000
# 760/760 - 2s - loss: 5.4769e-05 - val_loss: 3.1819e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 33/2000
# 760/760 - 2s - loss: 5.4761e-05 - val_loss: 3.1815e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 34/2000
# 760/760 - 2s - loss: 5.4753e-05 - val_loss: 3.1811e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 35/2000
# 760/760 - 2s - loss: 5.4745e-05 - val_loss: 3.1808e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 36/2000
# 760/760 - 2s - loss: 5.4737e-05 - val_loss: 3.1804e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 37/2000
# 760/760 - 2s - loss: 5.4730e-05 - val_loss: 3.1801e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 38/2000
# 760/760 - 2s - loss: 5.4722e-05 - val_loss: 3.1797e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 39/2000
# 760/760 - 2s - loss: 5.4714e-05 - val_loss: 3.1794e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 40/2000
# 760/760 - 2s - loss: 5.4706e-05 - val_loss: 3.1790e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 41/2000
# 760/760 - 2s - loss: 5.4699e-05 - val_loss: 3.1787e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 42/2000
# 760/760 - 2s - loss: 5.4691e-05 - val_loss: 3.1783e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 43/2000
# 760/760 - 2s - loss: 5.4683e-05 - val_loss: 3.1780e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 44/2000
# 760/760 - 2s - loss: 5.4675e-05 - val_loss: 3.1777e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 45/2000
# 760/760 - 2s - loss: 5.4668e-05 - val_loss: 3.1773e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 46/2000
# 760/760 - 2s - loss: 5.4660e-05 - val_loss: 3.1770e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 47/2000
# 760/760 - 2s - loss: 5.4652e-05 - val_loss: 3.1766e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 48/2000
# 760/760 - 2s - loss: 5.4644e-05 - val_loss: 3.1763e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 49/2000
# 760/760 - 2s - loss: 5.4637e-05 - val_loss: 3.1760e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 50/2000
# 760/760 - 2s - loss: 5.4629e-05 - val_loss: 3.1756e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 51/2000
# 760/760 - 2s - loss: 5.4621e-05 - val_loss: 3.1752e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 52/2000
# 760/760 - 2s - loss: 5.4613e-05 - val_loss: 3.1749e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 53/2000
# 760/760 - 2s - loss: 5.4606e-05 - val_loss: 3.1746e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 54/2000
# 760/760 - 2s - loss: 5.4598e-05 - val_loss: 3.1742e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 55/2000
# 760/760 - 2s - loss: 5.4590e-05 - val_loss: 3.1739e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 56/2000
# 760/760 - 2s - loss: 5.4583e-05 - val_loss: 3.1735e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 57/2000
# 760/760 - 2s - loss: 5.4575e-05 - val_loss: 3.1732e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 58/2000
# 760/760 - 2s - loss: 5.4567e-05 - val_loss: 3.1729e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 59/2000
# 760/760 - 4s - loss: 5.4560e-05 - val_loss: 3.1725e-05 - lr: 1.0000e-05 - 4s/epoch - 5ms/step
# Epoch 60/2000
# 760/760 - 2s - loss: 5.4552e-05 - val_loss: 3.1722e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 61/2000
# 760/760 - 2s - loss: 5.4544e-05 - val_loss: 3.1719e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 62/2000
# 760/760 - 2s - loss: 5.4537e-05 - val_loss: 3.1715e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 63/2000
# 760/760 - 2s - loss: 5.4529e-05 - val_loss: 3.1712e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 64/2000
# 760/760 - 2s - loss: 5.4521e-05 - val_loss: 3.1709e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 65/2000
# 760/760 - 2s - loss: 5.4514e-05 - val_loss: 3.1705e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 66/2000
# 760/760 - 2s - loss: 5.4506e-05 - val_loss: 3.1702e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 67/2000
# 760/760 - 2s - loss: 5.4499e-05 - val_loss: 3.1699e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 68/2000
# 760/760 - 2s - loss: 5.4491e-05 - val_loss: 3.1696e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 69/2000
# 760/760 - 2s - loss: 5.4483e-05 - val_loss: 3.1692e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 70/2000
# 760/760 - 2s - loss: 5.4476e-05 - val_loss: 3.1689e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 71/2000
# 760/760 - 2s - loss: 5.4468e-05 - val_loss: 3.1686e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 72/2000
# 760/760 - 2s - loss: 5.4461e-05 - val_loss: 3.1683e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 73/2000
# 760/760 - 2s - loss: 5.4453e-05 - val_loss: 3.1679e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 74/2000
# 760/760 - 3s - loss: 5.4445e-05 - val_loss: 3.1676e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 75/2000
# 760/760 - 4s - loss: 5.4438e-05 - val_loss: 3.1673e-05 - lr: 1.0000e-05 - 4s/epoch - 5ms/step
# Epoch 76/2000
# 760/760 - 2s - loss: 5.4430e-05 - val_loss: 3.1670e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 77/2000
# 760/760 - 2s - loss: 5.4423e-05 - val_loss: 3.1667e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 78/2000
# 760/760 - 2s - loss: 5.4415e-05 - val_loss: 3.1664e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 79/2000
# 760/760 - 2s - loss: 5.4408e-05 - val_loss: 3.1661e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 80/2000
# 760/760 - 2s - loss: 5.4400e-05 - val_loss: 3.1658e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 81/2000
# 760/760 - 2s - loss: 5.4393e-05 - val_loss: 3.1655e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 82/2000
# 760/760 - 2s - loss: 5.4385e-05 - val_loss: 3.1652e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 83/2000
# 760/760 - 2s - loss: 5.4378e-05 - val_loss: 3.1649e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 84/2000
# 760/760 - 2s - loss: 5.4370e-05 - val_loss: 3.1645e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 85/2000
# 760/760 - 2s - loss: 5.4363e-05 - val_loss: 3.1642e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 86/2000
# 760/760 - 2s - loss: 5.4355e-05 - val_loss: 3.1639e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 87/2000
# 760/760 - 2s - loss: 5.4348e-05 - val_loss: 3.1636e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 88/2000
# 760/760 - 2s - loss: 5.4340e-05 - val_loss: 3.1633e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 89/2000
# 760/760 - 2s - loss: 5.4333e-05 - val_loss: 3.1629e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 90/2000
# 760/760 - 3s - loss: 5.4326e-05 - val_loss: 3.1626e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 91/2000
# 760/760 - 2s - loss: 5.4318e-05 - val_loss: 3.1623e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 92/2000
# 760/760 - 3s - loss: 5.4311e-05 - val_loss: 3.1620e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 93/2000
# 760/760 - 3s - loss: 5.4303e-05 - val_loss: 3.1616e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 94/2000
# 760/760 - 2s - loss: 5.4296e-05 - val_loss: 3.1613e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 95/2000
# 760/760 - 3s - loss: 5.4288e-05 - val_loss: 3.1610e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 96/2000
# 760/760 - 2s - loss: 5.4281e-05 - val_loss: 3.1607e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 97/2000
# 760/760 - 2s - loss: 5.4273e-05 - val_loss: 3.1604e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 98/2000
# 760/760 - 2s - loss: 5.4266e-05 - val_loss: 3.1601e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 99/2000
# 760/760 - 2s - loss: 5.4259e-05 - val_loss: 3.1598e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 100/2000
# 760/760 - 3s - loss: 5.4251e-05 - val_loss: 3.1595e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 101/2000
# 760/760 - 3s - loss: 5.4244e-05 - val_loss: 3.1592e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 102/2000
# 760/760 - 3s - loss: 5.4236e-05 - val_loss: 3.1589e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 103/2000
# 760/760 - 3s - loss: 5.4229e-05 - val_loss: 3.1586e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 104/2000
# 760/760 - 3s - loss: 5.4222e-05 - val_loss: 3.1583e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 105/2000
# 760/760 - 2s - loss: 5.4214e-05 - val_loss: 3.1580e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 106/2000
# 760/760 - 3s - loss: 5.4207e-05 - val_loss: 3.1577e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 107/2000
# 760/760 - 2s - loss: 5.4200e-05 - val_loss: 3.1574e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 108/2000
# 760/760 - 2s - loss: 5.4192e-05 - val_loss: 3.1571e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 109/2000
# 760/760 - 2s - loss: 5.4185e-05 - val_loss: 3.1568e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 110/2000
# 760/760 - 2s - loss: 5.4178e-05 - val_loss: 3.1565e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 111/2000
# 760/760 - 2s - loss: 5.4170e-05 - val_loss: 3.1562e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 112/2000
# 760/760 - 2s - loss: 5.4163e-05 - val_loss: 3.1559e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 113/2000
# 760/760 - 2s - loss: 5.4156e-05 - val_loss: 3.1556e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 114/2000
# 760/760 - 2s - loss: 5.4148e-05 - val_loss: 3.1553e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 115/2000
# 760/760 - 2s - loss: 5.4141e-05 - val_loss: 3.1550e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 116/2000
# 760/760 - 2s - loss: 5.4134e-05 - val_loss: 3.1548e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 117/2000
# 760/760 - 2s - loss: 5.4126e-05 - val_loss: 3.1545e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 118/2000
# 760/760 - 2s - loss: 5.4119e-05 - val_loss: 3.1542e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 119/2000
# 760/760 - 2s - loss: 5.4112e-05 - val_loss: 3.1540e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 120/2000
# 760/760 - 2s - loss: 5.4104e-05 - val_loss: 3.1537e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 121/2000
# 760/760 - 2s - loss: 5.4097e-05 - val_loss: 3.1534e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 122/2000
# 760/760 - 2s - loss: 5.4090e-05 - val_loss: 3.1531e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 123/2000
# 760/760 - 2s - loss: 5.4083e-05 - val_loss: 3.1529e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 124/2000
# 760/760 - 2s - loss: 5.4075e-05 - val_loss: 3.1526e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 125/2000
# 760/760 - 2s - loss: 5.4068e-05 - val_loss: 3.1523e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 126/2000
# 760/760 - 2s - loss: 5.4061e-05 - val_loss: 3.1520e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 127/2000
# 760/760 - 2s - loss: 5.4054e-05 - val_loss: 3.1518e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 128/2000
# 760/760 - 2s - loss: 5.4046e-05 - val_loss: 3.1515e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 129/2000
# 760/760 - 2s - loss: 5.4039e-05 - val_loss: 3.1512e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 130/2000
# 760/760 - 2s - loss: 5.4032e-05 - val_loss: 3.1510e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 131/2000
# 760/760 - 2s - loss: 5.4025e-05 - val_loss: 3.1507e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 132/2000
# 760/760 - 3s - loss: 5.4018e-05 - val_loss: 3.1504e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 133/2000
# 760/760 - 2s - loss: 5.4010e-05 - val_loss: 3.1501e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 134/2000
# 760/760 - 2s - loss: 5.4003e-05 - val_loss: 3.1499e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 135/2000
# 760/760 - 2s - loss: 5.3996e-05 - val_loss: 3.1496e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 136/2000
# 760/760 - 3s - loss: 5.3989e-05 - val_loss: 3.1493e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 137/2000
# 760/760 - 2s - loss: 5.3982e-05 - val_loss: 3.1491e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 138/2000
# 760/760 - 2s - loss: 5.3974e-05 - val_loss: 3.1488e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 139/2000
# 760/760 - 2s - loss: 5.3967e-05 - val_loss: 3.1485e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 140/2000
# 760/760 - 2s - loss: 5.3960e-05 - val_loss: 3.1483e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 141/2000
# 760/760 - 2s - loss: 5.3953e-05 - val_loss: 3.1480e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 142/2000
# 760/760 - 2s - loss: 5.3946e-05 - val_loss: 3.1477e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 143/2000
# 760/760 - 2s - loss: 5.3939e-05 - val_loss: 3.1475e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 144/2000
# 760/760 - 2s - loss: 5.3931e-05 - val_loss: 3.1472e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 145/2000
# 760/760 - 2s - loss: 5.3924e-05 - val_loss: 3.1469e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 146/2000
# 760/760 - 2s - loss: 5.3917e-05 - val_loss: 3.1467e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 147/2000
# 760/760 - 2s - loss: 5.3910e-05 - val_loss: 3.1464e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 148/2000
# 760/760 - 2s - loss: 5.3903e-05 - val_loss: 3.1462e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 149/2000
# 760/760 - 2s - loss: 5.3896e-05 - val_loss: 3.1459e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 150/2000
# 760/760 - 2s - loss: 5.3889e-05 - val_loss: 3.1456e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 151/2000
# 760/760 - 2s - loss: 5.3881e-05 - val_loss: 3.1454e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 152/2000
# 760/760 - 2s - loss: 5.3874e-05 - val_loss: 3.1451e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 153/2000
# 760/760 - 2s - loss: 5.3867e-05 - val_loss: 3.1449e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 154/2000
# 760/760 - 2s - loss: 5.3860e-05 - val_loss: 3.1446e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 155/2000
# 760/760 - 2s - loss: 5.3853e-05 - val_loss: 3.1444e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 156/2000
# 760/760 - 3s - loss: 5.3846e-05 - val_loss: 3.1441e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 157/2000
# 760/760 - 2s - loss: 5.3839e-05 - val_loss: 3.1439e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 158/2000
# 760/760 - 2s - loss: 5.3832e-05 - val_loss: 3.1436e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 159/2000
# 760/760 - 2s - loss: 5.3825e-05 - val_loss: 3.1434e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 160/2000
# 760/760 - 2s - loss: 5.3818e-05 - val_loss: 3.1431e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 161/2000
# 760/760 - 2s - loss: 5.3811e-05 - val_loss: 3.1429e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 162/2000
# 760/760 - 4s - loss: 5.3804e-05 - val_loss: 3.1427e-05 - lr: 1.0000e-05 - 4s/epoch - 5ms/step
# Epoch 163/2000
# 760/760 - 3s - loss: 5.3797e-05 - val_loss: 3.1424e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 164/2000
# 760/760 - 2s - loss: 5.3790e-05 - val_loss: 3.1422e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 165/2000
# 760/760 - 2s - loss: 5.3783e-05 - val_loss: 3.1420e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 166/2000
# 760/760 - 2s - loss: 5.3776e-05 - val_loss: 3.1417e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 167/2000
# 760/760 - 2s - loss: 5.3769e-05 - val_loss: 3.1415e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 168/2000
# 760/760 - 3s - loss: 5.3762e-05 - val_loss: 3.1413e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 169/2000
# 760/760 - 2s - loss: 5.3755e-05 - val_loss: 3.1410e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 170/2000
# 760/760 - 2s - loss: 5.3748e-05 - val_loss: 3.1408e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 171/2000
# 760/760 - 2s - loss: 5.3741e-05 - val_loss: 3.1405e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 172/2000
# 760/760 - 2s - loss: 5.3734e-05 - val_loss: 3.1403e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 173/2000
# 760/760 - 2s - loss: 5.3727e-05 - val_loss: 3.1400e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 174/2000
# 760/760 - 2s - loss: 5.3720e-05 - val_loss: 3.1398e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 175/2000
# 760/760 - 2s - loss: 5.3713e-05 - val_loss: 3.1396e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 176/2000
# 760/760 - 2s - loss: 5.3706e-05 - val_loss: 3.1393e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 177/2000
# 760/760 - 3s - loss: 5.3699e-05 - val_loss: 3.1391e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 178/2000
# 760/760 - 2s - loss: 5.3692e-05 - val_loss: 3.1389e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 179/2000
# 760/760 - 3s - loss: 5.3685e-05 - val_loss: 3.1387e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 180/2000
# 760/760 - 3s - loss: 5.3678e-05 - val_loss: 3.1385e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 181/2000
# 760/760 - 3s - loss: 5.3671e-05 - val_loss: 3.1382e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 182/2000
# 760/760 - 2s - loss: 5.3664e-05 - val_loss: 3.1380e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 183/2000
# 760/760 - 3s - loss: 5.3657e-05 - val_loss: 3.1378e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 184/2000
# 760/760 - 3s - loss: 5.3650e-05 - val_loss: 3.1376e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 185/2000
# 760/760 - 2s - loss: 5.3643e-05 - val_loss: 3.1374e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 186/2000
# 760/760 - 2s - loss: 5.3637e-05 - val_loss: 3.1371e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 187/2000
# 760/760 - 3s - loss: 5.3630e-05 - val_loss: 3.1369e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 188/2000
# 760/760 - 3s - loss: 5.3623e-05 - val_loss: 3.1367e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 189/2000
# 760/760 - 3s - loss: 5.3616e-05 - val_loss: 3.1365e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 190/2000
# 760/760 - 3s - loss: 5.3609e-05 - val_loss: 3.1363e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 191/2000
# 760/760 - 2s - loss: 5.3602e-05 - val_loss: 3.1361e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 192/2000
# 760/760 - 2s - loss: 5.3595e-05 - val_loss: 3.1359e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 193/2000
# 760/760 - 2s - loss: 5.3588e-05 - val_loss: 3.1356e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 194/2000
# 760/760 - 2s - loss: 5.3581e-05 - val_loss: 3.1354e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 195/2000
# 760/760 - 2s - loss: 5.3574e-05 - val_loss: 3.1352e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 196/2000
# 760/760 - 2s - loss: 5.3568e-05 - val_loss: 3.1350e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 197/2000
# 760/760 - 2s - loss: 5.3561e-05 - val_loss: 3.1348e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 198/2000
# 760/760 - 2s - loss: 5.3554e-05 - val_loss: 3.1346e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 199/2000
# 760/760 - 2s - loss: 5.3547e-05 - val_loss: 3.1344e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 200/2000
# 760/760 - 2s - loss: 5.3540e-05 - val_loss: 3.1341e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 201/2000
# 760/760 - 2s - loss: 5.3533e-05 - val_loss: 3.1339e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 202/2000
# 760/760 - 2s - loss: 5.3526e-05 - val_loss: 3.1337e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 203/2000
# 760/760 - 2s - loss: 5.3520e-05 - val_loss: 3.1335e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 204/2000
# 760/760 - 2s - loss: 5.3513e-05 - val_loss: 3.1333e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 205/2000
# 760/760 - 2s - loss: 5.3506e-05 - val_loss: 3.1331e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 206/2000
# 760/760 - 2s - loss: 5.3499e-05 - val_loss: 3.1329e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 207/2000
# 760/760 - 2s - loss: 5.3492e-05 - val_loss: 3.1327e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 208/2000
# 760/760 - 2s - loss: 5.3486e-05 - val_loss: 3.1325e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 209/2000
# 760/760 - 2s - loss: 5.3479e-05 - val_loss: 3.1323e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 210/2000
# 760/760 - 2s - loss: 5.3472e-05 - val_loss: 3.1321e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 211/2000
# 760/760 - 2s - loss: 5.3465e-05 - val_loss: 3.1319e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 212/2000
# 760/760 - 2s - loss: 5.3458e-05 - val_loss: 3.1317e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 213/2000
# 760/760 - 2s - loss: 5.3452e-05 - val_loss: 3.1315e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 214/2000
# 760/760 - 2s - loss: 5.3445e-05 - val_loss: 3.1313e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 215/2000
# 760/760 - 3s - loss: 5.3438e-05 - val_loss: 3.1311e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 216/2000
# 760/760 - 2s - loss: 5.3431e-05 - val_loss: 3.1309e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 217/2000
# 760/760 - 2s - loss: 5.3425e-05 - val_loss: 3.1308e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 218/2000
# 760/760 - 2s - loss: 5.3418e-05 - val_loss: 3.1306e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 219/2000
# 760/760 - 2s - loss: 5.3411e-05 - val_loss: 3.1304e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 220/2000
# 760/760 - 2s - loss: 5.3404e-05 - val_loss: 3.1302e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 221/2000
# 760/760 - 2s - loss: 5.3398e-05 - val_loss: 3.1300e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 222/2000
# 760/760 - 3s - loss: 5.3391e-05 - val_loss: 3.1298e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 223/2000
# 760/760 - 2s - loss: 5.3384e-05 - val_loss: 3.1297e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 224/2000
# 760/760 - 2s - loss: 5.3377e-05 - val_loss: 3.1295e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 225/2000
# 760/760 - 2s - loss: 5.3371e-05 - val_loss: 3.1293e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 226/2000
# 760/760 - 2s - loss: 5.3364e-05 - val_loss: 3.1291e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 227/2000
# 760/760 - 2s - loss: 5.3357e-05 - val_loss: 3.1289e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 228/2000
# 760/760 - 2s - loss: 5.3351e-05 - val_loss: 3.1287e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 229/2000
# 760/760 - 2s - loss: 5.3344e-05 - val_loss: 3.1286e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 230/2000
# 760/760 - 2s - loss: 5.3337e-05 - val_loss: 3.1284e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 231/2000
# 760/760 - 2s - loss: 5.3331e-05 - val_loss: 3.1282e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 232/2000
# 760/760 - 2s - loss: 5.3324e-05 - val_loss: 3.1280e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 233/2000
# 760/760 - 2s - loss: 5.3317e-05 - val_loss: 3.1278e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 234/2000
# 760/760 - 2s - loss: 5.3310e-05 - val_loss: 3.1277e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 235/2000
# 760/760 - 2s - loss: 5.3304e-05 - val_loss: 3.1275e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 236/2000
# 760/760 - 2s - loss: 5.3297e-05 - val_loss: 3.1273e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 237/2000
# 760/760 - 2s - loss: 5.3291e-05 - val_loss: 3.1271e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 238/2000
# 760/760 - 2s - loss: 5.3284e-05 - val_loss: 3.1270e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 239/2000
# 760/760 - 2s - loss: 5.3277e-05 - val_loss: 3.1268e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 240/2000
# 760/760 - 2s - loss: 5.3271e-05 - val_loss: 3.1266e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 241/2000
# 760/760 - 2s - loss: 5.3264e-05 - val_loss: 3.1265e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 242/2000
# 760/760 - 2s - loss: 5.3257e-05 - val_loss: 3.1263e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 243/2000
# 760/760 - 2s - loss: 5.3251e-05 - val_loss: 3.1261e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 244/2000
# 760/760 - 2s - loss: 5.3244e-05 - val_loss: 3.1260e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 245/2000
# 760/760 - 2s - loss: 5.3237e-05 - val_loss: 3.1258e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 246/2000
# 760/760 - 2s - loss: 5.3231e-05 - val_loss: 3.1256e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 247/2000
# 760/760 - 2s - loss: 5.3224e-05 - val_loss: 3.1255e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 248/2000
# 760/760 - 2s - loss: 5.3218e-05 - val_loss: 3.1253e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 249/2000
# 760/760 - 2s - loss: 5.3211e-05 - val_loss: 3.1251e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 250/2000
# 760/760 - 3s - loss: 5.3205e-05 - val_loss: 3.1250e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 251/2000
# 760/760 - 3s - loss: 5.3198e-05 - val_loss: 3.1248e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 252/2000
# 760/760 - 2s - loss: 5.3191e-05 - val_loss: 3.1247e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 253/2000
# 760/760 - 2s - loss: 5.3185e-05 - val_loss: 3.1245e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 254/2000
# 760/760 - 2s - loss: 5.3178e-05 - val_loss: 3.1244e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 255/2000
# 760/760 - 2s - loss: 5.3172e-05 - val_loss: 3.1242e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 256/2000
# 760/760 - 2s - loss: 5.3165e-05 - val_loss: 3.1240e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 257/2000
# 760/760 - 3s - loss: 5.3158e-05 - val_loss: 3.1239e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 258/2000
# 760/760 - 2s - loss: 5.3152e-05 - val_loss: 3.1237e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 259/2000
# 760/760 - 2s - loss: 5.3145e-05 - val_loss: 3.1236e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 260/2000
# 760/760 - 2s - loss: 5.3139e-05 - val_loss: 3.1234e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 261/2000
# 760/760 - 3s - loss: 5.3132e-05 - val_loss: 3.1232e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 262/2000
# 760/760 - 2s - loss: 5.3126e-05 - val_loss: 3.1231e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 263/2000
# 760/760 - 2s - loss: 5.3119e-05 - val_loss: 3.1229e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 264/2000
# 760/760 - 2s - loss: 5.3113e-05 - val_loss: 3.1228e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 265/2000
# 760/760 - 2s - loss: 5.3106e-05 - val_loss: 3.1226e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 266/2000
# 760/760 - 2s - loss: 5.3100e-05 - val_loss: 3.1224e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 267/2000
# 760/760 - 3s - loss: 5.3093e-05 - val_loss: 3.1222e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 268/2000
# 760/760 - 3s - loss: 5.3087e-05 - val_loss: 3.1221e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 269/2000
# 760/760 - 3s - loss: 5.3080e-05 - val_loss: 3.1219e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 270/2000
# 760/760 - 2s - loss: 5.3074e-05 - val_loss: 3.1218e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 271/2000
# 760/760 - 3s - loss: 5.3067e-05 - val_loss: 3.1216e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 272/2000
# 760/760 - 2s - loss: 5.3061e-05 - val_loss: 3.1214e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 273/2000
# 760/760 - 3s - loss: 5.3054e-05 - val_loss: 3.1213e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 274/2000
# 760/760 - 2s - loss: 5.3048e-05 - val_loss: 3.1211e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 275/2000
# 760/760 - 2s - loss: 5.3041e-05 - val_loss: 3.1210e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 276/2000
# 760/760 - 3s - loss: 5.3035e-05 - val_loss: 3.1209e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 277/2000
# 760/760 - 3s - loss: 5.3028e-05 - val_loss: 3.1207e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 278/2000
# 760/760 - 2s - loss: 5.3022e-05 - val_loss: 3.1206e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 279/2000
# 760/760 - 2s - loss: 5.3015e-05 - val_loss: 3.1205e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 280/2000
# 760/760 - 3s - loss: 5.3009e-05 - val_loss: 3.1203e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 281/2000
# 760/760 - 2s - loss: 5.3003e-05 - val_loss: 3.1202e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 282/2000
# 760/760 - 2s - loss: 5.2996e-05 - val_loss: 3.1200e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 283/2000
# 760/760 - 3s - loss: 5.2990e-05 - val_loss: 3.1199e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 284/2000
# 760/760 - 2s - loss: 5.2983e-05 - val_loss: 3.1197e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 285/2000
# 760/760 - 2s - loss: 5.2977e-05 - val_loss: 3.1196e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 286/2000
# 760/760 - 2s - loss: 5.2970e-05 - val_loss: 3.1194e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 287/2000
# 760/760 - 2s - loss: 5.2964e-05 - val_loss: 3.1193e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 288/2000
# 760/760 - 2s - loss: 5.2958e-05 - val_loss: 3.1191e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 289/2000
# 760/760 - 2s - loss: 5.2951e-05 - val_loss: 3.1190e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 290/2000
# 760/760 - 2s - loss: 5.2945e-05 - val_loss: 3.1188e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 291/2000
# 760/760 - 3s - loss: 5.2938e-05 - val_loss: 3.1187e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 292/2000
# 760/760 - 2s - loss: 5.2932e-05 - val_loss: 3.1185e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 293/2000
# 760/760 - 2s - loss: 5.2926e-05 - val_loss: 3.1184e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 294/2000
# 760/760 - 2s - loss: 5.2919e-05 - val_loss: 3.1182e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 295/2000
# 760/760 - 2s - loss: 5.2913e-05 - val_loss: 3.1181e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 296/2000
# 760/760 - 2s - loss: 5.2906e-05 - val_loss: 3.1180e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 297/2000
# 760/760 - 2s - loss: 5.2900e-05 - val_loss: 3.1178e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 298/2000
# 760/760 - 2s - loss: 5.2894e-05 - val_loss: 3.1177e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 299/2000
# 760/760 - 2s - loss: 5.2887e-05 - val_loss: 3.1176e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 300/2000
# 760/760 - 3s - loss: 5.2881e-05 - val_loss: 3.1175e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 301/2000
# 760/760 - 2s - loss: 5.2875e-05 - val_loss: 3.1174e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 302/2000
# 760/760 - 2s - loss: 5.2868e-05 - val_loss: 3.1173e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 303/2000
# 760/760 - 2s - loss: 5.2862e-05 - val_loss: 3.1171e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 304/2000
# 760/760 - 2s - loss: 5.2856e-05 - val_loss: 3.1170e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 305/2000
# 760/760 - 2s - loss: 5.2849e-05 - val_loss: 3.1169e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 306/2000
# 760/760 - 2s - loss: 5.2843e-05 - val_loss: 3.1168e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 307/2000
# 760/760 - 2s - loss: 5.2837e-05 - val_loss: 3.1166e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 308/2000
# 760/760 - 2s - loss: 5.2830e-05 - val_loss: 3.1165e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 309/2000
# 760/760 - 2s - loss: 5.2824e-05 - val_loss: 3.1164e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 310/2000
# 760/760 - 3s - loss: 5.2818e-05 - val_loss: 3.1162e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 311/2000
# 760/760 - 2s - loss: 5.2811e-05 - val_loss: 3.1161e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 312/2000
# 760/760 - 2s - loss: 5.2805e-05 - val_loss: 3.1160e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 313/2000
# 760/760 - 2s - loss: 5.2799e-05 - val_loss: 3.1159e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 314/2000
# 760/760 - 2s - loss: 5.2792e-05 - val_loss: 3.1157e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 315/2000
# 760/760 - 2s - loss: 5.2786e-05 - val_loss: 3.1156e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 316/2000
# 760/760 - 2s - loss: 5.2780e-05 - val_loss: 3.1155e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 317/2000
# 760/760 - 2s - loss: 5.2774e-05 - val_loss: 3.1154e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 318/2000
# 760/760 - 2s - loss: 5.2767e-05 - val_loss: 3.1152e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 319/2000
# 760/760 - 2s - loss: 5.2761e-05 - val_loss: 3.1151e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 320/2000
# 760/760 - 2s - loss: 5.2755e-05 - val_loss: 3.1150e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 321/2000
# 760/760 - 2s - loss: 5.2748e-05 - val_loss: 3.1149e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 322/2000
# 760/760 - 2s - loss: 5.2742e-05 - val_loss: 3.1147e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 323/2000
# 760/760 - 2s - loss: 5.2736e-05 - val_loss: 3.1146e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 324/2000
# 760/760 - 2s - loss: 5.2730e-05 - val_loss: 3.1145e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 325/2000
# 760/760 - 2s - loss: 5.2723e-05 - val_loss: 3.1144e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 326/2000
# 760/760 - 2s - loss: 5.2717e-05 - val_loss: 3.1143e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 327/2000
# 760/760 - 2s - loss: 5.2711e-05 - val_loss: 3.1141e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 328/2000
# 760/760 - 2s - loss: 5.2705e-05 - val_loss: 3.1140e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 329/2000
# 760/760 - 2s - loss: 5.2699e-05 - val_loss: 3.1139e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 330/2000
# 760/760 - 2s - loss: 5.2692e-05 - val_loss: 3.1138e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 331/2000
# 760/760 - 2s - loss: 5.2686e-05 - val_loss: 3.1137e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 332/2000
# 760/760 - 2s - loss: 5.2680e-05 - val_loss: 3.1135e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 333/2000
# 760/760 - 2s - loss: 5.2674e-05 - val_loss: 3.1134e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 334/2000
# 760/760 - 3s - loss: 5.2668e-05 - val_loss: 3.1133e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 335/2000
# 760/760 - 3s - loss: 5.2661e-05 - val_loss: 3.1132e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 336/2000
# 760/760 - 3s - loss: 5.2655e-05 - val_loss: 3.1131e-05 - lr: 1.0000e-05 - 3s/epoch - 5ms/step
# Epoch 337/2000
# 760/760 - 2s - loss: 5.2649e-05 - val_loss: 3.1129e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 338/2000
# 760/760 - 2s - loss: 5.2643e-05 - val_loss: 3.1128e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 339/2000
# 760/760 - 2s - loss: 5.2637e-05 - val_loss: 3.1127e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 340/2000
# 760/760 - 2s - loss: 5.2630e-05 - val_loss: 3.1126e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 341/2000
# 760/760 - 2s - loss: 5.2624e-05 - val_loss: 3.1125e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 342/2000
# 760/760 - 2s - loss: 5.2618e-05 - val_loss: 3.1124e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 343/2000
# 760/760 - 2s - loss: 5.2612e-05 - val_loss: 3.1123e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 344/2000
# 760/760 - 2s - loss: 5.2606e-05 - val_loss: 3.1122e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 345/2000
# 760/760 - 2s - loss: 5.2599e-05 - val_loss: 3.1121e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 346/2000
# 760/760 - 2s - loss: 5.2593e-05 - val_loss: 3.1120e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 347/2000
# 760/760 - 3s - loss: 5.2587e-05 - val_loss: 3.1119e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 348/2000
# 760/760 - 2s - loss: 5.2581e-05 - val_loss: 3.1118e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 349/2000
# 760/760 - 2s - loss: 5.2575e-05 - val_loss: 3.1118e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 350/2000
# 760/760 - 2s - loss: 5.2569e-05 - val_loss: 3.1117e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 351/2000
# 760/760 - 2s - loss: 5.2563e-05 - val_loss: 3.1116e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 352/2000
# 760/760 - 3s - loss: 5.2556e-05 - val_loss: 3.1115e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 353/2000
# 760/760 - 2s - loss: 5.2550e-05 - val_loss: 3.1114e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 354/2000
# 760/760 - 2s - loss: 5.2544e-05 - val_loss: 3.1113e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 355/2000
# 760/760 - 3s - loss: 5.2538e-05 - val_loss: 3.1112e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 356/2000
# 760/760 - 3s - loss: 5.2532e-05 - val_loss: 3.1111e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 357/2000
# 760/760 - 2s - loss: 5.2526e-05 - val_loss: 3.1110e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 358/2000
# 760/760 - 3s - loss: 5.2520e-05 - val_loss: 3.1109e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 359/2000
# 760/760 - 3s - loss: 5.2514e-05 - val_loss: 3.1108e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 360/2000
# 760/760 - 3s - loss: 5.2508e-05 - val_loss: 3.1107e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 361/2000
# 760/760 - 2s - loss: 5.2501e-05 - val_loss: 3.1106e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 362/2000
# 760/760 - 2s - loss: 5.2495e-05 - val_loss: 3.1105e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 363/2000
# 760/760 - 3s - loss: 5.2489e-05 - val_loss: 3.1104e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 364/2000
# 760/760 - 3s - loss: 5.2483e-05 - val_loss: 3.1103e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 365/2000
# 760/760 - 3s - loss: 5.2477e-05 - val_loss: 3.1102e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 366/2000
# 760/760 - 3s - loss: 5.2471e-05 - val_loss: 3.1101e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 367/2000
# 760/760 - 2s - loss: 5.2465e-05 - val_loss: 3.1100e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 368/2000
# 760/760 - 3s - loss: 5.2459e-05 - val_loss: 3.1099e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 369/2000
# 760/760 - 2s - loss: 5.2453e-05 - val_loss: 3.1098e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 370/2000
# 760/760 - 2s - loss: 5.2447e-05 - val_loss: 3.1097e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 371/2000
# 760/760 - 2s - loss: 5.2441e-05 - val_loss: 3.1096e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 372/2000
# 760/760 - 3s - loss: 5.2435e-05 - val_loss: 3.1095e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 373/2000
# 760/760 - 2s - loss: 5.2429e-05 - val_loss: 3.1094e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 374/2000
# 760/760 - 2s - loss: 5.2422e-05 - val_loss: 3.1093e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 375/2000
# 760/760 - 2s - loss: 5.2416e-05 - val_loss: 3.1092e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 376/2000
# 760/760 - 2s - loss: 5.2410e-05 - val_loss: 3.1091e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 377/2000
# 760/760 - 2s - loss: 5.2404e-05 - val_loss: 3.1090e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 378/2000
# 760/760 - 2s - loss: 5.2398e-05 - val_loss: 3.1089e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 379/2000
# 760/760 - 2s - loss: 5.2392e-05 - val_loss: 3.1088e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 380/2000
# 760/760 - 2s - loss: 5.2386e-05 - val_loss: 3.1088e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 381/2000
# 760/760 - 2s - loss: 5.2380e-05 - val_loss: 3.1087e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 382/2000
# 760/760 - 2s - loss: 5.2374e-05 - val_loss: 3.1086e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 383/2000
# 760/760 - 3s - loss: 5.2368e-05 - val_loss: 3.1085e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 384/2000
# 760/760 - 2s - loss: 5.2362e-05 - val_loss: 3.1084e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 385/2000
# 760/760 - 2s - loss: 5.2356e-05 - val_loss: 3.1083e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 386/2000
# 760/760 - 2s - loss: 5.2350e-05 - val_loss: 3.1082e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 387/2000
# 760/760 - 2s - loss: 5.2344e-05 - val_loss: 3.1082e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 388/2000
# 760/760 - 3s - loss: 5.2338e-05 - val_loss: 3.1081e-05 - lr: 1.0000e-05 - 3s/epoch - 3ms/step
# Epoch 389/2000
# 760/760 - 2s - loss: 5.2332e-05 - val_loss: 3.1080e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 390/2000
# 760/760 - 2s - loss: 5.2326e-05 - val_loss: 3.1079e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 391/2000
# 760/760 - 2s - loss: 5.2320e-05 - val_loss: 3.1079e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 392/2000
# 760/760 - 3s - loss: 5.2314e-05 - val_loss: 3.1078e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 393/2000
# 760/760 - 2s - loss: 5.2308e-05 - val_loss: 3.1077e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 394/2000
# 760/760 - 3s - loss: 5.2303e-05 - val_loss: 3.1076e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 395/2000
# 760/760 - 2s - loss: 5.2297e-05 - val_loss: 3.1075e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 396/2000
# 760/760 - 2s - loss: 5.2291e-05 - val_loss: 3.1075e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 397/2000
# 760/760 - 3s - loss: 5.2285e-05 - val_loss: 3.1074e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# Epoch 398/2000
# 760/760 - 2s - loss: 5.2279e-05 - val_loss: 3.1073e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 399/2000
# 760/760 - 2s - loss: 5.2273e-05 - val_loss: 3.1072e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 400/2000
# 760/760 - 2s - loss: 5.2267e-05 - val_loss: 3.1071e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 401/2000
# 760/760 - 2s - loss: 5.2261e-05 - val_loss: 3.1070e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 402/2000
# 760/760 - 2s - loss: 5.2255e-05 - val_loss: 3.1070e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 403/2000
# 760/760 - 2s - loss: 5.2249e-05 - val_loss: 3.1069e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 404/2000
# 760/760 - 2s - loss: 5.2243e-05 - val_loss: 3.1068e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 405/2000
# 760/760 - 2s - loss: 5.2237e-05 - val_loss: 3.1068e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 406/2000
# 760/760 - 2s - loss: 5.2231e-05 - val_loss: 3.1067e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 407/2000
# 760/760 - 2s - loss: 5.2225e-05 - val_loss: 3.1067e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 408/2000
# 760/760 - 2s - loss: 5.2219e-05 - val_loss: 3.1066e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 409/2000
# 760/760 - 2s - loss: 5.2214e-05 - val_loss: 3.1066e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 410/2000
# 760/760 - 2s - loss: 5.2208e-05 - val_loss: 3.1065e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 411/2000
# 760/760 - 2s - loss: 5.2202e-05 - val_loss: 3.1064e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 412/2000
# 760/760 - 2s - loss: 5.2196e-05 - val_loss: 3.1064e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 413/2000
# 760/760 - 2s - loss: 5.2190e-05 - val_loss: 3.1063e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 414/2000
# 760/760 - 2s - loss: 5.2184e-05 - val_loss: 3.1062e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 415/2000
# 760/760 - 2s - loss: 5.2178e-05 - val_loss: 3.1062e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 416/2000
# 760/760 - 2s - loss: 5.2172e-05 - val_loss: 3.1061e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 417/2000
# 760/760 - 2s - loss: 5.2167e-05 - val_loss: 3.1060e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 418/2000
# 760/760 - 2s - loss: 5.2161e-05 - val_loss: 3.1060e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 419/2000
# 760/760 - 2s - loss: 5.2155e-05 - val_loss: 3.1059e-05 - lr: 1.0000e-05 - 2s/epoch - 3ms/step
# Epoch 420/2000
# 760/760 - 3s - loss: 5.2149e-05 - val_loss: 3.1058e-05 - lr: 1.0000e-05 - 3s/epoch - 4ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-459-57bef6200f26> in <module>
#      18     print(f'Epoch {epoch}/{n_epochs}')
#      19     # Train the model for one epoch
# ---> 20     history = model.fit(train_X, train_y, callbacks=[early_stopping, mcp_save, reduce_lr_loss],
#      21                     epochs=1, batch_size=2, validation_data=(test_X, test_y),
#      22                      verbose=2,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:

# %%
# 2.455e-04 all variables 6 times steps
# 4.2105e-04 all variables 4 times steps
# all variables 9 time steps 1.870e-04

# %%
fig, ax = plt.subplots(1, 1, figsize=(18,6)) 
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
#plt.plot(history.history['loss'], label='train')
plt.plot( loss_tracking, label='test')
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# **MinMax Scaler equation**
# $$x' = \frac{(x - min)}{(max - min)} \times (new\ max\ value - new\ min\  value) + new\ min\ value$$<br/>
#
#
# $$x = \frac{(max - min)\times (new\ min\ value + x') + (new\ max\ value - new\ min\ value)\times min}{new\ max\ value - new\ min\ value}$$
#
# Where:
#
# $x$ is the inverse scaled value
# $x'$ is the scaled value
# $min$ is the minimum value of the original data
# $max$ is the maximum value of the original data.<br/>
# $new\ max\ value$ and $new\ min\ value$ is the new range that we want to scale the data to. For example: $(1,0)\ or\ (1,-1)$

# %%
# make a prediction 
# select the number of obersvtions for prediction
n_obs = len(test)
yhat = model.predict(test_X[-n_obs:], verbose=1)


# invert scaling 
scaled_y = pd.DataFrame(test_y)
scaled_yhat = pd.DataFrame(yhat.ravel()) ## ravel () converting into 1D array
#obtain the min and max from the training set
unscaled_train = pd.DataFrame(series_supervised[:len(train)])
#new feature range
new_max_value = 1 
new_min_value= 0
feature_range = new_max_value - new_min_value

def transform_column(column):
    min_value = min(unscaled_train.iloc[:, -steps_ahead + column.name])
    max_value = max(unscaled_train.iloc[:, -steps_ahead + column.name])
    return ((max_value - min_value) * (new_min_value + column) + (feature_range  * min_value)) / feature_range 
    
# invert scaling for actual
inv_scale_y = scaled_y.apply(transform_column, axis=0)
inv_scale_y = inv_scale_y.values.ravel() 
# invert scaling for forecast
inv_scale_yhat = scaled_yhat.apply(transform_column, axis=0)
inv_scale_yhat = inv_scale_yhat.values.ravel()
# Out:
# 12/12 [==============================] - 0s 1ms/step

# %%
# Invert the Differencing for actual 
df = pd.DataFrame(series.iloc[-len(test)-steps_ahead:,-1])
n_vars = df.shape[1]
columns = df.columns
cols, names = list(), list()
for i in range(0, steps_ahead):
    cols.append(df.shift(-i))
    if i == 0:
        names += [('%s(t)' % (columns[j])) for j in range(n_vars)]
    else:
        names += [('%s(t+%d)' % (columns[j], i)) for j in range(n_vars)]
# put it all together
agg = pd.concat(cols, axis=1)
agg.columns = names
agg.dropna(inplace=True)
agg = agg.iloc[:-1,0]
#drop all the variables that we don't want to predict
#agg.drop(columns=vars_to_drop, inplace=True)
agg = agg.to_numpy()
inv_y = np.add(inv_scale_y,agg)

# %%
series.iloc[-len(test)-steps_ahead:,-1]
# Out:
# DATEPRD
# 2014-03-11    3333.536720
# 2014-03-12    3312.214262
# 2014-03-13    3421.594068
# 2014-03-14    3415.241360
# 2014-03-15    3419.141042
#                  ...
# 2015-03-18    1659.440731
# 2015-03-19    1662.711432
# 2015-03-20    1707.494884
# 2015-03-21    1725.420844
# 2015-03-22    1620.632599
# Name: BORE_OIL_VOL, Length: 377, dtype: float64

# %% [markdown]
# * To invert the differencing of time series for multistep prediction:<br/>
# The equation is given by $$
# \hat x_{t+h|t}=x_t+(\widehat{\Delta x_{t+1}}+\dots+\widehat{\Delta x_{t+h}}).
# $$ <br/>
# where: <br/>
# $\hat x_{t+h|t}$ is the predicted value of the time series x at time $t$+h, given the value of the time series at time $t$.<br/>
# $x_t$ is the value of the time series $x$ at time t.<br/>
# ${\Delta x_{t+1}}$ is the difference between the value of the time series $x$ at time $t+1$ and the value of the time series at time t.<br/>
# ${\Delta x_{t+2}}$ is the difference between the value of the time series $x$ at time $t+2$ and the value of the time series at time $t+1$.<br/>
# ${\Delta x_{t+h}}$ is the difference between the value of the time series $x$ at time $t+h$ and the value of the time series at time $t+h-1$.

# %%
# Invert the Differencing for forecast
# to invert the diffrenced predicted values,the the predicted differenced value is added
# to previous predicted diffenced values and last available observation in test set(Xt) as explained above
originalSeries_supervised = series_to_supervised(series, series.columns, n_in=timesteps, n_out=steps_ahead, dropnan=True)

current_timestep = 1
# actual value of oil rate at current time step
# steps_ahead = 4
#drop all the variables that we don't want to predict
vars_y = originalSeries_supervised.columns[-steps_ahead*len(series.columns):]
vars_to_drop = [col for col in vars_y if col.startswith(vars_name_to_drop[0])]
originalSeries_supervised.drop(columns=vars_to_drop, inplace=True)
originalSeries_xt = originalSeries_supervised.iloc[-len(test):,-steps_ahead-2]


# A predicted value at any given step ahead is a result of the previous cumulative differnced predicted values and current time step
col = []
#inv_yhat_cum = np.cumsum(inv_scale_yhat, axis=1)
inv_yhat_cum = inv_scale_yhat

for i in range(n_obs):
    #.ravel() flattens the series into a one-dimensional array
    inverted_diff_yhat = originalSeries_xt[-n_obs:].ravel()[i] + inv_yhat_cum[i]
    col.append(inverted_diff_yhat)
#col = pd.DataFrame.from_records(col) # creates a DataFrame from a list of records
col = pd.DataFrame(col)
#col.columns = pd.RangeIndex(start=1, stop=steps_ahead+1, step=1)
inv_yhat = col.values.ravel() # convert df to NumpyArray
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-169-8f51947b0c24> in <module>
#       9 #drop all the variables that we don't want to predict
#      10 vars_y = originalSeries_supervised.columns[-steps_ahead*len(series.columns):]
# ---> 11 vars_to_drop = [col for col in vars_y if col.startswith(vars_name_to_drop[0])]
#      12 originalSeries_supervised.drop(columns=vars_to_drop, inplace=True)
#      13 originalSeries_xt = originalSeries_supervised.iloc[-len(test):,-steps_ahead-2]
#
# <ipython-input-169-8f51947b0c24> in <listcomp>(.0)
#       9 #drop all the variables that we don't want to predict
#      10 vars_y = originalSeries_supervised.columns[-steps_ahead*len(series.columns):]
# ---> 11 vars_to_drop = [col for col in vars_y if col.startswith(vars_name_to_drop[0])]
#      12 originalSeries_supervised.drop(columns=vars_to_drop, inplace=True)
#      13 originalSeries_xt = originalSeries_supervised.iloc[-len(test):,-steps_ahead-2]
#
# NameError: name 'vars_name_to_drop' is not defined

# %%
inv_yhat = np.add(inv_scale_yhat,agg)

# %%
inv_y[np.where(inv_y <0)]
# Out:
# array([-1.81898940e-12, -3.83693077e-13, -1.81898940e-12, -1.81898940e-12,
#        -1.81898940e-12, -1.81898940e-12])

# %%
inv_yhat[np.where(inv_y <0)]
# Out:
# array([-193.81265462,  -66.7252988 ,  -19.41699219,  -18.77148438,
#         -18.77148438,  -18.77148438])

# %%
inv_yhat[np.where(inv_y <0)]
# Out:
# array([-163.72281087,  -25.71943942,  -20.23535156,  -19.48730469,
#         -19.48730469,  -19.48730469])

# %%
inv_yhat[np.where(inv_y <0)]
# Out:
# array([-193.72964681,  -66.68428317,  -19.41894531,  -18.77441406,
#         -18.77441406,  -18.77441406])

# %%
inv_yhat[np.where(inv_y <0)]
# Out:
# array([-255.16617025, -167.07588473,  -37.01660156,  -41.84667969,
#         -41.84667969,  -41.84667969])

# %%
inv_yhat[np.where(inv_y <0)]
# Out:
# array([-193.81265462,  -66.7252988 ,  -19.41699219,  -18.77148438,
#         -18.77148438,  -18.77148438])

# %%
inv_yhat[np.where(inv_y <0)]
# Out:
# array([-370.86734212, -266.39229098, -111.45996094,  -61.03417969,
#         -61.15429688,  -61.15429688])

# %%
inv_yhat[np.where(inv_y <0)]
# Out:
# array([-184.43960775, -117.37275973,   31.31445312,   32.32421875,
#          32.32421875,   32.32421875])

# %%
r2_score(inv_y,inv_yhat)
# Out:
# 0.978565834438558

# %%
r2_score(inv_y,inv_yhat)
# Out:
# 0.9785535623482639

# %%
r2_score(inv_y,inv_yhat)
# Out:
# 0.9678677413182221

# %%
r2_score(inv_y,inv_yhat)
# Out:
# 0.9779287671467687

# %%
MAPE(inv_y[np.where(~(inv_y <0))],inv_yhat[np.where(~(inv_y <0))])
# Out:
# 9.199331744772142

# %%
wMAPE(inv_y,inv_yhat)
# Out:
# 2.589347447688912

# %%
wMAPE(inv_y,inv_yhat)
# Out:
# 4.075756149494592

# %%
inv_y.shape, inv_yhat.shape
# Out:
# ((6,), (6,))

# %%
# Performance evaluation

rmse_test = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.5f' % rmse_test)
#report performance using RMSPE
RMSPE_test = RMSPE(inv_y, inv_yhat)
print('Test RMSPE: %.5f' % RMSPE_test)
MAE_test = mean_absolute_error(inv_y, inv_yhat)
print('Test MAE: %.5f' % MAE_test)
MAPE_test = MAPE(inv_y, inv_yhat)
print('Test MAPE: %.5f' % MAPE_test)
r2 = r2_score(inv_y, inv_yhat)
print('Test r2: %.5f' % r2)
wMAPE_test = wMAPE(inv_y, inv_yhat)
print('Test wMAPE: %.5f ' % wMAPE_test)
SMAPE_test = SMAPE(inv_y, inv_yhat)
print('Test SMAPE: %.5f ' % SMAPE_test)
# Out:
# Test RMSE: 108.57806
# Test RMSPE: 1050289855997328.50000
# Test MAE: 59.25281
# Test MAPE: 84537068670607.06250
# Test r2: 0.97855
# Test wMAPE: 2.58988
# Test SMAPE: 7.66815

# %%
# Performance evaluation
rmse_test, RMSPE_test, MAE_test, MAPE_test, r2_test, wMAPE_test, SMAPE_test  = [], [], [], [], [], [], []
# calculate the score for each day

for i in range(test_y.shape[1]):
    result_rmse = sqrt(mean_squared_error(inv_y[:,i], inv_yhat[:,i]))
    result_RMSPE = RMSPE(inv_y[:,i], inv_yhat[:,i])
    result_MAE = mean_absolute_error(inv_y[:,i], inv_yhat[:,i])
    result_MAPE = MAPE(inv_y[:,i], inv_yhat[:,i])
    result_r2 = r2_score(inv_y[:,i], inv_yhat[:,i])
    result_wMAPE = wMAPE(inv_y[:,i], inv_yhat[:,i])
    result_SMAPE = SMAPE(inv_y[:,i], inv_yhat[:,i])

    rmse_test.append(result_rmse)
    RMSPE_test.append(result_RMSPE)
    MAE_test.append(result_MAE)
    MAPE_test.append(result_MAPE)
    r2_test.append(result_r2)
    wMAPE_test.append(result_wMAPE)
    SMAPE_test.append(result_SMAPE)
    
## calculate overall score
print("The Average scores for the vector output {} steps ahead:\n".format(steps_ahead))
print('Test RMSE: %.5f' % np.mean(rmse_test))
#print('Test RMSPE: %.5f' % np.mean(RMSPE_test)) because of that the denominator (actual) has some zero values
print('Test MAE: %.5f' % np.mean(MAE_test))
#print('Test MAPE: %.5f' % np.mean(MAPE_test)) because of that the denominator (actual) has some zero values
print('Test r2: %.5f' % np.mean(r2_test))
print('Test wMAPE: %.5f ' % np.mean(wMAPE_test))
print('Test SMAPE: %.5f ' % np.mean(SMAPE_test))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-bef913473e92> in <module>
#       4
#       5 for i in range(test_y.shape[1]):
# ----> 6     result_rmse = sqrt(mean_squared_error(inv_y[:,i], inv_yhat[:,i]))
#       7     result_RMSPE = RMSPE(inv_y[:,i], inv_yhat[:,i])
#       8     result_MAE = mean_absolute_error(inv_y[:,i], inv_yhat[:,i])
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
Test RMSE: 555.56135
Test MAE: 277.11301
Test r2: 0.39641
Test wMAPE: 12.32902 
Test SMAPE: 17.45901

# %%
# plot the scores for each time step of the multi-step forecast
scores = pd.DataFrame({"rmse_test":rmse_test, "MAE_test":MAE_test, "R-squared_test":r2_test, "wMAPE_test":wMAPE_test, "SMAPE_test":SMAPE_test})

# Reset the index, keeping the old index as a column
scores = scores.reset_index(drop=False)

# Set the 'index' column as the new index
scores.index = scores['index'] + 1

# Drop the old 'index' column
scores = scores.drop(columns='index')

data = scores.columns

# Creating figure with two rows and one column
fig, axs = plt.subplots(nrows=len(data), figsize=(17, 15))

axs = axs.ravel()

for id, column in enumerate(data):
    # Set the x-axis limits
    #axs[id].set_xlim(xmin=1, xmax= steps_ahead)
    #print the name of the test on plot
    axs[id].plot(scores[column])
    # Add a title to the x-axis
    axs[id].set_xlabel('Steps ahead',fontsize=10, labelpad=0.1)
    axs[id].grid(True)
    # Remove the horizontal grid lines
    axs[id].grid(which='both', axis='y')
    axs[id].xaxis.set_major_locator(plt.MultipleLocator(1))
    axs[id].legend([column], loc='upper left', fontsize=15, handlelength=0, handletextpad=0, frameon=False)
    
plt.show()

# %%
inv_yhat

# %%
inv_yhat[-1]

# %%
plt.plot(inv_yhat[-1], label = "predicted")
plt.plot(inv_y[-1], label = "actual")

# %%
plt.plot(inv_yhat.flatten(), label = "predicted")
plt.plot(inv_y.flatten(), label = "actual")

# %%
plt.plot(inv_yhat.flatten(), label = "predicted")
plt.plot(inv_y.flatten(), label = "actual")

# %%
# plot the last forecasted values on test set
fig, ax = plt.subplots(1, 1, figsize=(18,6)) 
# Set the major locator for the x-axis
x = list(range(1, len(inv_yhat[-1])+1))
ax.xaxis.set_major_locator(plt.MultipleLocator(1))
ax.plot(x, inv_yhat[-1], label = "predicted")
ax.plot(x, inv_y[-1], label = "actual")
ax.set_ylabel('Oil Rate', fontsize=15)
ax.set_xlabel('Steps Ahead (Days)',fontsize=15)
plt.legend(fontsize=15)
plt.show()

# %%
#comparing predictions and actual values
act_pred = pd.DataFrame({"actual":inv_y.flatten(), "prediction":inv_yhat.flatten()})
act_pred.head(5)

# %%
series_to_supervised(series, series.columns, n_in=2, n_out=steps_ahead, dropnan=True).iloc[-len(test):-len(test)+5]

# %%
r2_score(act_pred.iloc[:5,0],act_pred.iloc[:5,1])

# %%
wMAPE(act_pred.iloc[:5,0],act_pred.iloc[:5,1])

# %%
MAPE(act_pred.iloc[:5,0],act_pred.iloc[:5,1])
