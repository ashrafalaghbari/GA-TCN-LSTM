# %% [markdown]
# # Import libraries and define functions

# %%
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
import os
import numpy as np
import random 
from numpy.random import randint, rand
import pandas as pd
import re
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import seaborn as sns
from scipy.stats import spearmanr
import itertools
from itertools import groupby
import re
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense,Activation, Input, Flatten
from keras.layers import LSTM, Conv1D
from keras.models import Model
import keras.backend as k
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt, inf

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# # check if GPU is utilized 
# device_name = tf.config.experimental.list_physical_devices()[-1][-1]
# if device_name != 'GPU':
#     raise SystemError('GPU device not found')
# print('Found GPU at: {}'.format(tf.test.gpu_device_name()))

# %%
# Select features based on a  threshold
def select_features(df, target, correlation_type, threshold):
    if (threshold < -1 ) | (threshold > 1 ) :
            raise SystemError('correlation threshold is out of bounds')
    features = df.corr(correlation_type).loc[target].drop(target)
    best_features = features.where(abs(features) > threshold).dropna()
    df = pd.concat([df[target], df[best_features.index]], axis=1)
    return df

# convert series to supervised learning using a sliding  window approach
def series_to_supervised(data, columns, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('%s(t-%d)' % (columns[j], i)) for j in range(n_vars)]
        # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('%s(t)' % (columns[j])) for j in range(n_vars)]
        else:
            names += [('%s(t+%d)' % (columns[j], i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# scale train and test data to new feature range[0, 1]
def scale(train, test):
	# fit scaler
	scaler = MinMaxScaler(feature_range=(0, 1))
	scaler = scaler.fit(train)
	# transform train
	train = train.reshape(train.shape[0], train.shape[1])
	train_scaled = scaler.transform(train)
	# transform test
	test = test.reshape(test.shape[0], test.shape[1])
	test_scaled = scaler.transform(test)
	return scaler, train_scaled, test_scaled


# compute wMAPE weighted absolute percentage error
def wMAPE(actual, predicted): 
    result_nom = 0
    result_deno = 0
    for i in range(len(actual)):
        result_nom +=  abs(actual[i] - predicted[i])
        result_deno +=  abs(actual[i]) 
    result = result_nom/result_deno
    return result *100

# %% [markdown]
# # GA

# %%
# decode bitstring to numbers
def decode(bounds, n_bits, bitstring):
    decoded = list()
    largest = 2**n_bits
    for i in range(len(bounds)):
        # extract the substring
        start, end = i * n_bits, (i * n_bits)+n_bits
    
        substring = bitstring[start:end]
        # convert bitstring to a string of chars
        chars = ''.join([str(s) for s in substring])
        # convert string to integer
        integer = int(chars, 2)
        # scale integer to desired range
        value = bounds[i][0] + (integer/largest) * (bounds[i][1] - bounds[i][0])
        value = np.round(value)
        value = int(value)
        # store
        decoded.append(value)
    return decoded

# tournament selection
def selection(pop, scores, k=3):
	# first random selection
	selection_ix = randint(len(pop))
	for ix in randint(0, len(pop), k-1):
		# check if better (e.g. perform a tournament)
		if scores[ix] < scores[selection_ix] : # which individual has the lowest loss

			selection_ix = ix
	return pop[selection_ix]

# crossover two parents to create two children
def crossover(p1, p2, r_cross):
	# children are copies of parents by default
	c1, c2 = p1.copy(), p2.copy()
	# check for recombination
	if rand() < r_cross:
		# select crossover point that is not on the end of the string
		pt = randint(1, len(p1)-2)
		# perform crossover
		c1 = np.append(p1[:pt] , p2[pt:])
		c2 = np.append(p2[:pt] , p1[pt:])
	return [c1, c2]

# mutation operator
def mutation(bitstring, r_mut):
	for i in range(len(bitstring)):
		# check for a mutation
		if rand() < r_mut:
			# flip the bit
			bitstring[i] = 1 - bitstring[i]

# genetic algorithm
def genetic_algorithm(evaluate, bounds, n_bits, n_iter, n_pop, r_cross, r_mut):
    # initial population of random bitstring
    pop = [randint(0, 2, n_bits*len(bounds)).tolist() for _ in range(n_pop)]
    # keep track of best solution
    best, best_eval = 0, inf
    # enumerate generations
    for gen in range(1, n_iter+1):
        print(f"Generation:{gen}")
        # decode population
        decoded = [decode(bounds, n_bits, p) for p in pop]
        # evaluate all candidates in the population
        scores = [evaluate(ind) for ind in decoded]
        # check for new best solution
        for i in range(n_pop):
            if scores[i] < best_eval: # find the lowest validation loss
                best, best_eval = pop[i], scores[i]
                # print(">%d, new best combination, Epoch: %d, num_hidden_layers: %d, num_neurons:%d, batch_size: %d, window_size: %d, Loss = %.8f" % \
                #         (gen,  decoded[i][0],decoded[i][1], decoded[i][2], decoded[i][3], decoded[i][4],
                #                                             scores[i]))
                print(">%d, new best combination, Epoch: %d, n_filters_1: %d, n_filters_2: %d, n_filters_3: %d, batch_size: %d, window_size: %d, Loss = %.8f" % \
                        (gen,  decoded[i][0],decoded[i][1], decoded[i][2], decoded[i][3], decoded[i][4], decoded[i][5],
                                                            scores[i]))
		# select parents (Tournament selection)
        selected = [selection(pop, scores) for _ in range(n_pop)]
		# create the next generation
        children = list()
        for i in range(0, n_pop, 2):
			# get selected parents in pairs
            p1, p2 = selected[i], selected[i+1]
			# crossover and mutation
            for c in crossover(p1, p2, r_cross):
				# mutation
                mutation(c, r_mut)
				# store for next generation
                children.append(c)
		# replace population
        pop = children
    return [best, best_eval]

# %% [markdown]
# # Evaluate LSTM using GA

# %%
# Evalaute LSTM model with the random generated combinations by GA
def evaluate_LSTM(individual, steps_ahead=1):

    n_epochs = individual[0]
    num_hidden_layers = individual[1]
    num_neurons = individual[2]
    batch_size = individual[3]
    window_size = individual[4]
  

    print('n_epochs', n_epochs, 'num_hidden_layers', num_hidden_layers, 'num_neurons',
              num_neurons, "batch_size", str(batch_size), 'window_size', window_size)

    # setting the session configurations for reproducibility.
    combinations = [n_epochs, num_hidden_layers, num_neurons, batch_size, window_size]
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
    os.environ['PYTHONHASHSEED'] = '0'
    # seed = int(random.random()*(2**32-1))
    np.random.seed(42)
    np.random.seed(12345)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,
                                        inter_op_parallelism_threads=1)
    from keras import backend as K   
    tf.random.set_seed(1234)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), 
                            config=session_conf)
    K.set_session(sess)

    #feature engineering
    # # convert the stationary series to supervise learning
    series_supervised = series_to_supervised(series, series.columns, n_in= window_size, n_out= steps_ahead, dropnan=True)   

    # drop columns we don't want to predict
    pattern = re.compile(r"(t-)|^BORE_OIL_VOL.*")
    # Extract the column names that match the pattern
    matching_columns = [col for col in series_supervised.columns if re.search(pattern, col)]
    series_supervised = series_supervised[matching_columns]

    # # split into train and test sets
    series_supervised = series_supervised.values
    train_size = int(series_supervised.shape[0] * 0.8)
    test_size = series_supervised.shape[0] - train_size
    train, test = series_supervised[0:train_size], series_supervised[train_size:]
    # print("train.shape:",train.shape, "test.shape:",test.shape)

    # scale  the data to a feature range(0,1)
    scaler, train_scaled, test_scaled = scale(train, test)
    # print('train_scaled.shape:',train_scaled.shape, "test_scaled.shape:",test_scaled.shape)

    # reshape input to be 3D [samples, window_size, features]
    n_features = len(series.columns)
    train_X, train_y = train_scaled[:, 0:-steps_ahead], train_scaled[:, -steps_ahead:]
    train_X = train_X.reshape(train_X.shape[0], window_size, n_features)
    test_X, test_y = test_scaled[:, 0:-steps_ahead], test_scaled[:, -steps_ahead:]
    test_X = test_X.reshape(test_X.shape[0], window_size, n_features )
    # print("train_X.shape:",train_X.shape, "train_y.shape:",train_y.shape,
    #         "test_X.shape:", test_X.shape,"test_y.shape:",test_y.shape)

    # build the LSTM model
    model =  Sequential()

    if num_hidden_layers == 1:
        model.add(LSTM(num_neurons, activation='tanh', input_shape = (window_size, n_features)))
        
    else:
        for num in range(num_hidden_layers-1):
            model.add(LSTM(num_neurons,activation='tanh', input_shape =(window_size, n_features), return_sequences=True))        
        model.add(LSTM(num_neurons))
            
    model.add(Dense(steps_ahead))
    model.compile(loss='mean_squared_error',
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001))
    #prevent overfitting
    early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=0,
                                restore_best_weights=True, mode='min')

    model.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, callbacks = [early_stopping],
                validation_data=(test_X, test_y), verbose=0, shuffle=False)
    
    # # save the weights to a HDF5 file
    # combination = [n_epochs, num_hidden_layers, num_neurons, batch_size, window_size]
    # model.save_weights(f'{combination}_weights.h5')

    return model.evaluate(test_X, test_y, verbose=0)

# %% [markdown]
# # Evaluate TCN using GA

# %%
# Evalaute TCN model with the random generated combinations by GA
def evaluate_TCN(individual, steps_ahead=1):

    n_epochs = individual[0]
    n_filters_1 = individual[1]
    n_filters_2 = individual[2]
    n_filters_3 = individual[3]
    batch_size = individual[4]
    window_size = individual[5]


    print('n_epochs', n_epochs, 'n_filters_1', n_filters_1, 'n_filters_2',n_filters_2, 'n_filters_3', n_filters_3,
               "batch_size", batch_size, 'window_size', window_size)
    
    # setting the session configurations for reproducibility.
    combinations = [n_epochs, n_filters_1, n_filters_2, n_filters_3, batch_size, window_size]
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
    os.environ['PYTHONHASHSEED'] = '0'
    # seed = int(random.random()*(2**32-1))
    np.random.seed(42)
    np.random.seed(12345)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,
                                        inter_op_parallelism_threads=1)
    from keras import backend as K   
    tf.random.set_seed(1234)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), 
                            config=session_conf)
    K.set_session(sess)

    #feature engineering
    # # convert the stationary series to supervise learning
    series_supervised = series_to_supervised(series, series.columns, n_in= window_size, n_out= steps_ahead, dropnan=True)   

    # drop columns we don't want to predict
    pattern = re.compile(r"(t-)|^BORE_OIL_VOL.*")
    # Extract the column names that match the pattern
    matching_columns = [col for col in series_supervised.columns if re.search(pattern, col)]
    series_supervised = series_supervised[matching_columns]

    # # split into train and test sets
    series_supervised = series_supervised.values
    train_size = int(series_supervised.shape[0] * 0.8)
    test_size = series_supervised.shape[0] - train_size
    train, test = series_supervised[0:train_size], series_supervised[train_size:]
    # print("train.shape:",train.shape, "test.shape:",test.shape)

    # scale  the data to a feature range(0,1)
    scaler, train_scaled, test_scaled = scale(train, test)
    # print('train_scaled.shape:',train_scaled.shape, "test_scaled.shape:",test_scaled.shape)

    # reshape input to be 3D [samples, window_size, features]
    n_features = len(series.columns)
    train_X, train_y = train_scaled[:, 0:-steps_ahead], train_scaled[:, -steps_ahead:]
    train_X = train_X.reshape(train_X.shape[0], window_size, n_features)
    test_X, test_y = test_scaled[:, 0:-steps_ahead], test_scaled[:, -steps_ahead:]
    test_X = test_X.reshape(test_X.shape[0], window_size, n_features )
    # print("train_X.shape:",train_X.shape, "train_y.shape:",train_y.shape,
            # "test_X.shape:", test_X.shape,"test_y.shape:",test_y.shape)

    # build the TCN model
    input_tensor=Input(shape=(window_size, n_features))

    #Feature extraction module
    conv1 = Conv1D(filters = n_filters_1, kernel_size = 1, dilation_rate=1 ,padding='same')(input_tensor)
    conv2 = Conv1D(filters = n_filters_2 , kernel_size = 1, dilation_rate=1, padding='same')(conv1)
    # Time information extraction module
    conv3 = Conv1D(filters = n_filters_3, kernel_size= window_size, dilation_rate=1, padding='causal')(conv2) 
    
    conv3 = Flatten()(conv3)  
    outputs = Dense(steps_ahead)(conv3)
    model = Model(input_tensor, outputs)

    model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001))
    #prevent overfitting
    early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=0,
                                restore_best_weights=True, mode='min')
    
    model.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, callbacks = [early_stopping],
              validation_data=(test_X, test_y), verbose=0, shuffle=False)
    
    return model.evaluate(test_X, test_y, verbose=0)

# %% [markdown]
# # Feature selection

# %%
#load the dataset and select only the features that improved the performance during expermentation 
series = pd.read_csv('cleaned_df.csv',  usecols = ["DATEPRD",'ON_STREAM_HRS', 'AVG_CHOKE_SIZE_P', 'BORE_GAS_VOL','BORE_OIL_VOL'],
                     parse_dates=["DATEPRD"], index_col="DATEPRD") 
# # create new features
series.insert(0, column = 'days', value= range(len(series), 0, -1))
series.insert(3, column = "ON_STREAM_HRS*AVG_CHOKE_SIZE_P*days", value= series["ON_STREAM_HRS"] * series["AVG_CHOKE_SIZE_P"] * series['days'])
series =series[[
                "ON_STREAM_HRS*AVG_CHOKE_SIZE_P*days",
                "BORE_GAS_VOL", 
                "BORE_OIL_VOL"
                ]]
# shift ON_STREAM_HRS*AVG_CHOKE_SIZE_P*days by one step backward for modeling
# series['ON_STREAM_HRS*AVG_CHOKE_SIZE_P*days'] = series['ON_STREAM_HRS*AVG_CHOKE_SIZE_P*days'].shift(-1)
series.dropna(inplace=True)
series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1908 entries, 2010-01-01 to 2015-03-23
# Data columns (total 3 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ON_STREAM_HRS*AVG_CHOKE_SIZE_P*days  1908 non-null   float64
#  1   BORE_GAS_VOL                         1908 non-null   float64
#  2   BORE_OIL_VOL                         1908 non-null   float64
# dtypes: float64(3)
# memory usage: 59.6 KB

# %%
series
# Out:
#             ON_STREAM_HRS*AVG_CHOKE_SIZE_P*days  BORE_GAS_VOL  BORE_OIL_VOL
# DATEPRD
# 2010-01-01                         2.296507e+06  1.462166e+07  18593.749401
# 2010-01-02                         2.320193e+06  1.469266e+07  18701.242265
# 2010-01-03                         2.180419e+06  1.400904e+07  17799.912406
# 2010-01-04                         2.043969e+06  1.341015e+07  17002.616014
# 2010-01-05                         2.090307e+06  1.361768e+07  17270.939334
# ...                                         ...           ...           ...
# 2015-03-19                         1.200000e+04  1.366424e+06   1662.711432
# 2015-03-20                         9.600000e+03  1.397308e+06   1707.494884
# 2015-03-21                         7.200000e+03  1.408435e+06   1725.420844
# 2015-03-22                         4.800000e+03  1.379366e+06   1620.632599
# 2015-03-23                         2.399858e+03  1.263109e+06   1443.511533
#
# [1908 rows x 3 columns]

# %%
# plot only the useful variables for the model
columns = [series.columns[0], series.columns[1], series.columns[2]]
columns_units = [f'{series.columns[0]}, \nHours*%*days',
        f'{series.columns[1]}, SCF' , f'{series.columns[2]}, bbl']

# Creating figure with one row and four columns
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(14, 16))

for id, column in enumerate(columns):

    axs[id].plot(series[column])
    axs[id].grid(False)
    axs[id].set_ylabel(columns_units[id], fontsize=13)
    # axs[id].set_ylim(min(series[column]), max(series[column]))
    
    # set xlabel font size
    for label in axs[id].get_xticklabels():
        label.set_fontsize(13)
    # axs[id].set_xlabel(fontsize=13)
# plt.savefig("MTS with optimal features.png", dpi=1600, bbox_inches='tight')
plt.show()

# %%
# detrend and standardize signal x & y
y = series['BORE_OIL_VOL'].diff().dropna()
x = series['ON_STREAM_HRS*AVG_CHOKE_SIZE_P*days'].diff().dropna()

scaler = MinMaxScaler()
y = scaler.fit_transform(y.values.reshape(-1,1))
x = scaler.fit_transform(x.values.reshape(-1,1))

from statsmodels.tsa.stattools import adfuller

# test for stationarity using ADF test

for idx, values in enumerate([x,y]):
    adf_result = adfuller(values)

    # Print the ADF test results
    print("ADF Statistic: %f" % adf_result[0])
    print("p-value: %f" % adf_result[1])
    print("Critical Values:")
    for key, value in adf_result[4].items():
        print("\t%s: %.3f" % (key, value))

    # Check if the data is stationary
    if adf_result[1] < 0.05:
        print(f"Series {idx} is stationary")
    else:
        print(f"Series {idx} is not stationary")
# Out:
# ADF Statistic: -12.354285
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# Series 0 is stationary
# ADF Statistic: -13.217658
# p-value: 0.000000
# Critical Values:
# 	1%: -3.434
# 	5%: -2.863
# 	10%: -2.568
# Series 1 is stationary

# %%
# !pip install rpy2==3.5.1

# %%
# %load_ext rpy2.ipython

# %%
# %R -i x -i y

# %%
# %%R
# # Set the device size and resolution
# options(repr.plot.width = 140/25.5, repr.plot.height = 90/25.5, repr.plot.res = 1000)
#
# df <- data.frame(x, y)
# par(mar = c(5, 5, 1, 1))
# CCF <- ccf(df$x, df$y, lwd=2,
#            xlab='Lead/Lag',
#            ylab='Correlation',
#            main= "",
#            cex.lab=1.2, cex.axis=1.2, cex.main=1.2)
#
#
# # Save the image with a width of 140 mm
#
# jpeg(filename = "Cross correlation, on stream hours*average choke size*time\n& oil volume.jpeg", width = 140, height = 90, units = "mm", res = 1000)
# # Create the ACF plot with modified font sizes
# par(mar = c(5, 5, 1, 1))
# plot(CCF, lwd=2,
#      xlab=  'Lead/Lag',
#      ylab ='Correlation',
#      main="", cex.lab=1.2, cex.axis=1.2, cex.main=1.2)
# dev.off()
# Out:
# png
#   2

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(140/25.5,90/25.5))
plt.plot(y[:100], label='Oil volume')
plt.plot(np.roll(x,-1)[:100], label='On-stream hours*average choke size*time\n(shifted one step backward)')

plt.ylabel('Standardized daily Oil Production, bbl', fontsize=10)
plt.xlabel('Days', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Create a font object with bold weight and small size
font = FontProperties(size=9, weight='bold')
plt.legend(loc='lower left', prop=font)

plt.tight_layout()
plt.subplots_adjust(hspace=0.1, wspace=0.1)

plt.savefig("Standardized daily Oil Production.jpeg", dpi=1000, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Optimizing LSTM hyperparameters with GA

# %%
# optimize the LSTM model
# define the total number of generations
n_iter = 10
# bits per variable
n_bits = 16
# define the number of combinations (individuals) per generation 
n_pop = 20
# crossover rate
r_cross = 0.9
# mutation rate
r_mut = 0.1

# define the search space for LSTM
n_epochs = [500,500]
num_hidden_layers = [1, 2]
num_neurons = [4, 200]
batch_size = [2, 8]
window_size = [2, 12]
bounds_lstm = [n_epochs,num_hidden_layers, num_neurons, batch_size, window_size]


# run optimization
best_comb_lstm, score_lstm = genetic_algorithm(evaluate_LSTM, bounds_lstm, n_bits, n_iter, n_pop, r_cross, r_mut)
print('Done!')
decoded = decode(bounds_lstm, n_bits, best_comb_lstm)
print('LSTM Best: %s = %f' % (decoded, score_lstm))
# Out:
# Generation:1
# n_epochs 500 num_hidden_layers 2 num_neurons 175 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 6
# n_epochs 500 num_hidden_layers 2 num_neurons 88 batch_size 4 window_size 3
# n_epochs 500 num_hidden_layers 2 num_neurons 133 batch_size 3 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 139 batch_size 8 window_size 9
# n_epochs 500 num_hidden_layers 2 num_neurons 97 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 94 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 2 num_neurons 186 batch_size 4 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 86 batch_size 6 window_size 3
# n_epochs 500 num_hidden_layers 2 num_neurons 95 batch_size 3 window_size 9
# n_epochs 500 num_hidden_layers 2 num_neurons 42 batch_size 5 window_size 4
# n_epochs 500 num_hidden_layers 2 num_neurons 116 batch_size 3 window_size 7
# n_epochs 500 num_hidden_layers 2 num_neurons 62 batch_size 7 window_size 4
# n_epochs 500 num_hidden_layers 1 num_neurons 50 batch_size 6 window_size 6
# n_epochs 500 num_hidden_layers 1 num_neurons 166 batch_size 5 window_size 2
# n_epochs 500 num_hidden_layers 1 num_neurons 148 batch_size 4 window_size 5
# n_epochs 500 num_hidden_layers 1 num_neurons 119 batch_size 5 window_size 2
# n_epochs 500 num_hidden_layers 2 num_neurons 5 batch_size 6 window_size 7
# n_epochs 500 num_hidden_layers 2 num_neurons 21 batch_size 8 window_size 6
# n_epochs 500 num_hidden_layers 1 num_neurons 20 batch_size 5 window_size 4
# >1, new best combination, Epoch: 500, num_hidden_layers: 2, num_neurons:175, batch_size: 8, window_size: 10, Loss = 0.00011482
# >1, new best combination, Epoch: 500, num_hidden_layers: 1, num_neurons:68, batch_size: 8, window_size: 6, Loss = 0.00011179
# Generation:2
# n_epochs 500 num_hidden_layers 2 num_neurons 139 batch_size 8 window_size 8
# n_epochs 500 num_hidden_layers 1 num_neurons 19 batch_size 7 window_size 3
# n_epochs 500 num_hidden_layers 2 num_neurons 68 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 2 num_neurons 95 batch_size 3 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 116 batch_size 3 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 148 batch_size 6 window_size 2
# n_epochs 500 num_hidden_layers 2 num_neurons 51 batch_size 2 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 66 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 139 batch_size 5 window_size 4
# n_epochs 500 num_hidden_layers 2 num_neurons 101 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 116 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 98 batch_size 3 window_size 7
# n_epochs 500 num_hidden_layers 1 num_neurons 19 batch_size 5 window_size 4
# n_epochs 500 num_hidden_layers 2 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 73 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 2 num_neurons 97 batch_size 8 window_size 4
# n_epochs 500 num_hidden_layers 2 num_neurons 42 batch_size 5 window_size 4
# n_epochs 500 num_hidden_layers 2 num_neurons 200 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 2 num_neurons 193 batch_size 3 window_size 9
# n_epochs 500 num_hidden_layers 2 num_neurons 186 batch_size 4 window_size 9
# >2, new best combination, Epoch: 500, num_hidden_layers: 1, num_neurons:73, batch_size: 5, window_size: 10, Loss = 0.00011123
# Generation:3
# n_epochs 500 num_hidden_layers 2 num_neurons 101 batch_size 7 window_size 6
# n_epochs 500 num_hidden_layers 2 num_neurons 19 batch_size 7 window_size 12
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 73 batch_size 5 window_size 9
# n_epochs 500 num_hidden_layers 2 num_neurons 101 batch_size 7 window_size 6
# n_epochs 500 num_hidden_layers 2 num_neurons 18 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 1 num_neurons 23 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 6
# n_epochs 500 num_hidden_layers 1 num_neurons 139 batch_size 5 window_size 3
# n_epochs 500 num_hidden_layers 2 num_neurons 101 batch_size 8 window_size 4
# n_epochs 500 num_hidden_layers 1 num_neurons 72 batch_size 3 window_size 7
# n_epochs 500 num_hidden_layers 2 num_neurons 98 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 2 num_neurons 68 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 2 num_neurons 68 batch_size 7 window_size 4
# n_epochs 500 num_hidden_layers 2 num_neurons 94 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 19 batch_size 4 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 116 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 115 batch_size 5 window_size 8
# n_epochs 500 num_hidden_layers 2 num_neurons 199 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 73 batch_size 5 window_size 5
# >3, new best combination, Epoch: 500, num_hidden_layers: 1, num_neurons:68, batch_size: 8, window_size: 10, Loss = 0.00010425
# Generation:4
# n_epochs 500 num_hidden_layers 2 num_neurons 101 batch_size 7 window_size 7
# n_epochs 500 num_hidden_layers 1 num_neurons 19 batch_size 7 window_size 8
# n_epochs 500 num_hidden_layers 2 num_neurons 68 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 116 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 2 num_neurons 199 batch_size 7 window_size 8
# n_epochs 500 num_hidden_layers 1 num_neurons 170 batch_size 3 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 25 batch_size 5 window_size 6
# n_epochs 500 num_hidden_layers 1 num_neurons 66 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 101 batch_size 4 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 5 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 72 batch_size 5 window_size 8
# n_epochs 500 num_hidden_layers 2 num_neurons 115 batch_size 5 window_size 5
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 45 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 2 num_neurons 68 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 2 num_neurons 68 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 2 num_neurons 76 batch_size 4 window_size 6
# n_epochs 500 num_hidden_layers 2 num_neurons 101 batch_size 7 window_size 6
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 11
# Generation:5
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 6 window_size 7
# n_epochs 500 num_hidden_layers 1 num_neurons 121 batch_size 3 window_size 8
# n_epochs 500 num_hidden_layers 2 num_neurons 19 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 5 window_size 7
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 5 window_size 8
# n_epochs 500 num_hidden_layers 1 num_neurons 170 batch_size 5 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 23 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 6
# n_epochs 500 num_hidden_layers 1 num_neurons 199 batch_size 4 window_size 3
# n_epochs 500 num_hidden_layers 1 num_neurons 173 batch_size 3 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 67 batch_size 3 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 171 batch_size 8 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 5
# n_epochs 500 num_hidden_layers 1 num_neurons 101 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 194 batch_size 6 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 174 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 66 batch_size 8 window_size 9
# Generation:6
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 6 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 121 batch_size 5 window_size 11
# n_epochs 500 num_hidden_layers 2 num_neurons 194 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 171 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 96 batch_size 6 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 25 batch_size 5 window_size 6
# n_epochs 500 num_hidden_layers 1 num_neurons 172 batch_size 8 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 68 batch_size 4 window_size 4
# n_epochs 500 num_hidden_layers 1 num_neurons 71 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 102 batch_size 8 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 171 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 66 batch_size 8 window_size 8
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 6
# n_epochs 500 num_hidden_layers 2 num_neurons 101 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 195 batch_size 5 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 5 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 101 batch_size 7 window_size 10
# Generation:7
# n_epochs 500 num_hidden_layers 1 num_neurons 96 batch_size 6 window_size 12
# n_epochs 500 num_hidden_layers 1 num_neurons 47 batch_size 6 window_size 8
# n_epochs 500 num_hidden_layers 2 num_neurons 121 batch_size 4 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 68 batch_size 8 window_size 12
# n_epochs 500 num_hidden_layers 1 num_neurons 71 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 166 batch_size 8 window_size 4
# n_epochs 500 num_hidden_layers 1 num_neurons 21 batch_size 2 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 172 batch_size 7 window_size 3
# n_epochs 500 num_hidden_layers 2 num_neurons 75 batch_size 3 window_size 4
# n_epochs 500 num_hidden_layers 1 num_neurons 71 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 101 batch_size 6 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 102 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 96 batch_size 6 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 101 batch_size 8 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 96 batch_size 5 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 66 batch_size 8 window_size 8
# n_epochs 500 num_hidden_layers 1 num_neurons 72 batch_size 3 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 169 batch_size 7 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 5 window_size 9
# Generation:8
# n_epochs 500 num_hidden_layers 1 num_neurons 71 batch_size 7 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 96 batch_size 6 window_size 11
# n_epochs 500 num_hidden_layers 2 num_neurons 47 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 71 batch_size 8 window_size 7
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 199 batch_size 6 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 126 batch_size 4 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 99 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 96 batch_size 3 window_size 7
# n_epochs 500 num_hidden_layers 1 num_neurons 71 batch_size 8 window_size 12
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 5 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 102 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 100 batch_size 8 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 102 batch_size 8 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 102 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 73 batch_size 4 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 169 batch_size 8 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 169 batch_size 7 window_size 10
# Generation:9
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 47 batch_size 6 window_size 8
# n_epochs 500 num_hidden_layers 2 num_neurons 96 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 102 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 195 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 126 batch_size 5 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 98 batch_size 6 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 102 batch_size 5 window_size 4
# n_epochs 500 num_hidden_layers 1 num_neurons 98 batch_size 8 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 169 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 5 window_size 4
# n_epochs 500 num_hidden_layers 2 num_neurons 68 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 76 batch_size 6 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 72 batch_size 4 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 71 batch_size 8 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 169 batch_size 8 window_size 9
# Generation:10
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 12
# n_epochs 500 num_hidden_layers 1 num_neurons 96 batch_size 6 window_size 11
# n_epochs 500 num_hidden_layers 2 num_neurons 72 batch_size 5 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 195 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 28 batch_size 5 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 99 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 97 batch_size 4 window_size 5
# n_epochs 500 num_hidden_layers 1 num_neurons 98 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 169 batch_size 8 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 195 batch_size 7 window_size 5
# n_epochs 500 num_hidden_layers 2 num_neurons 70 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 169 batch_size 7 window_size 11
# n_epochs 500 num_hidden_layers 1 num_neurons 97 batch_size 7 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 73 batch_size 4 window_size 10
# n_epochs 500 num_hidden_layers 1 num_neurons 169 batch_size 8 window_size 9
# n_epochs 500 num_hidden_layers 1 num_neurons 71 batch_size 8 window_size 9
# Done!
# LSTM Best: [500, 1, 68, 8, 10] = 0.000104

# %% [markdown]
# # Run the LSTM model using the optimal hyperparamters obtained by GA

# %%
# how many steps ahead we want to forecast
steps_ahead = 1
# Define hyperparamtes
n_epochs = 500
num_hidden_layers = 1
num_neurons = 68
batch_size = 8
window_size = 10


# # setting the session configurations for reproducibility.

combinations = [n_epochs, num_hidden_layers, num_neurons, batch_size, window_size]
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
np.random.seed(12345)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,
                                    inter_op_parallelism_threads=1)
from keras import backend as K   
tf.random.set_seed(1234)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), 
                        config=session_conf)
K.set_session(sess)

# # convert the series to supervise learning using sliding window approach
series_supervised = series_to_supervised(series, series.columns, n_in= window_size, n_out= steps_ahead, dropnan=True)   

# drop columns we don't want to predict
pattern = re.compile(r"(t-)|^BORE_OIL_VOL.*")

# Extract the column names that match the pattern
matching_columns = [col for col in series_supervised.columns if re.search(pattern, col)]
series_supervised = series_supervised[matching_columns]
# # split into train and test sets
n_features = int((len(series_supervised.columns) -steps_ahead)/window_size)
series_supervised = series_supervised.values
train_size = int(series_supervised.shape[0] * 0.8)
test_size = series_supervised.shape[0] - train_size
train, test = series_supervised[0:train_size], series_supervised[train_size:]
print("train.shape:",train.shape, "test.shape:",test.shape)

# scale  the data to a feature range(0,1)
scaler, train_scaled, test_scaled = scale(train, test)
print('train_scaled.shape:',train_scaled.shape, "test_scaled.shape:",test_scaled.shape)

# # reshape input to be 3D [samples, window_size, features]
train_X, train_y = train_scaled[:, 0:-steps_ahead], train_scaled[:, -steps_ahead:]
train_X = train_X.reshape(train_X.shape[0], window_size, n_features)
test_X, test_y = test_scaled[:, 0:-steps_ahead], test_scaled[:, -steps_ahead:]
test_X = test_X.reshape(test_X.shape[0], window_size, n_features )
print("train_X.shape:",train_X.shape, "train_y.shape:",train_y.shape,
        "test_X.shape:", test_X.shape,"test_y.shape:",test_y.shape)

#Run the model
model_lstm =  Sequential()

if num_hidden_layers == 1:
    model_lstm.add(LSTM(num_neurons, activation='tanh', input_shape = (window_size, n_features)))
    
else:
    for num in range(num_hidden_layers-1):
        model_lstm.add(LSTM(num_neurons,activation='tanh', input_shape =(window_size, n_features), return_sequences=True))        
    model_lstm.add(LSTM(num_neurons))
        
model_lstm.add(Dense(steps_ahead))
model_lstm.compile(loss='mean_squared_error',
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001))
#prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=0,
                            restore_best_weights=True, mode='min')
history_lstm = model_lstm.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, callbacks = [early_stopping],
            validation_data=(test_X, test_y), verbose=2, shuffle=False)
model_lstm.evaluate(test_X, test_y)
# Out:
# train.shape: (1517, 31) test.shape: (380, 31)
# train_scaled.shape: (1517, 31) test_scaled.shape: (380, 31)
# train_X.shape: (1517, 10, 3) train_y.shape: (1517, 1) test_X.shape: (380, 10, 3) test_y.shape: (380, 1)
# Epoch 1/500
# 190/190 - 4s - loss: 0.1039 - val_loss: 0.0017 - 4s/epoch - 21ms/step
# Epoch 2/500
# 190/190 - 1s - loss: 0.0201 - val_loss: 0.0019 - 1s/epoch - 6ms/step
# Epoch 3/500
# 190/190 - 1s - loss: 0.0176 - val_loss: 0.0018 - 1s/epoch - 6ms/step
# Epoch 4/500
# 190/190 - 1s - loss: 0.0163 - val_loss: 0.0017 - 1s/epoch - 6ms/step
# Epoch 5/500
# 190/190 - 2s - loss: 0.0153 - val_loss: 0.0016 - 2s/epoch - 10ms/step
# Epoch 6/500
# 190/190 - 2s - loss: 0.0146 - val_loss: 0.0015 - 2s/epoch - 10ms/step
# Epoch 7/500
# 190/190 - 1s - loss: 0.0139 - val_loss: 0.0014 - 1s/epoch - 6ms/step
# Epoch 8/500
# 190/190 - 1s - loss: 0.0133 - val_loss: 0.0014 - 1s/epoch - 6ms/step
# Epoch 9/500
# 190/190 - 1s - loss: 0.0127 - val_loss: 0.0013 - 1s/epoch - 6ms/step
# Epoch 10/500
# 190/190 - 1s - loss: 0.0121 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 11/500
# 190/190 - 1s - loss: 0.0115 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 12/500
# 190/190 - 1s - loss: 0.0110 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 13/500
# 190/190 - 1s - loss: 0.0105 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 14/500
# 190/190 - 1s - loss: 0.0100 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 15/500
# 190/190 - 1s - loss: 0.0095 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 16/500
# 190/190 - 1s - loss: 0.0091 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 17/500
# 190/190 - 1s - loss: 0.0087 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 18/500
# 190/190 - 2s - loss: 0.0084 - val_loss: 0.0012 - 2s/epoch - 8ms/step
# Epoch 19/500
# 190/190 - 1s - loss: 0.0081 - val_loss: 0.0012 - 1s/epoch - 6ms/step
# Epoch 20/500
# 190/190 - 1s - loss: 0.0078 - val_loss: 0.0011 - 1s/epoch - 6ms/step
# Epoch 21/500
# 190/190 - 1s - loss: 0.0075 - val_loss: 0.0011 - 1s/epoch - 6ms/step
# Epoch 22/500
# 190/190 - 1s - loss: 0.0073 - val_loss: 0.0011 - 1s/epoch - 6ms/step
# Epoch 23/500
# 190/190 - 1s - loss: 0.0071 - val_loss: 0.0010 - 1s/epoch - 6ms/step
# Epoch 24/500
# 190/190 - 1s - loss: 0.0068 - val_loss: 9.9777e-04 - 1s/epoch - 6ms/step
# Epoch 25/500
# 190/190 - 1s - loss: 0.0066 - val_loss: 9.5739e-04 - 1s/epoch - 6ms/step
# Epoch 26/500
# 190/190 - 1s - loss: 0.0064 - val_loss: 9.1654e-04 - 1s/epoch - 6ms/step
# Epoch 27/500
# 190/190 - 1s - loss: 0.0062 - val_loss: 8.7528e-04 - 1s/epoch - 6ms/step
# Epoch 28/500
# 190/190 - 1s - loss: 0.0060 - val_loss: 8.3363e-04 - 1s/epoch - 6ms/step
# Epoch 29/500
# 190/190 - 1s - loss: 0.0058 - val_loss: 7.9171e-04 - 1s/epoch - 6ms/step
# Epoch 30/500
# 190/190 - 1s - loss: 0.0056 - val_loss: 7.4976e-04 - 1s/epoch - 6ms/step
# Epoch 31/500
# 190/190 - 1s - loss: 0.0054 - val_loss: 7.0817e-04 - 1s/epoch - 6ms/step
# Epoch 32/500
# 190/190 - 1s - loss: 0.0052 - val_loss: 6.6750e-04 - 1s/epoch - 6ms/step
# Epoch 33/500
# 190/190 - 1s - loss: 0.0050 - val_loss: 6.2833e-04 - 1s/epoch - 6ms/step
# Epoch 34/500
# 190/190 - 1s - loss: 0.0048 - val_loss: 5.9120e-04 - 1s/epoch - 6ms/step
# Epoch 35/500
# 190/190 - 1s - loss: 0.0047 - val_loss: 5.5646e-04 - 1s/epoch - 6ms/step
# Epoch 36/500
# 190/190 - 1s - loss: 0.0045 - val_loss: 5.2419e-04 - 1s/epoch - 6ms/step
# Epoch 37/500
# 190/190 - 1s - loss: 0.0044 - val_loss: 4.9430e-04 - 1s/epoch - 6ms/step
# Epoch 38/500
# 190/190 - 1s - loss: 0.0042 - val_loss: 4.6655e-04 - 1s/epoch - 6ms/step
# Epoch 39/500
# 190/190 - 1s - loss: 0.0041 - val_loss: 4.4066e-04 - 1s/epoch - 6ms/step
# Epoch 40/500
# 190/190 - 1s - loss: 0.0040 - val_loss: 4.1641e-04 - 1s/epoch - 6ms/step
# Epoch 41/500
# 190/190 - 1s - loss: 0.0038 - val_loss: 3.9360e-04 - 1s/epoch - 6ms/step
# Epoch 42/500
# 190/190 - 1s - loss: 0.0037 - val_loss: 3.7209e-04 - 1s/epoch - 6ms/step
# Epoch 43/500
# 190/190 - 1s - loss: 0.0036 - val_loss: 3.5181e-04 - 1s/epoch - 6ms/step
# Epoch 44/500
# 190/190 - 1s - loss: 0.0035 - val_loss: 3.3269e-04 - 1s/epoch - 6ms/step
# Epoch 45/500
# 190/190 - 1s - loss: 0.0034 - val_loss: 3.1466e-04 - 1s/epoch - 7ms/step
# Epoch 46/500
# 190/190 - 1s - loss: 0.0033 - val_loss: 2.9770e-04 - 1s/epoch - 6ms/step
# Epoch 47/500
# 190/190 - 1s - loss: 0.0032 - val_loss: 2.8176e-04 - 1s/epoch - 6ms/step
# Epoch 48/500
# 190/190 - 1s - loss: 0.0031 - val_loss: 2.6682e-04 - 1s/epoch - 6ms/step
# Epoch 49/500
# 190/190 - 1s - loss: 0.0031 - val_loss: 2.5286e-04 - 1s/epoch - 6ms/step
# Epoch 50/500
# 190/190 - 1s - loss: 0.0030 - val_loss: 2.3984e-04 - 1s/epoch - 6ms/step
# Epoch 51/500
# 190/190 - 1s - loss: 0.0029 - val_loss: 2.2774e-04 - 1s/epoch - 6ms/step
# Epoch 52/500
# 190/190 - 1s - loss: 0.0029 - val_loss: 2.1654e-04 - 1s/epoch - 6ms/step
# Epoch 53/500
# 190/190 - 1s - loss: 0.0028 - val_loss: 2.0621e-04 - 1s/epoch - 6ms/step
# Epoch 54/500
# 190/190 - 1s - loss: 0.0027 - val_loss: 1.9673e-04 - 1s/epoch - 7ms/step
# Epoch 55/500
# 190/190 - 1s - loss: 0.0027 - val_loss: 1.8804e-04 - 1s/epoch - 7ms/step
# Epoch 56/500
# 190/190 - 1s - loss: 0.0026 - val_loss: 1.8012e-04 - 1s/epoch - 6ms/step
# Epoch 57/500
# 190/190 - 1s - loss: 0.0026 - val_loss: 1.7292e-04 - 1s/epoch - 6ms/step
# Epoch 58/500
# 190/190 - 1s - loss: 0.0026 - val_loss: 1.6639e-04 - 1s/epoch - 7ms/step
# Epoch 59/500
# 190/190 - 1s - loss: 0.0025 - val_loss: 1.6049e-04 - 1s/epoch - 7ms/step
# Epoch 60/500
# 190/190 - 1s - loss: 0.0025 - val_loss: 1.5516e-04 - 1s/epoch - 6ms/step
# Epoch 61/500
# 190/190 - 1s - loss: 0.0024 - val_loss: 1.5037e-04 - 1s/epoch - 6ms/step
# Epoch 62/500
# 190/190 - 1s - loss: 0.0024 - val_loss: 1.4605e-04 - 1s/epoch - 7ms/step
# Epoch 63/500
# 190/190 - 1s - loss: 0.0024 - val_loss: 1.4217e-04 - 1s/epoch - 7ms/step
# Epoch 64/500
# 190/190 - 1s - loss: 0.0023 - val_loss: 1.3869e-04 - 1s/epoch - 7ms/step
# Epoch 65/500
# 190/190 - 1s - loss: 0.0023 - val_loss: 1.3554e-04 - 1s/epoch - 6ms/step
# Epoch 66/500
# 190/190 - 1s - loss: 0.0023 - val_loss: 1.3271e-04 - 1s/epoch - 6ms/step
# Epoch 67/500
# 190/190 - 1s - loss: 0.0023 - val_loss: 1.3013e-04 - 1s/epoch - 6ms/step
# Epoch 68/500
# 190/190 - 1s - loss: 0.0022 - val_loss: 1.2778e-04 - 1s/epoch - 6ms/step
# Epoch 69/500
# 190/190 - 1s - loss: 0.0022 - val_loss: 1.2561e-04 - 1s/epoch - 6ms/step
# Epoch 70/500
# 190/190 - 1s - loss: 0.0022 - val_loss: 1.2356e-04 - 1s/epoch - 6ms/step
# Epoch 71/500
# 190/190 - 1s - loss: 0.0022 - val_loss: 1.2158e-04 - 1s/epoch - 6ms/step
# Epoch 72/500
# 190/190 - 1s - loss: 0.0021 - val_loss: 1.1961e-04 - 1s/epoch - 6ms/step
# Epoch 73/500
# 190/190 - 1s - loss: 0.0021 - val_loss: 1.1763e-04 - 1s/epoch - 6ms/step
# Epoch 74/500
# 190/190 - 1s - loss: 0.0021 - val_loss: 1.1566e-04 - 1s/epoch - 6ms/step
# Epoch 75/500
# 190/190 - 1s - loss: 0.0020 - val_loss: 1.1383e-04 - 1s/epoch - 6ms/step
# Epoch 76/500
# 190/190 - 1s - loss: 0.0020 - val_loss: 1.1229e-04 - 1s/epoch - 6ms/step
# Epoch 77/500
# 190/190 - 1s - loss: 0.0020 - val_loss: 1.1112e-04 - 1s/epoch - 6ms/step
# Epoch 78/500
# 190/190 - 1s - loss: 0.0020 - val_loss: 1.1030e-04 - 1s/epoch - 6ms/step
# Epoch 79/500
# 190/190 - 1s - loss: 0.0019 - val_loss: 1.0972e-04 - 1s/epoch - 6ms/step
# Epoch 80/500
# 190/190 - 1s - loss: 0.0019 - val_loss: 1.0932e-04 - 1s/epoch - 6ms/step
# Epoch 81/500
# 190/190 - 1s - loss: 0.0019 - val_loss: 1.0902e-04 - 1s/epoch - 6ms/step
# Epoch 82/500
# 190/190 - 1s - loss: 0.0018 - val_loss: 1.0875e-04 - 1s/epoch - 6ms/step
# Epoch 83/500
# 190/190 - 1s - loss: 0.0018 - val_loss: 1.0845e-04 - 1s/epoch - 6ms/step
# Epoch 84/500
# 190/190 - 1s - loss: 0.0018 - val_loss: 1.0805e-04 - 1s/epoch - 6ms/step
# Epoch 85/500
# 190/190 - 1s - loss: 0.0018 - val_loss: 1.0751e-04 - 1s/epoch - 6ms/step
# Epoch 86/500
# 190/190 - 1s - loss: 0.0017 - val_loss: 1.0685e-04 - 1s/epoch - 6ms/step
# Epoch 87/500
# 190/190 - 1s - loss: 0.0017 - val_loss: 1.0612e-04 - 1s/epoch - 6ms/step
# Epoch 88/500
# 190/190 - 1s - loss: 0.0017 - val_loss: 1.0541e-04 - 1s/epoch - 6ms/step
# Epoch 89/500
# 190/190 - 1s - loss: 0.0017 - val_loss: 1.0480e-04 - 1s/epoch - 6ms/step
# Epoch 90/500
# 190/190 - 1s - loss: 0.0016 - val_loss: 1.0439e-04 - 1s/epoch - 6ms/step
# Epoch 91/500
# 190/190 - 1s - loss: 0.0016 - val_loss: 1.0425e-04 - 1s/epoch - 6ms/step
# Epoch 92/500
# 190/190 - 1s - loss: 0.0016 - val_loss: 1.0441e-04 - 1s/epoch - 6ms/step
# Epoch 93/500
# 190/190 - 1s - loss: 0.0016 - val_loss: 1.0488e-04 - 1s/epoch - 6ms/step
# Epoch 94/500
# 190/190 - 1s - loss: 0.0016 - val_loss: 1.0566e-04 - 1s/epoch - 7ms/step
# Epoch 95/500
# 190/190 - 1s - loss: 0.0015 - val_loss: 1.0670e-04 - 1s/epoch - 6ms/step
# Epoch 96/500
# 190/190 - 1s - loss: 0.0015 - val_loss: 1.0797e-04 - 1s/epoch - 6ms/step
# Epoch 97/500
# 190/190 - 1s - loss: 0.0015 - val_loss: 1.0941e-04 - 1s/epoch - 6ms/step
# Epoch 98/500
# 190/190 - 1s - loss: 0.0015 - val_loss: 1.1099e-04 - 1s/epoch - 6ms/step
# Epoch 99/500
# 190/190 - 1s - loss: 0.0015 - val_loss: 1.1265e-04 - 1s/epoch - 6ms/step
# Epoch 100/500
# 190/190 - 1s - loss: 0.0015 - val_loss: 1.1435e-04 - 1s/epoch - 6ms/step
# Epoch 101/500
# 190/190 - 1s - loss: 0.0015 - val_loss: 1.1608e-04 - 1s/epoch - 6ms/step
# Epoch 102/500
# 190/190 - 1s - loss: 0.0015 - val_loss: 1.1780e-04 - 1s/epoch - 6ms/step
# Epoch 103/500
# 190/190 - 1s - loss: 0.0014 - val_loss: 1.1948e-04 - 1s/epoch - 6ms/step
# Epoch 104/500
# 190/190 - 1s - loss: 0.0014 - val_loss: 1.2113e-04 - 1s/epoch - 6ms/step
# Epoch 105/500
# 190/190 - 1s - loss: 0.0014 - val_loss: 1.2272e-04 - 1s/epoch - 6ms/step
# Epoch 106/500
# 190/190 - 1s - loss: 0.0014 - val_loss: 1.2425e-04 - 1s/epoch - 6ms/step
# Epoch 107/500
# 190/190 - 1s - loss: 0.0014 - val_loss: 1.2571e-04 - 1s/epoch - 6ms/step
# Epoch 108/500
# 190/190 - 1s - loss: 0.0014 - val_loss: 1.2709e-04 - 1s/epoch - 6ms/step
# Epoch 109/500
# 190/190 - 1s - loss: 0.0014 - val_loss: 1.2841e-04 - 1s/epoch - 6ms/step
# Epoch 110/500
# 190/190 - 1s - loss: 0.0014 - val_loss: 1.2964e-04 - 1s/epoch - 6ms/step
# Epoch 111/500
# 190/190 - 1s - loss: 0.0014 - val_loss: 1.3080e-04 - 1s/epoch - 6ms/step
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0425e-04
# 0.00010424532956676558

# %%
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 68)                19584
#
#  dense (Dense)               (None, 1)                 69
#
# =================================================================
# Total params: 19,653
# Trainable params: 19,653
# Non-trainable params: 0
# _________________________________________________________________

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,6))
plt.plot(history_lstm.history['loss'], label='GA-LSTM training loss')
plt.plot(history_lstm.history['val_loss'], label='GA-LSTM validation loss')
plt.xlabel('Epochs', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.yticks(fontsize=12)
# plt.title('GA-LSTM validation loss over Epochs', fontsize=20)
plt.grid()
plt.legend(fontsize=15)
plt.savefig("GA-LSTM loss.png", format='png', dpi=1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# **MinMax Scaler equation**
# $$x' = \frac{(x - min)}{(max - min)} \times (new\ max\ value - new\ min\  value) + new\ min\ value$$<br/>
#
#
# $$x = \frac{(max - min)\times (new\ min\ value + x') + (new\ max\ value - new\ min\ value)\times min}{new\ max\ value - new\ min\ value}$$
#
# Where:
#
# $x$ is the inverse scaled value
# $x'$ is the scaled value
# $min$ is the minimum value of the original data
# $max$ is the maximum value of the original data.<br/>
# $new\ max\ value$ and $new\ min\ value$ is the new range that we want to scale the data to. For example: $(1,0)\ or\ (1,-1)$

# %% [markdown]
# # LSTM prediction

# %%
# make a prediction 
# select the number of obersvtions for prediction
yhat_lstm_test = model_lstm.predict(test_X, verbose=1)
yhat_lstm_train = model_lstm.predict(train_X, verbose=1)


# invert scaling 
scaled_test_y = pd.DataFrame(test_y)
scaled_train_y = pd.DataFrame(train_y)
scaled_yhat_lstm_test = pd.DataFrame(yhat_lstm_test) ## ravel () converting into 1D array
scaled_yhat_lstm_train = pd.DataFrame(yhat_lstm_train)
#obtain the min and max from the training set
unscaled_train = pd.DataFrame(series_supervised[:len(train)])
#new feature range
new_max_value = 1 
new_min_value= 0
feature_range = new_max_value - new_min_value

def transform_column(column):
    min_value = min(unscaled_train.iloc[:, -steps_ahead + column.name])
    max_value = max(unscaled_train.iloc[:, -steps_ahead + column.name])
    return ((max_value - min_value) * (new_min_value + column) + (feature_range  * min_value)) / feature_range 
    
# invert scaling for actual
y_lstm_test = scaled_test_y.apply(transform_column, axis=0).values
y_lstm_train = scaled_train_y.apply(transform_column, axis=0).values
# invert scaling for forecast
yhat_lstm_test = scaled_yhat_lstm_test.apply(transform_column, axis=0).values
yhat_lstm_train = scaled_yhat_lstm_train.apply(transform_column, axis=0).values
# Out:
# 12/12 [==============================] - 0s 3ms/step
# 48/48 [==============================] - 0s 3ms/step

# %%
# Performance evaluation LSTM
rmse_test = sqrt(mean_squared_error(y_lstm_test, yhat_lstm_test))
print('Test LSTM RMSE: %.5f' % rmse_test)
MAE_test = mean_absolute_error(y_lstm_test, yhat_lstm_test)
print('Test LSTM MAE: %.5f' % MAE_test)
r2 = r2_score(y_lstm_test, yhat_lstm_test)
print('Test LSTM r2: %.5f' % r2)
wMAPE_test = wMAPE(y_lstm_test, yhat_lstm_test)
print('Test LSTM wMAPE: %.5f ' % wMAPE_test)
# Out:
# Test LSTM RMSE: 204.28029
# Test LSTM MAE: 113.48826
# Test LSTM r2: 0.92351
# Test LSTM wMAPE: 4.96879

# %%
# concatenate the actual and LSTM predicetd values for both train adn test sets to be plotted together
entire_actual_lstm = np.concatenate([y_lstm_train,y_lstm_test], axis=0)
entire_forecast_lstm = np.concatenate([yhat_lstm_train,yhat_lstm_test], axis=0)

# %% [markdown]
# # Optimizing TCN hyperparameters

# %%
# optimize the TCN model
# define the total number of generations
n_iter = 10
# bits per variable
n_bits = 16
# define the number of combinations (individuals) per generation 
n_pop = 20
# crossover rate
r_cross = 0.9
# mutation rate
r_mut = 0.1

# define the search space for TCN
n_epochs = [500,500]
n_filters_1 = [3, 15]
n_filters_2 = [3, 15]
n_filters_3 = [3, 15]
batch_size = [2, 4]
window_size = [2, 12]
bounds_tcn = [n_epochs, n_filters_1, n_filters_2, n_filters_3, batch_size, window_size]


# run optimization
best_comb_tcn, score_tcn = genetic_algorithm(evaluate_TCN, bounds_tcn, n_bits, n_iter, n_pop, r_cross, r_mut)
print('Done!')
decoded = decode(bounds_tcn, n_bits, best_comb_tcn)
print('TCN Best: %s = %f' % (decoded, score_tcn))
# Out:
# Generation:1
# n_epochs 500 n_filters_1 14 n_filters_2 13 n_filters_3 14 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 7 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 4 n_filters_3 6 batch_size 4 window_size 9
# n_epochs 500 n_filters_1 6 n_filters_2 9 n_filters_3 10 batch_size 3 window_size 12
# n_epochs 500 n_filters_1 10 n_filters_2 14 n_filters_3 9 batch_size 4 window_size 5
# n_epochs 500 n_filters_1 10 n_filters_2 9 n_filters_3 9 batch_size 4 window_size 8
# n_epochs 500 n_filters_1 14 n_filters_2 6 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 12 n_filters_2 5 n_filters_3 7 batch_size 3 window_size 7
# n_epochs 500 n_filters_1 12 n_filters_2 14 n_filters_3 14 batch_size 2 window_size 7
# n_epochs 500 n_filters_1 8 n_filters_2 11 n_filters_3 10 batch_size 2 window_size 7
# n_epochs 500 n_filters_1 10 n_filters_2 7 n_filters_3 14 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 6 n_filters_2 12 n_filters_3 7 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 9 n_filters_2 4 n_filters_3 14 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 8 n_filters_3 5 batch_size 3 window_size 6
# n_epochs 500 n_filters_1 7 n_filters_2 11 n_filters_3 3 batch_size 3 window_size 7
# n_epochs 500 n_filters_1 13 n_filters_2 4 n_filters_3 14 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 4 n_filters_2 9 n_filters_3 5 batch_size 3 window_size 7
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 11 n_filters_2 5 n_filters_3 6 batch_size 2 window_size 12
# >1, new best combination, Epoch: 500, n_filters_1: 14, n_filters_2: 13, n_filters_3: 14, batch_size: 4, window_size: 3, Loss = 0.00012751
# >1, new best combination, Epoch: 500, n_filters_1: 7, n_filters_2: 14, n_filters_3: 7, batch_size: 2, window_size: 9, Loss = 0.00012079
# >1, new best combination, Epoch: 500, n_filters_1: 6, n_filters_2: 9, n_filters_3: 10, batch_size: 3, window_size: 12, Loss = 0.00011525
# >1, new best combination, Epoch: 500, n_filters_1: 7, n_filters_2: 8, n_filters_3: 5, batch_size: 3, window_size: 6, Loss = 0.00010997
# >1, new best combination, Epoch: 500, n_filters_1: 13, n_filters_2: 4, n_filters_3: 14, batch_size: 3, window_size: 8, Loss = 0.00010545
# Generation:2
# n_epochs 500 n_filters_1 8 n_filters_2 11 n_filters_3 9 batch_size 2 window_size 3
# n_epochs 500 n_filters_1 4 n_filters_2 14 n_filters_3 4 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 9 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 3 n_filters_2 15 n_filters_3 8 batch_size 3 window_size 7
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 15 n_filters_3 11 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 4 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 8
# n_epochs 500 n_filters_1 13 n_filters_2 4 n_filters_3 15 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 13 n_filters_2 4 n_filters_3 14 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 5 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 2
# n_epochs 500 n_filters_1 7 n_filters_2 5 n_filters_3 6 batch_size 2 window_size 10
# n_epochs 500 n_filters_1 11 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 6 n_filters_2 5 n_filters_3 6 batch_size 2 window_size 12
# n_epochs 500 n_filters_1 12 n_filters_2 15 n_filters_3 5 batch_size 3 window_size 7
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 12 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 6 n_filters_2 4 n_filters_3 14 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 9 n_filters_2 11 n_filters_3 4 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 8 n_filters_2 12 n_filters_3 14 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 14 batch_size 2 window_size 9
# Generation:3
# n_epochs 500 n_filters_1 13 n_filters_2 4 n_filters_3 14 batch_size 3 window_size 4
# n_epochs 500 n_filters_1 6 n_filters_2 12 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 13 n_filters_2 10 n_filters_3 12 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 13 n_filters_2 4 n_filters_3 12 batch_size 4 window_size 2
# n_epochs 500 n_filters_1 5 n_filters_2 15 n_filters_3 11 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 5 n_filters_3 9 batch_size 2 window_size 10
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 11 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 12 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 13 n_filters_2 5 n_filters_3 6 batch_size 2 window_size 11
# n_epochs 500 n_filters_1 7 n_filters_2 5 n_filters_3 6 batch_size 2 window_size 12
# n_epochs 500 n_filters_1 9 n_filters_2 13 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 12 n_filters_2 15 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 10 n_filters_3 14 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 5 n_filters_2 5 n_filters_3 8 batch_size 2 window_size 6
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 2
# n_epochs 500 n_filters_1 5 n_filters_2 6 n_filters_3 8 batch_size 2 window_size 10
# n_epochs 500 n_filters_1 13 n_filters_2 10 n_filters_3 14 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 14 batch_size 2 window_size 8
# >3, new best combination, Epoch: 500, n_filters_1: 8, n_filters_2: 10, n_filters_3: 14, batch_size: 3, window_size: 9, Loss = 0.00010460
# Generation:4
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 11 batch_size 2 window_size 8
# n_epochs 500 n_filters_1 4 n_filters_2 12 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 4 n_filters_3 11 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 8 batch_size 2 window_size 10
# n_epochs 500 n_filters_1 5 n_filters_2 4 n_filters_3 15 batch_size 2 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 11 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 8
# n_epochs 500 n_filters_1 5 n_filters_2 5 n_filters_3 8 batch_size 2 window_size 6
# n_epochs 500 n_filters_1 5 n_filters_2 5 n_filters_3 8 batch_size 2 window_size 6
# n_epochs 500 n_filters_1 14 n_filters_2 6 n_filters_3 8 batch_size 2 window_size 11
# n_epochs 500 n_filters_1 5 n_filters_2 10 n_filters_3 14 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 10 n_filters_2 15 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 6 n_filters_2 4 n_filters_3 14 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 9 n_filters_2 14 n_filters_3 6 batch_size 3 window_size 11
# n_epochs 500 n_filters_1 13 n_filters_2 13 n_filters_3 13 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 4 n_filters_3 11 batch_size 3 window_size 4
# n_epochs 500 n_filters_1 5 n_filters_2 10 n_filters_3 12 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 5 n_filters_2 11 n_filters_3 14 batch_size 3 window_size 4
# Generation:5
# n_epochs 500 n_filters_1 5 n_filters_2 5 n_filters_3 8 batch_size 2 window_size 12
# n_epochs 500 n_filters_1 6 n_filters_2 12 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 11 n_filters_3 5 batch_size 2 window_size 6
# n_epochs 500 n_filters_1 5 n_filters_2 5 n_filters_3 11 batch_size 3 window_size 4
# n_epochs 500 n_filters_1 9 n_filters_2 5 n_filters_3 5 batch_size 2 window_size 7
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 11 batch_size 2 window_size 8
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 8 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 8 n_filters_2 4 n_filters_3 11 batch_size 2 window_size 10
# n_epochs 500 n_filters_1 11 n_filters_2 4 n_filters_3 11 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 11 n_filters_3 14 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 11 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 10 n_filters_2 14 n_filters_3 14 batch_size 3 window_size 4
# n_epochs 500 n_filters_1 6 n_filters_2 11 n_filters_3 11 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 6 batch_size 3 window_size 11
# n_epochs 500 n_filters_1 5 n_filters_2 13 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 10 n_filters_3 12 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 5 n_filters_2 12 n_filters_3 8 batch_size 2 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 14 batch_size 2 window_size 6
# Generation:6
# n_epochs 500 n_filters_1 5 n_filters_2 5 n_filters_3 11 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 4 n_filters_2 12 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 7 n_filters_3 9 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 12 n_filters_3 12 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 7 n_filters_2 12 n_filters_3 5 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 11 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 8
# n_epochs 500 n_filters_1 5 n_filters_2 5 n_filters_3 12 batch_size 3 window_size 11
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 6 batch_size 3 window_size 4
# n_epochs 500 n_filters_1 15 n_filters_2 11 n_filters_3 14 batch_size 3 window_size 4
# n_epochs 500 n_filters_1 9 n_filters_2 11 n_filters_3 14 batch_size 3 window_size 4
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 10 n_filters_2 15 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 7 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 9 n_filters_3 6 batch_size 4 window_size 11
# n_epochs 500 n_filters_1 5 n_filters_2 11 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 6 n_filters_3 5 batch_size 2 window_size 12
# n_epochs 500 n_filters_1 5 n_filters_2 5 n_filters_3 8 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 14 batch_size 2 window_size 3
# Generation:7
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 7 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 6 n_filters_2 12 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 6 n_filters_2 8 n_filters_3 3 batch_size 3 window_size 4
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 5 batch_size 2 window_size 12
# n_epochs 500 n_filters_1 5 n_filters_2 4 n_filters_3 3 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 11 batch_size 2 window_size 8
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 5 n_filters_2 5 n_filters_3 11 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 6 n_filters_2 7 n_filters_3 9 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 15 n_filters_2 11 n_filters_3 14 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 11 n_filters_3 14 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 10 n_filters_2 14 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 5 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 6 batch_size 3 window_size 11
# n_epochs 500 n_filters_1 5 n_filters_2 13 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 6 n_filters_3 14 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 7 n_filters_2 8 n_filters_3 6 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 14 batch_size 2 window_size 4
# Generation:8
# n_epochs 500 n_filters_1 5 n_filters_2 4 n_filters_3 4 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 4 n_filters_2 12 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 11 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 11 n_filters_3 14 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 15 n_filters_2 10 n_filters_3 11 batch_size 3 window_size 2
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 11 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 8
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 6 batch_size 3 window_size 11
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 6 batch_size 3 window_size 11
# n_epochs 500 n_filters_1 11 n_filters_2 4 n_filters_3 3 batch_size 3 window_size 2
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 14 batch_size 2 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 10 n_filters_2 15 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 5 n_filters_2 11 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 14 n_filters_3 6 batch_size 4 window_size 11
# n_epochs 500 n_filters_1 5 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 3 n_filters_3 7 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 6 n_filters_2 12 n_filters_3 9 batch_size 3 window_size 4
# n_epochs 500 n_filters_1 5 n_filters_2 3 n_filters_3 14 batch_size 2 window_size 8
# Generation:9
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 7 batch_size 3 window_size 6
# n_epochs 500 n_filters_1 6 n_filters_2 12 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 6 n_filters_2 7 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 7 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 5 n_filters_3 3 batch_size 3 window_size 11
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 11 batch_size 2 window_size 8
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 14 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 5 n_filters_2 4 n_filters_3 4 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 11 n_filters_3 9 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 11 n_filters_2 3 n_filters_3 14 batch_size 2 window_size 4
# n_epochs 500 n_filters_1 5 n_filters_2 11 n_filters_3 13 batch_size 4 window_size 2
# n_epochs 500 n_filters_1 9 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 10 n_filters_2 14 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 9 n_filters_2 7 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 6 batch_size 3 window_size 11
# n_epochs 500 n_filters_1 5 n_filters_2 13 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 3 n_filters_3 6 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 8 n_filters_3 6 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 8 n_filters_2 9 n_filters_3 12 batch_size 4 window_size 11
# >9, new best combination, Epoch: 500, n_filters_1: 7, n_filters_2: 8, n_filters_3: 6, batch_size: 3, window_size: 8, Loss = 0.00010437
# Generation:10
# n_epochs 500 n_filters_1 8 n_filters_2 11 n_filters_3 10 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 4 n_filters_2 12 n_filters_3 9 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 3 n_filters_3 6 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 9 n_filters_2 5 n_filters_3 13 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 8 n_filters_3 6 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 5 n_filters_3 3 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 8 n_filters_2 5 n_filters_3 11 batch_size 2 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 8 n_filters_3 6 batch_size 3 window_size 9
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 7 batch_size 3 window_size 11
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 6 batch_size 3 window_size 6
# n_epochs 500 n_filters_1 14 n_filters_2 3 n_filters_3 6 batch_size 3 window_size 8
# n_epochs 500 n_filters_1 7 n_filters_2 9 n_filters_3 13 batch_size 4 window_size 10
# n_epochs 500 n_filters_1 8 n_filters_2 10 n_filters_3 12 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 10 n_filters_2 15 n_filters_3 13 batch_size 4 window_size 11
# n_epochs 500 n_filters_1 5 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 11 n_filters_3 6 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 7 n_filters_2 13 n_filters_3 12 batch_size 4 window_size 3
# n_epochs 500 n_filters_1 8 n_filters_2 14 n_filters_3 3 batch_size 3 window_size 6
# n_epochs 500 n_filters_1 7 n_filters_2 14 n_filters_3 6 batch_size 3 window_size 3
# n_epochs 500 n_filters_1 4 n_filters_2 6 n_filters_3 6 batch_size 3 window_size 8
# >10, new best combination, Epoch: 500, n_filters_1: 7, n_filters_2: 8, n_filters_3: 6, batch_size: 3, window_size: 9, Loss = 0.00010100
# Done!
# TCN Best: [500, 7, 8, 6, 3, 9] = 0.000101

# %% [markdown]
# # Run the TCN model using the optimal hyperparamters obtained by GA

# %%
steps_ahead = 1
# Define hyperparamtes
n_epochs = 500
n_filters_1 = 7
n_filters_2 = 8
n_filters_3 =  6
batch_size = 3
window_size = 9


# # setting the session configurations for reproducibility.
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
np.random.seed(12345)
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,
                                    inter_op_parallelism_threads=1)
from keras import backend as K   
tf.random.set_seed(1234)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), 
                        config=session_conf)
K.set_session(sess)

# # convert the series to supervise learning using sliding window approach
series_supervised = series_to_supervised(series, series.columns, n_in= window_size, n_out= steps_ahead, dropnan=True)   

# drop columns we don't want to predict
pattern = re.compile(r"(t-)|^BORE_OIL_VOL.*")

# Extract the column names that match the pattern
matching_columns = [col for col in series_supervised.columns if re.search(pattern, col)]
series_supervised = series_supervised[matching_columns]
# # split into train and test sets
n_features = int((len(series_supervised.columns) -steps_ahead)/window_size)
series_supervised = series_supervised.values
train_size = int(series_supervised.shape[0] * 0.8)
test_size = series_supervised.shape[0] - train_size
train, test = series_supervised[0:train_size], series_supervised[train_size:]
print("train.shape:",train.shape, "test.shape:",test.shape)

# scale  the data to a feature range(0,1)
scaler, train_scaled, test_scaled = scale(train, test)
print('train_scaled.shape:',train_scaled.shape, "test_scaled.shape:",test_scaled.shape)

# # reshape input to be 3D [samples, window_size, features]
train_X, train_y = train_scaled[:, 0:-steps_ahead], train_scaled[:, -steps_ahead:]
train_X = train_X.reshape(train_X.shape[0], window_size, n_features)
test_X, test_y = test_scaled[:, 0:-steps_ahead], test_scaled[:, -steps_ahead:]
test_X = test_X.reshape(test_X.shape[0], window_size, n_features )
print("train_X.shape:",train_X.shape, "train_y.shape:",train_y.shape,
        "test_X.shape:", test_X.shape,"test_y.shape:",test_y.shape)

# build the TCN model
input_tensor=Input(shape=(window_size, n_features))

#Feature extraction module
conv1 = Conv1D(filters = n_filters_1, kernel_size = 1, dilation_rate=1 ,padding='same')(input_tensor)
conv2 = Conv1D(filters = n_filters_2 , kernel_size = 1, dilation_rate=1, padding='same')(conv1)
# Time information extraction module
conv3 = Conv1D(filters = n_filters_3, kernel_size= window_size, dilation_rate=1, padding='causal')(conv2) 

conv3 = Flatten()(conv3)  
outputs = Dense(steps_ahead)(conv3)
model_tcn = Model(input_tensor, outputs)

model_tcn.compile(loss='mean_squared_error',
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001))

#prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=20, verbose=0,
                            restore_best_weights=True, mode='min')
history_tcn = model_tcn.fit(train_X, train_y, epochs=n_epochs, batch_size=batch_size, callbacks = [early_stopping],
            validation_data=(test_X, test_y), verbose=2, shuffle=False)
model_tcn.evaluate(test_X, test_y)
# Out:
# train.shape: (1518, 28) test.shape: (380, 28)
# train_scaled.shape: (1518, 28) test_scaled.shape: (380, 28)
# train_X.shape: (1518, 9, 3) train_y.shape: (1518, 1) test_X.shape: (380, 9, 3) test_y.shape: (380, 1)
# Epoch 1/500
# 506/506 - 1s - loss: 0.2437 - val_loss: 0.0147 - 1s/epoch - 3ms/step
# Epoch 2/500
# 506/506 - 1s - loss: 0.0321 - val_loss: 0.0106 - 952ms/epoch - 2ms/step
# Epoch 3/500
# 506/506 - 1s - loss: 0.0278 - val_loss: 0.0074 - 803ms/epoch - 2ms/step
# Epoch 4/500
# 506/506 - 1s - loss: 0.0239 - val_loss: 0.0053 - 813ms/epoch - 2ms/step
# Epoch 5/500
# 506/506 - 1s - loss: 0.0207 - val_loss: 0.0039 - 815ms/epoch - 2ms/step
# Epoch 6/500
# 506/506 - 1s - loss: 0.0179 - val_loss: 0.0030 - 975ms/epoch - 2ms/step
# Epoch 7/500
# 506/506 - 1s - loss: 0.0157 - val_loss: 0.0024 - 787ms/epoch - 2ms/step
# Epoch 8/500
# 506/506 - 1s - loss: 0.0139 - val_loss: 0.0020 - 802ms/epoch - 2ms/step
# Epoch 9/500
# 506/506 - 1s - loss: 0.0125 - val_loss: 0.0017 - 818ms/epoch - 2ms/step
# Epoch 10/500
# 506/506 - 1s - loss: 0.0113 - val_loss: 0.0014 - 800ms/epoch - 2ms/step
# Epoch 11/500
# 506/506 - 1s - loss: 0.0104 - val_loss: 0.0013 - 811ms/epoch - 2ms/step
# Epoch 12/500
# 506/506 - 1s - loss: 0.0097 - val_loss: 0.0011 - 789ms/epoch - 2ms/step
# Epoch 13/500
# 506/506 - 1s - loss: 0.0091 - val_loss: 0.0010 - 800ms/epoch - 2ms/step
# Epoch 14/500
# 506/506 - 1s - loss: 0.0086 - val_loss: 9.3960e-04 - 820ms/epoch - 2ms/step
# Epoch 15/500
# 506/506 - 1s - loss: 0.0081 - val_loss: 8.6402e-04 - 812ms/epoch - 2ms/step
# Epoch 16/500
# 506/506 - 1s - loss: 0.0077 - val_loss: 7.9663e-04 - 800ms/epoch - 2ms/step
# Epoch 17/500
# 506/506 - 1s - loss: 0.0073 - val_loss: 7.3450e-04 - 795ms/epoch - 2ms/step
# Epoch 18/500
# 506/506 - 1s - loss: 0.0069 - val_loss: 6.7581e-04 - 823ms/epoch - 2ms/step
# Epoch 19/500
# 506/506 - 1s - loss: 0.0066 - val_loss: 6.1956e-04 - 978ms/epoch - 2ms/step
# Epoch 20/500
# 506/506 - 1s - loss: 0.0062 - val_loss: 5.6540e-04 - 818ms/epoch - 2ms/step
# Epoch 21/500
# 506/506 - 1s - loss: 0.0059 - val_loss: 5.1358e-04 - 824ms/epoch - 2ms/step
# Epoch 22/500
# 506/506 - 1s - loss: 0.0056 - val_loss: 4.6449e-04 - 950ms/epoch - 2ms/step
# Epoch 23/500
# 506/506 - 1s - loss: 0.0053 - val_loss: 4.1851e-04 - 809ms/epoch - 2ms/step
# Epoch 24/500
# 506/506 - 1s - loss: 0.0051 - val_loss: 3.7587e-04 - 781ms/epoch - 2ms/step
# Epoch 25/500
# 506/506 - 1s - loss: 0.0048 - val_loss: 3.3670e-04 - 835ms/epoch - 2ms/step
# Epoch 26/500
# 506/506 - 1s - loss: 0.0046 - val_loss: 3.0103e-04 - 819ms/epoch - 2ms/step
# Epoch 27/500
# 506/506 - 1s - loss: 0.0043 - val_loss: 2.6887e-04 - 814ms/epoch - 2ms/step
# Epoch 28/500
# 506/506 - 1s - loss: 0.0041 - val_loss: 2.4014e-04 - 969ms/epoch - 2ms/step
# Epoch 29/500
# 506/506 - 1s - loss: 0.0039 - val_loss: 2.1475e-04 - 778ms/epoch - 2ms/step
# Epoch 30/500
# 506/506 - 1s - loss: 0.0037 - val_loss: 1.9255e-04 - 819ms/epoch - 2ms/step
# Epoch 31/500
# 506/506 - 1s - loss: 0.0035 - val_loss: 1.7338e-04 - 851ms/epoch - 2ms/step
# Epoch 32/500
# 506/506 - 1s - loss: 0.0034 - val_loss: 1.5703e-04 - 838ms/epoch - 2ms/step
# Epoch 33/500
# 506/506 - 1s - loss: 0.0032 - val_loss: 1.4331e-04 - 810ms/epoch - 2ms/step
# Epoch 34/500
# 506/506 - 1s - loss: 0.0031 - val_loss: 1.3201e-04 - 791ms/epoch - 2ms/step
# Epoch 35/500
# 506/506 - 1s - loss: 0.0030 - val_loss: 1.2292e-04 - 797ms/epoch - 2ms/step
# Epoch 36/500
# 506/506 - 2s - loss: 0.0029 - val_loss: 1.1580e-04 - 2s/epoch - 3ms/step
# Epoch 37/500
# 506/506 - 1s - loss: 0.0028 - val_loss: 1.1042e-04 - 1s/epoch - 3ms/step
# Epoch 38/500
# 506/506 - 1s - loss: 0.0027 - val_loss: 1.0652e-04 - 1s/epoch - 3ms/step
# Epoch 39/500
# 506/506 - 1s - loss: 0.0027 - val_loss: 1.0384e-04 - 798ms/epoch - 2ms/step
# Epoch 40/500
# 506/506 - 1s - loss: 0.0026 - val_loss: 1.0215e-04 - 795ms/epoch - 2ms/step
# Epoch 41/500
# 506/506 - 1s - loss: 0.0026 - val_loss: 1.0124e-04 - 803ms/epoch - 2ms/step
# Epoch 42/500
# 506/506 - 1s - loss: 0.0025 - val_loss: 1.0090e-04 - 836ms/epoch - 2ms/step
# Epoch 43/500
# 506/506 - 1s - loss: 0.0025 - val_loss: 1.0098e-04 - 843ms/epoch - 2ms/step
# Epoch 44/500
# 506/506 - 1s - loss: 0.0025 - val_loss: 1.0136e-04 - 797ms/epoch - 2ms/step
# Epoch 45/500
# 506/506 - 1s - loss: 0.0024 - val_loss: 1.0193e-04 - 801ms/epoch - 2ms/step
# Epoch 46/500
# 506/506 - 1s - loss: 0.0024 - val_loss: 1.0261e-04 - 809ms/epoch - 2ms/step
# Epoch 47/500
# 506/506 - 1s - loss: 0.0024 - val_loss: 1.0335e-04 - 970ms/epoch - 2ms/step
# Epoch 48/500
# 506/506 - 1s - loss: 0.0024 - val_loss: 1.0411e-04 - 811ms/epoch - 2ms/step
# Epoch 49/500
# 506/506 - 1s - loss: 0.0024 - val_loss: 1.0487e-04 - 803ms/epoch - 2ms/step
# Epoch 50/500
# 506/506 - 1s - loss: 0.0024 - val_loss: 1.0561e-04 - 804ms/epoch - 2ms/step
# Epoch 51/500
# 506/506 - 1s - loss: 0.0023 - val_loss: 1.0632e-04 - 813ms/epoch - 2ms/step
# Epoch 52/500
# 506/506 - 1s - loss: 0.0023 - val_loss: 1.0700e-04 - 804ms/epoch - 2ms/step
# Epoch 53/500
# 506/506 - 1s - loss: 0.0023 - val_loss: 1.0765e-04 - 814ms/epoch - 2ms/step
# Epoch 54/500
# 506/506 - 1s - loss: 0.0023 - val_loss: 1.0827e-04 - 796ms/epoch - 2ms/step
# Epoch 55/500
# 506/506 - 1s - loss: 0.0023 - val_loss: 1.0886e-04 - 811ms/epoch - 2ms/step
# Epoch 56/500
# 506/506 - 1s - loss: 0.0023 - val_loss: 1.0943e-04 - 801ms/epoch - 2ms/step
# Epoch 57/500
# 506/506 - 1s - loss: 0.0023 - val_loss: 1.0997e-04 - 795ms/epoch - 2ms/step
# Epoch 58/500
# 506/506 - 1s - loss: 0.0023 - val_loss: 1.1049e-04 - 805ms/epoch - 2ms/step
# Epoch 59/500
# 506/506 - 1s - loss: 0.0022 - val_loss: 1.1098e-04 - 782ms/epoch - 2ms/step
# Epoch 60/500
# 506/506 - 1s - loss: 0.0022 - val_loss: 1.1146e-04 - 808ms/epoch - 2ms/step
# Epoch 61/500
# 506/506 - 1s - loss: 0.0022 - val_loss: 1.1191e-04 - 820ms/epoch - 2ms/step
# Epoch 62/500
# 506/506 - 1s - loss: 0.0022 - val_loss: 1.1234e-04 - 801ms/epoch - 2ms/step
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0090e-04
# 0.00010090012801811099

# %%
model_tcn.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 9, 3)]            0
#
#  conv1d (Conv1D)             (None, 9, 7)              28
#
#  conv1d_1 (Conv1D)           (None, 9, 8)              64
#
#  conv1d_2 (Conv1D)           (None, 9, 6)              438
#
#  flatten (Flatten)           (None, 54)                0
#
#  dense_1 (Dense)             (None, 1)                 55
#
# =================================================================
# Total params: 585
# Trainable params: 585
# Non-trainable params: 0
# _________________________________________________________________

# %%
# TCN validation loss over epochs
fig, ax = plt.subplots(1, 1, figsize=(8,6))
plt.plot(history_tcn.history['loss'], label='GA-TCN training loss')
plt.plot(history_tcn.history['val_loss'], label='GA-TCN validation loss')
plt.xlabel('Epochs', fontsize=15)
plt.xticks(fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.yticks(fontsize=12)
# plt.title('GA-TCN validation loss over Epochs', fontsize=20)
plt.grid()
plt.legend(fontsize=15)
plt.savefig("GA-TCN loss.png", format='png', dpi=1600, bbox_inches='tight')
plt.show()

# %% [markdown]
# # TCN prediction

# %%
# make a prediction 
# select the number of obersvtions for prediction
yhat_tcn_test = model_tcn.predict(test_X, verbose=1)
yhat_tcn_train = model_tcn.predict(train_X, verbose=1)


# invert scaling 
scaled_test_y = pd.DataFrame(test_y)
scaled_train_y = pd.DataFrame(train_y)
scaled_yhat_tcn_test = pd.DataFrame(yhat_tcn_test) ## ravel () converting into 1D array
scaled_yhat_tcn_train = pd.DataFrame(yhat_tcn_train)
#obtain the min and max from the training set
unscaled_train = pd.DataFrame(series_supervised[:len(train)])
#new feature range
new_max_value = 1 
new_min_value= 0
feature_range = new_max_value - new_min_value

def transform_column(column):
    min_value = min(unscaled_train.iloc[:, -steps_ahead + column.name])
    max_value = max(unscaled_train.iloc[:, -steps_ahead + column.name])
    return ((max_value - min_value) * (new_min_value + column) + (feature_range  * min_value)) / feature_range 
    
# invert scaling for actual
y_tcn_test = scaled_test_y.apply(transform_column, axis=0).values
y_tcn_train = scaled_train_y.apply(transform_column, axis=0).values
# invert scaling for forecast
yhat_tcn_test = scaled_yhat_tcn_test.apply(transform_column, axis=0).values
yhat_tcn_train = scaled_yhat_tcn_train.apply(transform_column, axis=0).values
# Out:
# 12/12 [==============================] - 0s 3ms/step
# 48/48 [==============================] - 0s 3ms/step

# %%
# Performance evaluation LSTM
rmse_test = sqrt(mean_squared_error(y_tcn_test, yhat_tcn_test))
print('Test LSTM RMSE: %.5f' % rmse_test)
MAE_test = mean_absolute_error(y_tcn_test, yhat_tcn_test)
print('Test LSTM MAE: %.5f' % MAE_test)
r2 = r2_score(y_tcn_test, yhat_tcn_test)
print('Test LSTM r2: %.5f' % r2)
wMAPE_test = wMAPE(y_tcn_test, yhat_tcn_test)
print('Test LSTM wMAPE: %.5f ' % wMAPE_test)
# Out:
# Test LSTM RMSE: 201.05765
# Test LSTM MAE: 122.45935
# Test LSTM r2: 0.92590
# Test LSTM wMAPE: 5.36157

# %%
# concatenate the actual and LSTM predicetd values for both train adn test sets to be plotted together
entire_actual_tcn = np.concatenate([y_tcn_train,y_tcn_test], axis=0)
entire_forecast_tcn = np.concatenate([yhat_tcn_train,yhat_tcn_test], axis=0)

# %% [markdown]
# # Combining the predictions of both modelS GA-LSTM & GA-TCN

# %%
#find the optimal weights for the weighted average metric that will be used for the prediction of TCN-LSTM
# Define a range for the weights to be searched
weights = np.linspace(0.0, 1, 100)
weights = np.round(weights,5)

# Initialize the best weights and best performance
# best_weights = (1,1)
best_performance = float('inf')

# Iterate over all possible weight combinations
for w1 in weights:
    for w2 in weights:        
        # Make predictions using the current weight combination
        predictions = ((w1 * yhat_tcn_test) + (w2 * yhat_lstm_test)) / (w1+w2+1e-10)
        
        # Evaluate the performance using some metric, e.g. accuracy
        performance = sqrt(mean_squared_error(y_tcn_test, predictions))

        # Update the best weights and best performance if the current performance is better
        if performance < best_performance:
            best_weights = (w1, w2)
            best_performance = performance

print("Best weights:", best_weights)
print("Best performance:", best_performance)
# Out:
# Best weights: (0.55556, 0.32323)
# Best performance: 199.38657611974884

# %%
# Performance evaluation

w1 , w2 = 0.55556,  0.32323
weightedA_test_tcn_lstm = (w1 * yhat_tcn_test + w2 * yhat_lstm_test) / (w1+w2+1e-10)

rmse_test = sqrt(mean_squared_error(y_tcn_test, weightedA_test_tcn_lstm))
print('Test GA-TCN-LSTM RMSE: %.5f' % rmse_test)
MAE_test = mean_absolute_error(y_tcn_test, weightedA_test_tcn_lstm)
print('Test GA-TCN-LSTM MAE: %.5f' % MAE_test)
r2 = r2_score(y_tcn_test, weightedA_test_tcn_lstm)
print('Test GA-TCN-LSTM r2: %.5f' % r2)
wMAPE_test = wMAPE(y_tcn_test, weightedA_test_tcn_lstm)
print('Test GA-TCN-LSTM wMAPE: %.5f ' % wMAPE_test)
# Out:
# Test GA-TCN-LSTM RMSE: 199.38658
# Test GA-TCN-LSTM MAE: 117.10746
# Test GA-TCN-LSTM r2: 0.92713
# Test GA-TCN-LSTM wMAPE: 5.12725

# %% [markdown]
# # Plotting the the forecasted and actual values for the whole dataset

# %%
# concatenate the predicted values of train and test sets by LSTM AND TCN
# remove the first one because the tcn window size is 9 steps and target is the 10th value while LSTM's window size is 10 and target is the 11th value
# when we remove the first actual point from TCN training data, the shape of both training data used for TCN and LSTM will be the same
# the start and end points for test sets used by both models are the same, so all values are retained
actual_entire_lstm_tcn = entire_actual_tcn[1:]
# we will concatenete the predicted values by weighted avaerage for training sets for both LSTM and TCN using the optimal weights that were used 
# to concatenate the test sets for both models 
weightedA_train_tcn_lstm = (w1 * yhat_tcn_train[1:] + w2 * yhat_lstm_train) / (w1+w2+1e-10)
forecast_entire_lstm_tcn = np.concatenate([weightedA_train_tcn_lstm, weightedA_test_tcn_lstm], axis=0)
print("weightedA_train_tcn_lstm.shape:",weightedA_train_tcn_lstm.shape,
      "\nweightedA_test_tcn_lstm.shape",weightedA_test_tcn_lstm.shape,
      "\nforecast_entire_lstm_tcn.shape",forecast_entire_lstm_tcn.shape,
      "\nactual_entire_lstm_tcn.shape",actual_entire_lstm_tcn.shape)
# Out:
# weightedA_train_tcn_lstm.shape: (1517, 1)
# weightedA_test_tcn_lstm.shape (380, 1)
# forecast_entire_lstm_tcn.shape (1897, 1)
# actual_entire_lstm_tcn.shape (1897, 1)

# %%
fig, ax = plt.subplots(1, 1, figsize=( 18,6))
plt.plot(actual_entire_lstm_tcn, label = 'Actual production')
plt.plot(forecast_entire_lstm_tcn, label = 'GA-TCN-LSTM predicted values')

# create the horizontal dashed line
plt.axvline(x=train_X.shape[0] + 1, color='black', linestyle='--')
plt.legend()
# add text labels
plt.text(1350, 17500, 'Training set', rotation=0, verticalalignment='center', style='italic', fontweight='bold')
plt.text(1540, 15000, 'Testing set', rotation=0, verticalalignment='center', style='italic', fontweight='bold')

plt.ylabel('Daily Oil Prodcution, bbl', fontsize=15)
plt.xlabel('Days', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

# Create a font object with bold weight
font = FontProperties()
font.set_weight('bold')
plt.legend(fontsize=10, loc= 'upper right', prop=font)


plt.savefig("GA-TCN-LSTM actual-forecast.png", dpi=1600, bbox_inches='tight')
plt.show()

# %%
# cross plot
fig, ax = plt.subplots(1, 1, figsize=(8,6))
# Create a scatter plot
ax.scatter(y_tcn_test, weightedA_test_tcn_lstm, marker='o', s=50, c='b', alpha=0.6)

# Add a 45-degree line
ax.plot([0,4500], [0,4500], 'k-', linestyle='dashed')

# Add labels and a title
plt.xlabel("Actual oil production, bbl", fontsize=15)
plt.ylabel("Predicted oil prodcution, bbl",  fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("GA-TCN-LSTM", fontsize=15)

plt.savefig("GA-TCN-LSTM cross plot.png", dpi=1600, bbox_inches='tight')
# Show the plot
plt.show()

# %%
# residual plot
# Calculate residuals
residuals = y_tcn_test -  weightedA_test_tcn_lstm  
# Plot residuals on a zero mean
fig, ax = plt.subplots(figsize=(8,6))
ax.axhline(y=0, color='black', linewidth=1)
ax.scatter(yhat_lstm_test, residuals, marker='o', s=50, c='b', alpha=0.6)
ax.set_xlabel("Predicted values", fontsize=15)
ax.set_ylabel("Residuals", fontsize=15)
ax.set_title("GA-TCN-LSTM", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("GA-TCN-LSTM", fontsize=15)

plt.savefig("GA-TCN-LSTM residual plot.png", dpi=1600, bbox_inches='tight')
plt.show()
